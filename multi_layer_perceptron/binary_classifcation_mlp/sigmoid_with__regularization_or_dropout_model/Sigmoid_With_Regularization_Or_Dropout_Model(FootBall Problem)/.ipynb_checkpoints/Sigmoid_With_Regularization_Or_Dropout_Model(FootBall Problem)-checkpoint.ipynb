# %% [markdown]
# ### Load 2D Dataset

# %%
import numpy as np
from Sigmoid_Necessary_Functions_With_Regularization_Or_Dropout import *
from Gradient_Checker_With_Regularization_Or_Dropout import *
from Load_2D_Dataset import load_2D_dataset

import matplotlib.pyplot as plt

# %%
X_train, Y_train, X_test, Y_test = load_2D_dataset()

# %%
print('X_train has shape :' +str(X_train.shape))
print('Y_train has shape :' +str(Y_train.shape))
print('X_test has shape :' +str(X_test.shape))
print('Y_test has shape :' +str(X_test.shape))
# Out:
# X_train has shape :(2, 211)
# Y_train has shape :(1, 211)
# X_test has shape :(2, 200)
# Y_test has shape :(2, 200)

# %%
parameters = regularized_or_dropout_model_sigmoid(X_train, Y_train, learning_rate = 0.3, num_iteration = 1000, layers_dims = [X_train.shape[0],40,30,1], lambd = 0, keep_prob = 0.6) # keep_prob = 0.8
train_accuracy = predict_accuracy(X_train, Y_train, parameters)
test_accuracy = predict_accuracy(X_test, Y_test, parameters)
print('Train accuracy is: '+str(train_accuracy))
print('Test accuracy is: '+str(test_accuracy))
# Out:
# cost after 0 epochs is 0.7804742433292275
# cost after 100 epochs is 0.11716296887454085
# cost after 200 epochs is 0.05647114927802821
# cost after 300 epochs is 0.027210868853479786
# /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Sigmoid_With__Regularization_Or_Dropout_Model/Sigmoid_With_Regularization_Or_Dropout_Model(FootBall Problem)/Sigmoid_Necessary_Functions_With_Regularization_Or_Dropout.py:95: RuntimeWarning: divide by zero encountered in log
#   J = -(1/m)*np.nansum((np.multiply(Y, np.log(AL)) + np.multiply((1 - Y), np.log(1 - AL))))
# /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Sigmoid_With__Regularization_Or_Dropout_Model/Sigmoid_With_Regularization_Or_Dropout_Model(FootBall Problem)/Sigmoid_Necessary_Functions_With_Regularization_Or_Dropout.py:95: RuntimeWarning: invalid value encountered in multiply
#   J = -(1/m)*np.nansum((np.multiply(Y, np.log(AL)) + np.multiply((1 - Y), np.log(1 - AL))))
# cost after 400 epochs is 0.01414417330123249
# cost after 500 epochs is 0.00847090624656223
# cost after 600 epochs is 0.0056775559792845605
# cost after 700 epochs is 0.004113429201618956
# cost after 800 epochs is 0.0031282492823198416
# cost after 900 epochs is 0.0024828728750873564
# Train accuracy is: 0.8909952606635071
# Test accuracy is: 0.895

# %%
AL, cache = forward_prop_with_dropout(X_train, parameters, keep_prob = 0.6)
gradients = back_prop_with_dropout(X_train, Y_train, cache, keep_prob = 0.6)
difference = gradient_checker_with_regularization_or_dropout(X_train, Y_train, parameters, gradients, lambd = 0, keep_prob = 0.6)
# Out:
# /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Sigmoid_With__Regularization_Or_Dropout_Model/Sigmoid_With_Regularization_Or_Dropout_Model(FootBall Problem)/Gradient_Checker_With_Regularization_Or_Dropout.py:50: RuntimeWarning: divide by zero encountered in log
#   J = -(1/m)*np.nansum((np.multiply(Y, np.log(AL)) + np.multiply((1 - Y), np.log(1 - AL))))
# /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Sigmoid_With__Regularization_Or_Dropout_Model/Sigmoid_With_Regularization_Or_Dropout_Model(FootBall Problem)/Gradient_Checker_With_Regularization_Or_Dropout.py:50: RuntimeWarning: invalid value encountered in multiply
#   J = -(1/m)*np.nansum((np.multiply(Y, np.log(AL)) + np.multiply((1 - Y), np.log(1 - AL))))
# gradient using grad checker is[9.4869208e-07]
# gradient using back prop is[9.48691109e-07]
# gradient using grad checker is[-3.19195625e-07]
# gradient using back prop is[-3.19192934e-07]
# gradient using grad checker is[-0.0001632]
# gradient using back prop is[-0.0001632]
# gradient using grad checker is[6.36322267e-05]
# gradient using back prop is[6.36322413e-05]
# gradient using grad checker is[-7.31754479e-05]
# gradient using back prop is[-7.31754521e-05]
# gradient using grad checker is[-3.93471367e-05]
# gradient using back prop is[-3.93471455e-05]
# gradient using grad checker is[1.67084315e-05]
# gradient using back prop is[1.67084371e-05]
# gradient using grad checker is[-5.57976386e-05]
# gradient using back prop is[-5.57976683e-05]
# gradient using grad checker is[0.00029601]
# gradient using back prop is[0.00029601]
# gradient using grad checker is[-5.57000366e-05]
# gradient using back prop is[-5.57000247e-05]
# gradient using grad checker is[9.94356615e-05]
# gradient using back prop is[9.94356582e-05]
# gradient using grad checker is[-6.72891907e-05]
# gradient using back prop is[-6.72891838e-05]
# gradient using grad checker is[7.53906486e-05]
# gradient using back prop is[7.53906368e-05]
# gradient using grad checker is[-0.00010653]
# gradient using back prop is[-0.00010653]
# gradient using grad checker is[-2.41360903e-05]
# gradient using back prop is[-2.41360823e-05]
# gradient using grad checker is[7.34325643e-05]
# gradient using back prop is[7.34325625e-05]
# gradient using grad checker is[-2.78091135e-06]
# gradient using back prop is[-2.78090969e-06]
# gradient using grad checker is[-3.10598249e-05]
# gradient using back prop is[-3.10598071e-05]
# gradient using grad checker is[1.74216631e-05]
# gradient using back prop is[1.74216447e-05]
# gradient using grad checker is[-7.53741253e-05]
# gradient using back prop is[-7.53741399e-05]
# gradient using grad checker is[9.33232354e-05]
# gradient using back prop is[9.3323241e-05]
# gradient using grad checker is[5.45801772e-05]
# gradient using back prop is[5.45801593e-05]
# gradient using grad checker is[-1.24322883e-05]
# gradient using back prop is[-1.24322892e-05]
# gradient using grad checker is[-8.15566451e-05]
# gradient using back prop is[-8.15566763e-05]
# gradient using grad checker is[0.00016891]
# gradient using back prop is[0.00016891]
# gradient using grad checker is[-4.77511086e-05]
# gradient using back prop is[-4.77510988e-05]
# gradient using grad checker is[3.01394825e-05]
# gradient using back prop is[3.01394659e-05]
# gradient using grad checker is[-0.00017474]
# gradient using back prop is[-0.00017474]
# gradient using grad checker is[4.19641947e-05]
# gradient using back prop is[4.19642036e-05]
# gradient using grad checker is[2.15491102e-05]
# gradient using back prop is[2.15491213e-05]
# gradient using grad checker is[2.64512327e-05]
# gradient using back prop is[2.64512355e-05]
# gradient using grad checker is[5.09775859e-05]
# gradient using back prop is[5.09775831e-05]
# gradient using grad checker is[-4.31360676e-07]
# gradient using back prop is[-4.31355991e-07]
# gradient using grad checker is[5.0017282e-07]
# gradient using back prop is[5.00176776e-07]
# gradient using grad checker is[2.33635832e-05]
# gradient using back prop is[2.33635624e-05]
# gradient using grad checker is[2.98420164e-05]
# gradient using back prop is[2.98420374e-05]
# gradient using grad checker is[-4.56774375e-08]
# gradient using back prop is[-4.56775235e-08]
# gradient using grad checker is[-4.00395862e-08]
# gradient using back prop is[-4.00449693e-08]
# gradient using grad checker is[-6.74326719e-05]
# gradient using back prop is[-6.74326846e-05]
# gradient using grad checker is[-2.00130667e-05]
# gradient using back prop is[-2.00130659e-05]
# gradient using grad checker is[6.65084893e-05]
# gradient using back prop is[6.65084978e-05]
# gradient using grad checker is[-2.45447109e-05]
# gradient using back prop is[-2.45446898e-05]
# gradient using grad checker is[-4.01781386e-05]
# gradient using back prop is[-4.01781314e-05]
# gradient using grad checker is[-1.05657453e-05]
# gradient using back prop is[-1.05657484e-05]
# gradient using grad checker is[9.92918118e-05]
# gradient using back prop is[9.9291797e-05]
# gradient using grad checker is[2.03932943e-05]
# gradient using back prop is[2.03932551e-05]
# gradient using grad checker is[9.90437832e-05]
# gradient using back prop is[9.90437772e-05]
# gradient using grad checker is[-2.28313657e-05]
# gradient using back prop is[-2.28313482e-05]
# gradient using grad checker is[8.1811077e-05]
# gradient using back prop is[8.1811072e-05]
# gradient using grad checker is[2.5148464e-05]
# gradient using back prop is[2.51484775e-05]
# gradient using grad checker is[7.93361449e-05]
# gradient using back prop is[7.93361574e-05]
# gradient using grad checker is[-2.15999961e-05]
# gradient using back prop is[-2.15999942e-05]
# gradient using grad checker is[8.121003e-05]
# gradient using back prop is[8.12100199e-05]
# gradient using grad checker is[-6.68624314e-05]
# gradient using back prop is[-6.68624035e-05]
# gradient using grad checker is[0.00019885]
# gradient using back prop is[0.00019885]
# gradient using grad checker is[0.00012304]
# gradient using back prop is[0.00012304]
# gradient using grad checker is[-3.00667412e-05]
# gradient using back prop is[-3.00667457e-05]
# gradient using grad checker is[0.00011596]
# gradient using back prop is[0.00011596]
# gradient using grad checker is[2.08078303e-05]
# gradient using back prop is[2.08078287e-05]
# gradient using grad checker is[9.49627096e-06]
# gradient using back prop is[9.49628051e-06]
# gradient using grad checker is[4.74524196e-05]
# gradient using back prop is[4.74524307e-05]
# gradient using grad checker is[-0.00017885]
# gradient using back prop is[-0.00017885]
# gradient using grad checker is[-0.00029175]
# gradient using back prop is[-0.00029175]
# gradient using grad checker is[-5.28273584e-05]
# gradient using back prop is[-5.28273444e-05]
# gradient using grad checker is[-0.00013926]
# gradient using back prop is[-0.00013926]
# gradient using grad checker is[1.66319064e-05]
# gradient using back prop is[1.66319073e-05]
# gradient using grad checker is[0.00010678]
# gradient using back prop is[0.00010678]
# gradient using grad checker is[0.00013455]
# gradient using back prop is[0.00013455]
# gradient using grad checker is[3.01600867e-05]
# gradient using back prop is[3.0160061e-05]
# gradient using grad checker is[5.34168825e-05]
# gradient using back prop is[5.34168631e-05]
# gradient using grad checker is[0.00011125]
# gradient using back prop is[0.00011125]
# gradient using grad checker is[0.00025742]
# gradient using back prop is[0.00025742]
# gradient using grad checker is[1.4609299e-06]
# gradient using back prop is[1.46092767e-06]
# gradient using grad checker is[6.9142218e-06]
# gradient using back prop is[6.91420177e-06]
# gradient using grad checker is[0.00010738]
# gradient using back prop is[0.00010738]
# gradient using grad checker is[4.14686167e-05]
# gradient using back prop is[4.14686125e-05]
# gradient using grad checker is[9.52525667e-05]
# gradient using back prop is[9.52525573e-05]
# gradient using grad checker is[0.00024231]
# gradient using back prop is[0.00024231]
# gradient using grad checker is[0.0001224]
# gradient using back prop is[0.0001224]
# gradient using grad checker is[-0.00014174]
# gradient using back prop is[-0.00014174]
# gradient using grad checker is[4.10291592e-06]
# gradient using back prop is[4.1029181e-06]
# gradient using grad checker is[-0.00038942]
# gradient using back prop is[-0.00038942]
# gradient using grad checker is[-0.00030242]
# gradient using back prop is[-0.00030242]
# gradient using grad checker is[-0.00018424]
# gradient using back prop is[-0.00018424]
# gradient using grad checker is[-7.95565003e-06]
# gradient using back prop is[-7.9556901e-06]
# gradient using grad checker is[0.00034346]
# gradient using back prop is[0.00034346]
# gradient using grad checker is[-0.00050844]
# gradient using back prop is[-0.00050844]
# gradient using grad checker is[-0.00014462]
# gradient using back prop is[-0.00014462]
# gradient using grad checker is[-0.00021364]
# gradient using back prop is[-0.00021364]
# gradient using grad checker is[-2.04389869e-05]
# gradient using back prop is[-2.04389701e-05]
# gradient using grad checker is[-0.00015315]
# gradient using back prop is[-0.00015315]
# gradient using grad checker is[6.80856153e-05]
# gradient using back prop is[6.80856171e-05]
# gradient using grad checker is[-4.36709696e-05]
# gradient using back prop is[-4.36709939e-05]
# gradient using grad checker is[-0.00022563]
# gradient using back prop is[-0.00022563]
# gradient using grad checker is[-0.0001138]
# gradient using back prop is[-0.0001138]
# gradient using grad checker is[-3.64211699e-07]
# gradient using back prop is[-3.64190554e-07]
# gradient using grad checker is[-1.73092877e-06]
# gradient using back prop is[-1.73092633e-06]
# gradient using grad checker is[-0.00018065]
# gradient using back prop is[-0.00018065]
# gradient using grad checker is[1.85303162e-07]
# gradient using back prop is[1.85300891e-07]
# gradient using grad checker is[-0.00049628]
# gradient using back prop is[-0.00049628]
# gradient using grad checker is[-0.00017635]
# gradient using back prop is[-0.00017635]
# gradient using grad checker is[-0.0001568]
# gradient using back prop is[-0.0001568]
# gradient using grad checker is[-0.00030174]
# gradient using back prop is[-0.00030174]
# gradient using grad checker is[-9.31179504e-05]
# gradient using back prop is[-9.31179617e-05]
# gradient using grad checker is[-0.00022817]
# gradient using back prop is[-0.00022817]
# gradient using grad checker is[-1.6843187e-05]
# gradient using back prop is[-1.68431856e-05]
# gradient using grad checker is[2.81551713e-05]
# gradient using back prop is[2.81551676e-05]
# gradient using grad checker is[-0.00015858]
# gradient using back prop is[-0.00015858]
# gradient using grad checker is[-0.00042108]
# gradient using back prop is[-0.00042108]
# gradient using grad checker is[0.0001747]
# gradient using back prop is[0.0001747]
# gradient using grad checker is[-0.00031065]
# gradient using back prop is[-0.00031065]
# gradient using grad checker is[-0.00038281]
# gradient using back prop is[-0.00038281]
# gradient using grad checker is[-0.00043088]
# gradient using back prop is[-0.00043088]
# gradient using grad checker is[-0.00021746]
# gradient using back prop is[-0.00021746]
# gradient using grad checker is[-0.00028802]
# gradient using back prop is[-0.00028802]
# gradient using grad checker is[-4.88047081e-05]
# gradient using back prop is[-4.88047277e-05]
# gradient using grad checker is[-0.00024088]
# gradient using back prop is[-0.00024088]
# gradient using grad checker is[3.83982234e-05]
# gradient using back prop is[3.83982275e-05]
# gradient using grad checker is[-0.0001053]
# gradient using back prop is[-0.0001053]
# gradient using grad checker is[-4.1572891e-05]
# gradient using back prop is[-4.1572858e-05]
# gradient using grad checker is[-7.74987713e-08]
# gradient using back prop is[-7.7499405e-08]
# gradient using grad checker is[-0.00010968]
# gradient using back prop is[-0.00010968]
# gradient using grad checker is[-6.43042954e-05]
# gradient using back prop is[-6.43043027e-05]
# gradient using grad checker is[0.00012087]
# gradient using back prop is[0.00012087]
# gradient using grad checker is[0.00014141]
# gradient using back prop is[0.00014141]
# gradient using grad checker is[-1.557142e-06]
# gradient using back prop is[-1.55715155e-06]
# gradient using grad checker is[0.00025683]
# gradient using back prop is[0.00025683]
# gradient using grad checker is[1.65688687e-05]
# gradient using back prop is[1.65688766e-05]
# gradient using grad checker is[-5.281082e-05]
# gradient using back prop is[-5.28108202e-05]
# gradient using grad checker is[1.21816858e-05]
# gradient using back prop is[1.21816985e-05]
# gradient using grad checker is[9.3243681e-05]
# gradient using back prop is[9.32436805e-05]
# gradient using grad checker is[3.3415961e-05]
# gradient using back prop is[3.34159616e-05]
# gradient using grad checker is[0.00012649]
# gradient using back prop is[0.00012649]
# gradient using grad checker is[0.00015135]
# gradient using back prop is[0.00015135]
# gradient using grad checker is[3.31423886e-05]
# gradient using back prop is[3.31423784e-05]
# gradient using grad checker is[-1.03825867e-05]
# gradient using back prop is[-1.03825877e-05]
# gradient using grad checker is[-5.80611947e-08]
# gradient using back prop is[-5.80590863e-08]
# gradient using grad checker is[8.11479356e-06]
# gradient using back prop is[8.11477881e-06]
# gradient using grad checker is[-4.63041064e-08]
# gradient using back prop is[-4.63005747e-08]
# gradient using grad checker is[4.91364198e-05]
# gradient using back prop is[4.91364275e-05]
# gradient using grad checker is[-2.03464936e-05]
# gradient using back prop is[-2.03464859e-05]
# gradient using grad checker is[-5.37265046e-05]
# gradient using back prop is[-5.3726501e-05]
# gradient using grad checker is[6.09396995e-05]
# gradient using back prop is[6.09396874e-05]
# gradient using grad checker is[4.36342824e-05]
# gradient using back prop is[4.36342711e-05]
# gradient using grad checker is[0.00013232]
# gradient using back prop is[0.00013232]
# gradient using grad checker is[0.00011132]
# gradient using back prop is[0.00011132]
# gradient using grad checker is[1.58512201e-05]
# gradient using back prop is[1.58512346e-05]
# gradient using grad checker is[4.31307334e-05]
# gradient using back prop is[4.31307467e-05]
# gradient using grad checker is[-3.51156886e-05]
# gradient using back prop is[-3.51156924e-05]
# gradient using grad checker is[1.109669e-05]
# gradient using back prop is[1.1096687e-05]
# gradient using grad checker is[-9.81723383e-06]
# gradient using back prop is[-9.81722943e-06]
# gradient using grad checker is[-0.00014198]
# gradient using back prop is[-0.00014198]
# gradient using grad checker is[-7.20781074e-06]
# gradient using back prop is[-7.20780671e-06]
# gradient using grad checker is[8.2657377e-05]
# gradient using back prop is[8.26573682e-05]
# gradient using grad checker is[-7.57315955e-05]
# gradient using back prop is[-7.57316146e-05]
# gradient using grad checker is[-9.63339217e-06]
# gradient using back prop is[-9.63339786e-06]
# gradient using grad checker is[3.74767166e-05]
# gradient using back prop is[3.74767083e-05]
# gradient using grad checker is[5.69852325e-07]
# gradient using back prop is[5.69858168e-07]
# gradient using grad checker is[-0.00018069]
# gradient using back prop is[-0.00018069]
# gradient using grad checker is[1.42013593e-05]
# gradient using back prop is[1.42013523e-05]
# gradient using grad checker is[-4.67985026e-08]
# gradient using back prop is[-4.67947845e-08]
# gradient using grad checker is[1.89641705e-06]
# gradient using back prop is[1.89642428e-06]
# gradient using grad checker is[-9.80982201e-05]
# gradient using back prop is[-9.80982217e-05]
# gradient using grad checker is[-0.00026659]
# gradient using back prop is[-0.00026659]
# gradient using grad checker is[3.65042935e-05]
# gradient using back prop is[3.65042832e-05]
# gradient using grad checker is[-5.79580763e-05]
# gradient using back prop is[-5.79580929e-05]
# gradient using grad checker is[-0.0001891]
# gradient using back prop is[-0.0001891]
# gradient using grad checker is[-4.08875928e-05]
# gradient using back prop is[-4.08875967e-05]
# gradient using grad checker is[4.9462409e-06]
# gradient using back prop is[4.94624927e-06]
# gradient using grad checker is[-2.23215652e-05]
# gradient using back prop is[-2.23215634e-05]
# gradient using grad checker is[-8.96916959e-05]
# gradient using back prop is[-8.969171e-05]
# gradient using grad checker is[3.29400027e-05]
# gradient using back prop is[3.29399952e-05]
# gradient using grad checker is[-0.00012562]
# gradient using back prop is[-0.00012562]
# gradient using grad checker is[0.00011]
# gradient using back prop is[0.00011]
# gradient using grad checker is[3.63395143e-05]
# gradient using back prop is[3.63395056e-05]
# gradient using grad checker is[-2.66879964e-05]
# gradient using back prop is[-2.66880016e-05]
# gradient using grad checker is[-3.06904025e-06]
# gradient using back prop is[-3.06904263e-06]
# gradient using grad checker is[-2.21613179e-05]
# gradient using back prop is[-2.21613332e-05]
# gradient using grad checker is[-1.24652892e-07]
# gradient using back prop is[-1.24649553e-07]
# gradient using grad checker is[-0.00010999]
# gradient using back prop is[-0.00010999]
# gradient using grad checker is[-5.81751943e-05]
# gradient using back prop is[-5.81751857e-05]
# gradient using grad checker is[4.10288036e-05]
# gradient using back prop is[4.10287935e-05]
# gradient using grad checker is[-0.00010111]
# gradient using back prop is[-0.00010111]
# gradient using grad checker is[-0.00017313]
# gradient using back prop is[-0.00017313]
# gradient using grad checker is[6.05268873e-06]
# gradient using back prop is[6.05267704e-06]
# gradient using grad checker is[8.47415042e-05]
# gradient using back prop is[8.47415039e-05]
# gradient using grad checker is[1.49959906e-05]
# gradient using back prop is[1.49959805e-05]
# gradient using grad checker is[-3.08849799e-05]
# gradient using back prop is[-3.08849891e-05]
# gradient using grad checker is[-0.00010896]
# gradient using back prop is[-0.00010896]
# gradient using grad checker is[2.45306683e-05]
# gradient using back prop is[2.45306683e-05]
# gradient using grad checker is[-0.00012526]
# gradient using back prop is[-0.00012526]
# gradient using grad checker is[-0.0001212]
# gradient using back prop is[-0.0001212]
# gradient using grad checker is[-0.00028976]
# gradient using back prop is[-0.00028976]
# gradient using grad checker is[-0.00020627]
# gradient using back prop is[-0.00020627]
# gradient using grad checker is[-1.83929109e-05]
# gradient using back prop is[-1.83929334e-05]
# gradient using grad checker is[-0.00017307]
# gradient using back prop is[-0.00017307]
# gradient using grad checker is[-9.13124394e-06]
# gradient using back prop is[-9.1312294e-06]
# gradient using grad checker is[9.57234509e-06]
# gradient using back prop is[9.57234702e-06]
# gradient using grad checker is[-6.36734198e-05]
# gradient using back prop is[-6.36734165e-05]
# gradient using grad checker is[4.93023461e-05]
# gradient using back prop is[4.93023382e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[3.29940003e-05]
# gradient using back prop is[3.29939927e-05]
# gradient using grad checker is[7.16535555e-06]
# gradient using back prop is[7.165357e-06]
# gradient using grad checker is[6.67674249e-06]
# gradient using back prop is[6.6767398e-06]
# gradient using grad checker is[-1.8086691e-05]
# gradient using back prop is[-1.80867187e-05]
# gradient using grad checker is[5.84923819e-06]
# gradient using back prop is[5.84924701e-06]
# gradient using grad checker is[-5.02832585e-06]
# gradient using back prop is[-5.02833573e-06]
# gradient using grad checker is[3.36641956e-06]
# gradient using back prop is[3.36641977e-06]
# gradient using grad checker is[3.13511196e-05]
# gradient using back prop is[3.13511161e-05]
# gradient using grad checker is[-1.62876873e-06]
# gradient using back prop is[-1.62875772e-06]
# gradient using grad checker is[-1.78869267e-05]
# gradient using back prop is[-1.78869357e-05]
# gradient using grad checker is[1.09843059e-05]
# gradient using back prop is[1.09843019e-05]
# gradient using grad checker is[-1.15558604e-05]
# gradient using back prop is[-1.1555857e-05]
# gradient using grad checker is[2.2946959e-05]
# gradient using back prop is[2.29469632e-05]
# gradient using grad checker is[-3.68421006e-06]
# gradient using back prop is[-3.68420914e-06]
# gradient using grad checker is[7.29371424e-06]
# gradient using back prop is[7.29371254e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-9.00568032e-06]
# gradient using back prop is[-9.00568753e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[3.54258073e-05]
# gradient using back prop is[3.54258167e-05]
# gradient using grad checker is[-2.46886582e-05]
# gradient using back prop is[-2.46886664e-05]
# gradient using grad checker is[5.6348589e-07]
# gradient using back prop is[5.63486944e-07]
# gradient using grad checker is[-5.44203137e-06]
# gradient using back prop is[-5.4420317e-06]
# gradient using grad checker is[1.46566136e-06]
# gradient using back prop is[1.46565498e-06]
# gradient using grad checker is[5.80848087e-05]
# gradient using back prop is[5.80848054e-05]
# gradient using grad checker is[2.3177185e-06]
# gradient using back prop is[2.31770588e-06]
# gradient using grad checker is[-4.72063144e-06]
# gradient using back prop is[-4.72063206e-06]
# gradient using grad checker is[-3.84775545e-05]
# gradient using back prop is[-3.84775528e-05]
# gradient using grad checker is[2.66741685e-05]
# gradient using back prop is[2.6674161e-05]
# gradient using grad checker is[2.06911029e-05]
# gradient using back prop is[2.06911018e-05]
# gradient using grad checker is[2.17702592e-06]
# gradient using back prop is[2.17700772e-06]
# gradient using grad checker is[-5.96742274e-06]
# gradient using back prop is[-5.96742668e-06]
# gradient using grad checker is[5.63901833e-05]
# gradient using back prop is[5.63901789e-05]
# gradient using grad checker is[1.53297795e-05]
# gradient using back prop is[1.5329785e-05]
# gradient using grad checker is[-3.75350358e-06]
# gradient using back prop is[-3.75350644e-06]
# gradient using grad checker is[5.89730023e-05]
# gradient using back prop is[5.89729986e-05]
# gradient using grad checker is[1.17727182e-05]
# gradient using back prop is[1.17727124e-05]
# gradient using grad checker is[-8.21938871e-06]
# gradient using back prop is[-8.2193864e-06]
# gradient using grad checker is[-2.35186436e-06]
# gradient using back prop is[-2.35187375e-06]
# gradient using grad checker is[-1.31881767e-05]
# gradient using back prop is[-1.31881789e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[6.12595695e-06]
# gradient using back prop is[6.12595239e-06]
# gradient using grad checker is[3.58651043e-06]
# gradient using back prop is[3.58649927e-06]
# gradient using grad checker is[-0.000141]
# gradient using back prop is[-0.000141]
# gradient using grad checker is[-5.61679587e-05]
# gradient using back prop is[-5.616795e-05]
# gradient using grad checker is[-1.84380007e-05]
# gradient using back prop is[-1.84379966e-05]
# gradient using grad checker is[-6.57725935e-05]
# gradient using back prop is[-6.57725884e-05]
# gradient using grad checker is[5.08736499e-06]
# gradient using back prop is[5.08735051e-06]
# gradient using grad checker is[4.99093518e-05]
# gradient using back prop is[4.9909356e-05]
# gradient using grad checker is[-5.94684892e-06]
# gradient using back prop is[-5.94683583e-06]
# gradient using grad checker is[-1.10301915e-05]
# gradient using back prop is[-1.10301838e-05]
# gradient using grad checker is[-5.52382575e-06]
# gradient using back prop is[-5.5238133e-06]
# gradient using grad checker is[-8.48389197e-05]
# gradient using back prop is[-8.48389113e-05]
# gradient using grad checker is[9.59047295e-06]
# gradient using back prop is[9.59046248e-06]
# gradient using grad checker is[-9.28739507e-06]
# gradient using back prop is[-9.28738403e-06]
# gradient using grad checker is[1.07570745e-05]
# gradient using back prop is[1.07570745e-05]
# gradient using grad checker is[1.49684952e-08]
# gradient using back prop is[1.49688319e-08]
# gradient using grad checker is[-3.13147511e-06]
# gradient using back prop is[-3.13146898e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[3.13979116e-05]
# gradient using back prop is[3.13979215e-05]
# gradient using grad checker is[2.12034296e-05]
# gradient using back prop is[2.1203412e-05]
# gradient using grad checker is[1.41532619e-06]
# gradient using back prop is[1.41532359e-06]
# gradient using grad checker is[-5.09052219e-06]
# gradient using back prop is[-5.09050116e-06]
# gradient using grad checker is[-2.67989667e-05]
# gradient using back prop is[-2.67989648e-05]
# gradient using grad checker is[-0.00010619]
# gradient using back prop is[-0.00010619]
# gradient using grad checker is[1.43860358e-05]
# gradient using back prop is[1.43860472e-05]
# gradient using grad checker is[-6.55619439e-06]
# gradient using back prop is[-6.55617814e-06]
# gradient using grad checker is[7.68666381e-05]
# gradient using back prop is[7.68666371e-05]
# gradient using grad checker is[-6.11817021e-06]
# gradient using back prop is[-6.11816286e-06]
# gradient using grad checker is[-3.56467742e-05]
# gradient using back prop is[-3.56467734e-05]
# gradient using grad checker is[9.21241252e-05]
# gradient using back prop is[9.21241395e-05]
# gradient using grad checker is[-1.07164841e-05]
# gradient using back prop is[-1.07164888e-05]
# gradient using grad checker is[-3.36778869e-05]
# gradient using back prop is[-3.36778862e-05]
# gradient using grad checker is[-6.55873468e-05]
# gradient using back prop is[-6.55873437e-05]
# gradient using grad checker is[9.81510229e-06]
# gradient using back prop is[9.81509377e-06]
# gradient using grad checker is[3.14586703e-05]
# gradient using back prop is[3.14586797e-05]
# gradient using grad checker is[-2.70783439e-05]
# gradient using back prop is[-2.70783438e-05]
# gradient using grad checker is[-1.86233082e-05]
# gradient using back prop is[-1.86232972e-05]
# gradient using grad checker is[3.21082961e-05]
# gradient using back prop is[3.21082911e-05]
# gradient using grad checker is[-1.4137426e-05]
# gradient using back prop is[-1.41374171e-05]
# gradient using grad checker is[-2.16840434e-12]
# gradient using back prop is[-2.39414297e-12]
# gradient using grad checker is[8.09885796e-05]
# gradient using back prop is[8.09885746e-05]
# gradient using grad checker is[8.60204139e-05]
# gradient using back prop is[8.60204135e-05]
# gradient using grad checker is[8.13414397e-05]
# gradient using back prop is[8.13414742e-05]
# gradient using grad checker is[7.45166515e-05]
# gradient using back prop is[7.45166572e-05]
# gradient using grad checker is[-1.82767213e-06]
# gradient using back prop is[-1.82767472e-06]
# gradient using grad checker is[5.8030707e-06]
# gradient using back prop is[5.80305918e-06]
# gradient using grad checker is[-1.46404026e-05]
# gradient using back prop is[-1.46403975e-05]
# gradient using grad checker is[1.90998823e-05]
# gradient using back prop is[1.90998837e-05]
# gradient using grad checker is[3.16027087e-05]
# gradient using back prop is[3.16027021e-05]
# gradient using grad checker is[-4.38186076e-05]
# gradient using back prop is[-4.38185976e-05]
# gradient using grad checker is[8.4629569e-07]
# gradient using back prop is[8.46301784e-07]
# gradient using grad checker is[6.58756903e-07]
# gradient using back prop is[6.58762221e-07]
# gradient using grad checker is[0.00014183]
# gradient using back prop is[0.00014183]
# gradient using grad checker is[1.99308387e-05]
# gradient using back prop is[1.9930826e-05]
# gradient using grad checker is[-1.53157717e-05]
# gradient using back prop is[-1.53157722e-05]
# gradient using grad checker is[-1.5514868e-06]
# gradient using back prop is[-1.55148156e-06]
# gradient using grad checker is[1.50037795e-05]
# gradient using back prop is[1.50037857e-05]
# gradient using grad checker is[-4.61826757e-08]
# gradient using back prop is[-4.61833044e-08]
# gradient using grad checker is[5.85941408e-05]
# gradient using back prop is[5.85941401e-05]
# gradient using grad checker is[3.43916367e-05]
# gradient using back prop is[3.43916215e-05]
# gradient using grad checker is[2.96697974e-05]
# gradient using back prop is[2.96697946e-05]
# gradient using grad checker is[2.99248755e-05]
# gradient using back prop is[2.99248689e-05]
# gradient using grad checker is[-5.68237688e-05]
# gradient using back prop is[-5.68237681e-05]
# gradient using grad checker is[-2.83785582e-07]
# gradient using back prop is[-2.83784142e-07]
# gradient using grad checker is[-3.87991961e-05]
# gradient using back prop is[-3.87991936e-05]
# gradient using grad checker is[1.86226186e-05]
# gradient using back prop is[1.86226188e-05]
# gradient using grad checker is[6.72003338e-05]
# gradient using back prop is[6.72003307e-05]
# gradient using grad checker is[0.00017728]
# gradient using back prop is[0.00017728]
# gradient using grad checker is[-1.44191516e-06]
# gradient using back prop is[-1.44191929e-06]
# gradient using grad checker is[4.38436223e-05]
# gradient using back prop is[4.38436161e-05]
# gradient using grad checker is[0.00018544]
# gradient using back prop is[0.00018544]
# gradient using grad checker is[-2.78510678e-05]
# gradient using back prop is[-2.78510627e-05]
# gradient using grad checker is[-8.56332821e-05]
# gradient using back prop is[-8.56332743e-05]
# gradient using grad checker is[2.88587622e-05]
# gradient using back prop is[2.88587649e-05]
# gradient using grad checker is[-0.0001023]
# gradient using back prop is[-0.0001023]
# gradient using grad checker is[-1.12818587e-05]
# gradient using back prop is[-1.1281871e-05]
# gradient using grad checker is[6.81449688e-06]
# gradient using back prop is[6.81448737e-06]
# gradient using grad checker is[-7.60365208e-05]
# gradient using back prop is[-7.6036519e-05]
# gradient using grad checker is[3.29652885e-05]
# gradient using back prop is[3.29652684e-05]
# gradient using grad checker is[-2.33645568e-08]
# gradient using back prop is[-2.336289e-08]
# gradient using grad checker is[-0.00025124]
# gradient using back prop is[-0.00025124]
# gradient using grad checker is[-9.1976691e-05]
# gradient using back prop is[-9.19766938e-05]
# gradient using grad checker is[-7.89887188e-05]
# gradient using back prop is[-7.89887211e-05]
# gradient using grad checker is[3.92783419e-05]
# gradient using back prop is[3.92783347e-05]
# gradient using grad checker is[-2.98958839e-05]
# gradient using back prop is[-2.98958875e-05]
# gradient using grad checker is[5.03234759e-05]
# gradient using back prop is[5.03234859e-05]
# gradient using grad checker is[-3.70625731e-05]
# gradient using back prop is[-3.70625713e-05]
# gradient using grad checker is[-0.00013208]
# gradient using back prop is[-0.00013208]
# gradient using grad checker is[-5.89884912e-06]
# gradient using back prop is[-5.8988552e-06]
# gradient using grad checker is[-3.11023559e-06]
# gradient using back prop is[-3.11024605e-06]
# gradient using grad checker is[1.31666076e-05]
# gradient using back prop is[1.31666e-05]
# gradient using grad checker is[4.72178937e-06]
# gradient using back prop is[4.72177289e-06]
# gradient using grad checker is[2.01337471e-05]
# gradient using back prop is[2.01337417e-05]
# gradient using grad checker is[2.27492396e-05]
# gradient using back prop is[2.27492239e-05]
# gradient using grad checker is[-2.01469418e-05]
# gradient using back prop is[-2.01469495e-05]
# gradient using grad checker is[-4.02984937e-07]
# gradient using back prop is[-4.0298113e-07]
# gradient using grad checker is[-4.87658438e-05]
# gradient using back prop is[-4.87658335e-05]
# gradient using grad checker is[-1.00204133e-07]
# gradient using back prop is[-1.00203145e-07]
# gradient using grad checker is[-0.00013729]
# gradient using back prop is[-0.00013729]
# gradient using grad checker is[-3.56984386e-05]
# gradient using back prop is[-3.56984159e-05]
# gradient using grad checker is[-2.11171011e-05]
# gradient using back prop is[-2.11170964e-05]
# gradient using grad checker is[-4.50541362e-05]
# gradient using back prop is[-4.505415e-05]
# gradient using grad checker is[-2.74889443e-05]
# gradient using back prop is[-2.74889393e-05]
# gradient using grad checker is[-2.1334887e-06]
# gradient using back prop is[-2.13348735e-06]
# gradient using grad checker is[-2.99458115e-05]
# gradient using back prop is[-2.9945815e-05]
# gradient using grad checker is[2.48753709e-06]
# gradient using back prop is[2.4875382e-06]
# gradient using grad checker is[-0.00014425]
# gradient using back prop is[-0.00014425]
# gradient using grad checker is[-3.53762592e-06]
# gradient using back prop is[-3.53763636e-06]
# gradient using grad checker is[5.8598959e-06]
# gradient using back prop is[5.85989562e-06]
# gradient using grad checker is[-0.00010132]
# gradient using back prop is[-0.00010132]
# gradient using grad checker is[-0.00020624]
# gradient using back prop is[-0.00020624]
# gradient using grad checker is[-8.53357033e-05]
# gradient using back prop is[-8.53357145e-05]
# gradient using grad checker is[1.03806286e-06]
# gradient using back prop is[1.0380748e-06]
# gradient using grad checker is[1.56304397e-05]
# gradient using back prop is[1.56304391e-05]
# gradient using grad checker is[-0.00015682]
# gradient using back prop is[-0.00015682]
# gradient using grad checker is[1.74751468e-05]
# gradient using back prop is[1.74751574e-05]
# gradient using grad checker is[-1.40979958e-05]
# gradient using back prop is[-1.40979903e-05]
# gradient using grad checker is[-6.74384745e-05]
# gradient using back prop is[-6.74384648e-05]
# gradient using grad checker is[1.47354698e-05]
# gradient using back prop is[1.47354764e-05]
# gradient using grad checker is[6.42498207e-09]
# gradient using back prop is[6.42534472e-09]
# gradient using grad checker is[-2.02359483e-05]
# gradient using back prop is[-2.02359461e-05]
# gradient using grad checker is[-3.00974523e-08]
# gradient using back prop is[-3.00924339e-08]
# gradient using grad checker is[-6.33909591e-06]
# gradient using back prop is[-6.33909773e-06]
# gradient using grad checker is[-6.87524256e-06]
# gradient using back prop is[-6.87522689e-06]
# gradient using grad checker is[-2.95573028e-07]
# gradient using back prop is[-2.95570196e-07]
# gradient using grad checker is[9.66538698e-06]
# gradient using back prop is[9.66538618e-06]
# gradient using grad checker is[-4.3160614e-06]
# gradient using back prop is[-4.31606827e-06]
# gradient using grad checker is[-3.72410002e-06]
# gradient using back prop is[-3.7241031e-06]
# gradient using grad checker is[-2.59211055e-07]
# gradient using back prop is[-2.59205163e-07]
# gradient using grad checker is[-2.37018087e-06]
# gradient using back prop is[-2.37017881e-06]
# gradient using grad checker is[-3.73291025e-06]
# gradient using back prop is[-3.73290344e-06]
# gradient using grad checker is[-4.89976874e-05]
# gradient using back prop is[-4.89976856e-05]
# gradient using grad checker is[-1.41724675e-05]
# gradient using back prop is[-1.41724594e-05]
# gradient using grad checker is[-6.42273344e-06]
# gradient using back prop is[-6.42272488e-06]
# gradient using grad checker is[6.48467825e-07]
# gradient using back prop is[6.48466217e-07]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-2.1511677e-06]
# gradient using back prop is[-2.15115718e-06]
# gradient using grad checker is[9.39569603e-09]
# gradient using back prop is[9.39668958e-09]
# gradient using grad checker is[-6.68207677e-06]
# gradient using back prop is[-6.68207917e-06]
# gradient using grad checker is[-5.91351404e-06]
# gradient using back prop is[-5.91352361e-06]
# gradient using grad checker is[1.47791935e-07]
# gradient using back prop is[1.47792842e-07]
# gradient using grad checker is[-1.4369853e-05]
# gradient using back prop is[-1.4369848e-05]
# gradient using grad checker is[-6.54762269e-06]
# gradient using back prop is[-6.5476145e-06]
# gradient using grad checker is[9.49410038e-06]
# gradient using back prop is[9.4941025e-06]
# gradient using grad checker is[-1.69208397e-05]
# gradient using back prop is[-1.69208343e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[-3.27969529e-16]
# gradient using grad checker is[2.83911349e-06]
# gradient using back prop is[2.83911435e-06]
# gradient using grad checker is[-3.38915332e-05]
# gradient using back prop is[-3.3891531e-05]
# gradient using grad checker is[2.86236096e-06]
# gradient using back prop is[2.86236167e-06]
# gradient using grad checker is[-3.14243575e-05]
# gradient using back prop is[-3.14243556e-05]
# gradient using grad checker is[-9.86159938e-06]
# gradient using back prop is[-9.86160301e-06]
# gradient using grad checker is[3.40305041e-06]
# gradient using back prop is[3.40304711e-06]
# gradient using grad checker is[9.51418415e-06]
# gradient using back prop is[9.51418729e-06]
# gradient using grad checker is[-1.43324003e-05]
# gradient using back prop is[-1.43323993e-05]
# gradient using grad checker is[7.51685172e-06]
# gradient using back prop is[7.5168453e-06]
# gradient using grad checker is[3.09827034e-06]
# gradient using back prop is[3.09826501e-06]
# gradient using grad checker is[-3.98784521e-06]
# gradient using back prop is[-3.98783395e-06]
# gradient using grad checker is[7.23292953e-06]
# gradient using back prop is[7.23294207e-06]
# gradient using grad checker is[-9.97924399e-06]
# gradient using back prop is[-9.97924852e-06]
# gradient using grad checker is[2.99825269e-08]
# gradient using back prop is[2.99834921e-08]
# gradient using grad checker is[2.53563663e-06]
# gradient using back prop is[2.5356262e-06]
# gradient using grad checker is[-4.88417878e-05]
# gradient using back prop is[-4.88417981e-05]
# gradient using grad checker is[1.3151806e-07]
# gradient using back prop is[1.31532687e-07]
# gradient using grad checker is[-9.52093829e-05]
# gradient using back prop is[-9.52093868e-05]
# gradient using grad checker is[2.32598641e-05]
# gradient using back prop is[2.32598766e-05]
# gradient using grad checker is[-6.40494363e-05]
# gradient using back prop is[-6.40494312e-05]
# gradient using grad checker is[-7.30991439e-06]
# gradient using back prop is[-7.30990414e-06]
# gradient using grad checker is[-2.13990306e-05]
# gradient using back prop is[-2.13990368e-05]
# gradient using grad checker is[-1.34156445e-05]
# gradient using back prop is[-1.34156464e-05]
# gradient using grad checker is[-2.37478179e-05]
# gradient using back prop is[-2.37478216e-05]
# gradient using grad checker is[-2.4933122e-05]
# gradient using back prop is[-2.49331246e-05]
# gradient using grad checker is[-0.00015093]
# gradient using back prop is[-0.00015093]
# gradient using grad checker is[9.35612612e-05]
# gradient using back prop is[9.35612747e-05]
# gradient using grad checker is[1.16488156e-05]
# gradient using back prop is[1.16488267e-05]
# gradient using grad checker is[6.38122367e-07]
# gradient using back prop is[6.3812022e-07]
# gradient using grad checker is[1.98565123e-07]
# gradient using back prop is[1.98566655e-07]
# gradient using grad checker is[-2.20468088e-05]
# gradient using back prop is[-2.20467955e-05]
# gradient using grad checker is[5.25252584e-08]
# gradient using back prop is[5.25234345e-08]
# gradient using grad checker is[-4.13823273e-05]
# gradient using back prop is[-4.13823331e-05]
# gradient using grad checker is[-1.61122829e-05]
# gradient using back prop is[-1.61122809e-05]
# gradient using grad checker is[2.70003204e-06]
# gradient using back prop is[2.70002833e-06]
# gradient using grad checker is[-3.81199629e-05]
# gradient using back prop is[-3.81199517e-05]
# gradient using grad checker is[-3.14788647e-05]
# gradient using back prop is[-3.14788631e-05]
# gradient using grad checker is[-4.27049433e-05]
# gradient using back prop is[-4.27049445e-05]
# gradient using grad checker is[-3.44745218e-05]
# gradient using back prop is[-3.44745368e-05]
# gradient using grad checker is[-3.72901254e-05]
# gradient using back prop is[-3.72901214e-05]
# gradient using grad checker is[-6.00326061e-05]
# gradient using back prop is[-6.00326222e-05]
# gradient using grad checker is[4.15308933e-05]
# gradient using back prop is[4.15308989e-05]
# gradient using grad checker is[-2.02653476e-05]
# gradient using back prop is[-2.02653435e-05]
# gradient using grad checker is[-1.0980522e-05]
# gradient using back prop is[-1.09805243e-05]
# gradient using grad checker is[6.81724447e-05]
# gradient using back prop is[6.81724352e-05]
# gradient using grad checker is[3.62285072e-06]
# gradient using back prop is[3.62284145e-06]
# gradient using grad checker is[-3.65099444e-05]
# gradient using back prop is[-3.6509955e-05]
# gradient using grad checker is[-3.70292577e-05]
# gradient using back prop is[-3.70292578e-05]
# gradient using grad checker is[-2.75398519e-05]
# gradient using back prop is[-2.75398531e-05]
# gradient using grad checker is[-1.1262844e-05]
# gradient using back prop is[-1.12628448e-05]
# gradient using grad checker is[-2.15947399e-05]
# gradient using back prop is[-2.15947538e-05]
# gradient using grad checker is[-4.69315841e-05]
# gradient using back prop is[-4.69315771e-05]
# gradient using grad checker is[2.0375355e-05]
# gradient using back prop is[2.03753606e-05]
# gradient using grad checker is[-7.69002917e-08]
# gradient using back prop is[-7.69011649e-08]
# gradient using grad checker is[6.45083379e-06]
# gradient using back prop is[6.45083658e-06]
# gradient using grad checker is[-2.97280972e-05]
# gradient using back prop is[-2.97280943e-05]
# gradient using grad checker is[3.80991441e-05]
# gradient using back prop is[3.80991519e-05]
# gradient using grad checker is[0.00010504]
# gradient using back prop is[0.00010504]
# gradient using grad checker is[2.0130861e-05]
# gradient using back prop is[2.0130869e-05]
# gradient using grad checker is[0.00014458]
# gradient using back prop is[0.00014458]
# gradient using grad checker is[-1.4588053e-05]
# gradient using back prop is[-1.45880355e-05]
# gradient using grad checker is[-5.31381818e-05]
# gradient using back prop is[-5.31381934e-05]
# gradient using grad checker is[-2.61558895e-05]
# gradient using back prop is[-2.61559014e-05]
# gradient using grad checker is[-6.86634148e-05]
# gradient using back prop is[-6.86634343e-05]
# gradient using grad checker is[2.24105933e-05]
# gradient using back prop is[2.24105966e-05]
# gradient using grad checker is[0.00020493]
# gradient using back prop is[0.00020493]
# gradient using grad checker is[-0.00013481]
# gradient using back prop is[-0.00013481]
# gradient using grad checker is[2.36867232e-05]
# gradient using back prop is[2.36867046e-05]
# gradient using grad checker is[-1.82076186e-05]
# gradient using back prop is[-1.82076285e-05]
# gradient using grad checker is[-8.14626144e-08]
# gradient using back prop is[-8.14576211e-08]
# gradient using grad checker is[3.7274179e-05]
# gradient using back prop is[3.72741931e-05]
# gradient using grad checker is[-4.59441513e-08]
# gradient using back prop is[-4.59423366e-08]
# gradient using grad checker is[-4.13062228e-05]
# gradient using back prop is[-4.13062283e-05]
# gradient using grad checker is[-7.7484423e-05]
# gradient using back prop is[-7.74844459e-05]
# gradient using grad checker is[-2.11257769e-05]
# gradient using back prop is[-2.11257742e-05]
# gradient using grad checker is[-4.99221736e-05]
# gradient using back prop is[-4.99221661e-05]
# gradient using grad checker is[8.4870895e-05]
# gradient using back prop is[8.48709073e-05]
# gradient using grad checker is[0.00016131]
# gradient using back prop is[0.00016131]
# gradient using grad checker is[4.08696276e-05]
# gradient using back prop is[4.08696323e-05]
# gradient using grad checker is[3.11787336e-05]
# gradient using back prop is[3.11787284e-05]
# gradient using grad checker is[-0.00011657]
# gradient using back prop is[-0.00011657]
# gradient using grad checker is[-0.00014107]
# gradient using back prop is[-0.00014107]
# gradient using grad checker is[-9.95972402e-06]
# gradient using back prop is[-9.95973361e-06]
# gradient using grad checker is[-0.00012701]
# gradient using back prop is[-0.00012701]
# gradient using grad checker is[-0.00035249]
# gradient using back prop is[-0.00035249]
# gradient using grad checker is[-0.00012937]
# gradient using back prop is[-0.00012937]
# gradient using grad checker is[2.80662125e-05]
# gradient using back prop is[2.80661967e-05]
# gradient using grad checker is[6.96033769e-05]
# gradient using back prop is[6.96033818e-05]
# gradient using grad checker is[-4.99424612e-05]
# gradient using back prop is[-4.9942448e-05]
# gradient using grad checker is[-8.04372844e-06]
# gradient using back prop is[-8.04372028e-06]
# gradient using grad checker is[-5.61357991e-05]
# gradient using back prop is[-5.61357963e-05]
# gradient using grad checker is[-3.07335472e-05]
# gradient using back prop is[-3.07335502e-05]
# gradient using grad checker is[5.09420522e-05]
# gradient using back prop is[5.09420568e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-8.06343512e-05]
# gradient using back prop is[-8.06343319e-05]
# gradient using grad checker is[0.00012702]
# gradient using back prop is[0.00012702]
# gradient using grad checker is[5.04667055e-05]
# gradient using back prop is[5.04666991e-05]
# gradient using grad checker is[-0.00012214]
# gradient using back prop is[-0.00012214]
# gradient using grad checker is[0.00011425]
# gradient using back prop is[0.00011425]
# gradient using grad checker is[0.00022115]
# gradient using back prop is[0.00022115]
# gradient using grad checker is[4.17704716e-06]
# gradient using back prop is[4.17705616e-06]
# gradient using grad checker is[5.47295694e-05]
# gradient using back prop is[5.47295579e-05]
# gradient using grad checker is[-2.97958143e-05]
# gradient using back prop is[-2.97957921e-05]
# gradient using grad checker is[-8.7363851e-05]
# gradient using back prop is[-8.73638535e-05]
# gradient using grad checker is[-5.32949249e-05]
# gradient using back prop is[-5.32949027e-05]
# gradient using grad checker is[-3.13749135e-05]
# gradient using back prop is[-3.13749199e-05]
# gradient using grad checker is[-0.00012255]
# gradient using back prop is[-0.00012255]
# gradient using grad checker is[-2.08237789e-05]
# gradient using back prop is[-2.08237803e-05]
# gradient using grad checker is[1.74915334e-05]
# gradient using back prop is[1.74915277e-05]
# gradient using grad checker is[7.17642092e-07]
# gradient using back prop is[7.17642275e-07]
# gradient using grad checker is[-2.76220128e-05]
# gradient using back prop is[-2.76219919e-05]
# gradient using grad checker is[1.24854554e-07]
# gradient using back prop is[1.2485374e-07]
# gradient using grad checker is[-3.99606628e-05]
# gradient using back prop is[-3.99606664e-05]
# gradient using grad checker is[-5.48959337e-05]
# gradient using back prop is[-5.48959495e-05]
# gradient using grad checker is[-1.04500956e-05]
# gradient using back prop is[-1.04500914e-05]
# gradient using grad checker is[0.00013217]
# gradient using back prop is[0.00013217]
# gradient using grad checker is[-8.45154307e-05]
# gradient using back prop is[-8.45154235e-05]
# gradient using grad checker is[2.07732486e-06]
# gradient using back prop is[2.0773237e-06]
# gradient using grad checker is[-0.00012681]
# gradient using back prop is[-0.00012681]
# gradient using grad checker is[-1.13763166e-07]
# gradient using back prop is[-1.13756579e-07]
# gradient using grad checker is[2.62206879e-05]
# gradient using back prop is[2.6220682e-05]
# gradient using grad checker is[1.31431671e-05]
# gradient using back prop is[1.31431611e-05]
# gradient using grad checker is[-2.75561366e-05]
# gradient using back prop is[-2.75561345e-05]
# gradient using grad checker is[3.82812705e-05]
# gradient using back prop is[3.82812855e-05]
# gradient using grad checker is[0.00029906]
# gradient using back prop is[0.00029906]
# gradient using grad checker is[0.00013014]
# gradient using back prop is[0.00013014]
# gradient using grad checker is[-6.55245172e-05]
# gradient using back prop is[-6.55245143e-05]
# gradient using grad checker is[-6.55335898e-05]
# gradient using back prop is[-6.55336017e-05]
# gradient using grad checker is[7.79735044e-05]
# gradient using back prop is[7.79735053e-05]
# gradient using grad checker is[-2.4256608e-05]
# gradient using back prop is[-2.42565914e-05]
# gradient using grad checker is[-8.96384941e-05]
# gradient using back prop is[-8.96385072e-05]
# gradient using grad checker is[-7.0387164e-06]
# gradient using back prop is[-7.03869442e-06]
# gradient using grad checker is[-9.93685798e-05]
# gradient using back prop is[-9.93685717e-05]
# gradient using grad checker is[2.76037873e-08]
# gradient using back prop is[2.76049234e-08]
# gradient using grad checker is[5.90953805e-05]
# gradient using back prop is[5.90953838e-05]
# gradient using grad checker is[-4.07377777e-05]
# gradient using back prop is[-4.07377954e-05]
# gradient using grad checker is[-1.91809914e-05]
# gradient using back prop is[-1.91809994e-05]
# gradient using grad checker is[-0.00014718]
# ...
# gradient using grad checker is[-2.59322967e-05]
# gradient using back prop is[-2.5932294e-05]
# gradient using grad checker is[-0.00011602]
# gradient using back prop is[-0.00011602]
# gradient using grad checker is[-7.50313657e-06]
# gradient using back prop is[-7.50313574e-06]
# gradient using grad checker is[-2.62940668e-05]
# gradient using back prop is[-2.62940586e-05]
# gradient using grad checker is[1.81766668e-05]
# gradient using back prop is[1.81766586e-05]
# gradient using grad checker is[2.23276887e-05]
# gradient using back prop is[2.23276769e-05]
# gradient using grad checker is[1.64007978e-05]
# gradient using back prop is[1.64008031e-05]
# gradient using grad checker is[-7.37045299e-05]
# gradient using back prop is[-7.37045317e-05]
# gradient using grad checker is[8.32885735e-05]
# gradient using back prop is[8.32885872e-05]
# gradient using grad checker is[9.88110852e-06]
# gradient using back prop is[9.88110589e-06]
# gradient using grad checker is[-4.48056522e-05]
# gradient using back prop is[-4.48056501e-05]
# gradient using grad checker is[-2.68161795e-06]
# gradient using back prop is[-2.6816163e-06]
# gradient using grad checker is[2.86089078e-06]
# gradient using back prop is[2.86088004e-06]
# gradient using grad checker is[-1.22115859e-07]
# gradient using back prop is[-1.22115038e-07]
# gradient using grad checker is[-3.17409358e-05]
# gradient using back prop is[-3.17409404e-05]
# gradient using grad checker is[5.04861452e-05]
# gradient using back prop is[5.04861487e-05]
# gradient using grad checker is[-3.47827322e-05]
# gradient using back prop is[-3.47827315e-05]
# gradient using grad checker is[9.07065764e-05]
# gradient using back prop is[9.07065707e-05]
# gradient using grad checker is[3.13808181e-05]
# gradient using back prop is[3.13808095e-05]
# gradient using grad checker is[-6.21379619e-05]
# gradient using back prop is[-6.21379523e-05]
# gradient using grad checker is[4.6462968e-05]
# gradient using back prop is[4.64629644e-05]
# gradient using grad checker is[1.59714906e-06]
# gradient using back prop is[1.59714848e-06]
# gradient using grad checker is[0.00013332]
# gradient using back prop is[0.00013332]
# gradient using grad checker is[3.48716195e-05]
# gradient using back prop is[3.48716202e-05]
# gradient using grad checker is[-5.75849047e-06]
# gradient using back prop is[-5.75849678e-06]
# gradient using grad checker is[3.23824583e-05]
# gradient using back prop is[3.23824461e-05]
# gradient using grad checker is[1.09752788e-05]
# gradient using back prop is[1.09752811e-05]
# gradient using grad checker is[-8.62719661e-05]
# gradient using back prop is[-8.62719636e-05]
# gradient using grad checker is[-2.97288149e-05]
# gradient using back prop is[-2.97288067e-05]
# gradient using grad checker is[6.53770571e-05]
# gradient using back prop is[6.53770607e-05]
# gradient using grad checker is[-0.00014091]
# gradient using back prop is[-0.00014091]
# gradient using grad checker is[-2.47123394e-05]
# gradient using back prop is[-2.47123522e-05]
# gradient using grad checker is[8.80882715e-05]
# gradient using back prop is[8.80882775e-05]
# gradient using grad checker is[2.9827345e-05]
# gradient using back prop is[2.98273496e-05]
# gradient using grad checker is[4.72798081e-05]
# gradient using back prop is[4.72798234e-05]
# gradient using grad checker is[-1.59551192e-08]
# gradient using back prop is[-1.59525458e-08]
# gradient using grad checker is[5.29729017e-05]
# gradient using back prop is[5.2972904e-05]
# gradient using grad checker is[-3.92253482e-05]
# gradient using back prop is[-3.92253294e-05]
# gradient using grad checker is[1.48897019e-05]
# gradient using back prop is[1.48896937e-05]
# gradient using grad checker is[3.85225315e-05]
# gradient using back prop is[3.8522522e-05]
# gradient using grad checker is[-6.67149452e-05]
# gradient using back prop is[-6.67149567e-05]
# gradient using grad checker is[1.97278413e-05]
# gradient using back prop is[1.97278364e-05]
# gradient using grad checker is[1.11129638e-06]
# gradient using back prop is[1.11130231e-06]
# gradient using grad checker is[5.42023024e-07]
# gradient using back prop is[5.42046351e-07]
# gradient using grad checker is[-1.83699301e-05]
# gradient using back prop is[-1.83699317e-05]
# gradient using grad checker is[2.22177702e-05]
# gradient using back prop is[2.22177887e-05]
# gradient using grad checker is[2.32820057e-06]
# gradient using back prop is[2.32819248e-06]
# gradient using grad checker is[2.56811152e-05]
# gradient using back prop is[2.56811089e-05]
# gradient using grad checker is[-3.20155642e-05]
# gradient using back prop is[-3.20155896e-05]
# gradient using grad checker is[-1.4978498e-05]
# gradient using back prop is[-1.49784951e-05]
# gradient using grad checker is[-1.19074889e-05]
# gradient using back prop is[-1.19074887e-05]
# gradient using grad checker is[-2.78141225e-08]
# gradient using back prop is[-2.78106721e-08]
# gradient using grad checker is[2.62606278e-05]
# gradient using back prop is[2.62606153e-05]
# gradient using grad checker is[-3.97815461e-08]
# gradient using back prop is[-3.97807817e-08]
# gradient using grad checker is[7.18433776e-06]
# gradient using back prop is[7.18434595e-06]
# gradient using grad checker is[1.0932184e-06]
# gradient using back prop is[1.09319799e-06]
# gradient using grad checker is[2.45467622e-05]
# gradient using back prop is[2.45467541e-05]
# gradient using grad checker is[9.94374505e-06]
# gradient using back prop is[9.94373048e-06]
# gradient using grad checker is[-4.09907806e-05]
# gradient using back prop is[-4.09907784e-05]
# gradient using grad checker is[-8.1373081e-06]
# gradient using back prop is[-8.13731658e-06]
# gradient using grad checker is[5.41693361e-05]
# gradient using back prop is[5.41693455e-05]
# gradient using grad checker is[-8.07719343e-06]
# gradient using back prop is[-8.07720058e-06]
# gradient using grad checker is[6.20946285e-05]
# gradient using back prop is[6.20946247e-05]
# gradient using grad checker is[2.15704256e-05]
# gradient using back prop is[2.15704271e-05]
# gradient using grad checker is[-5.77683734e-06]
# gradient using back prop is[-5.77683509e-06]
# gradient using grad checker is[-2.30536337e-05]
# gradient using back prop is[-2.30536561e-05]
# gradient using grad checker is[3.56219373e-05]
# gradient using back prop is[3.56219469e-05]
# gradient using grad checker is[-8.44324827e-05]
# gradient using back prop is[-8.4432485e-05]
# gradient using grad checker is[3.02253947e-05]
# gradient using back prop is[3.0225412e-05]
# gradient using grad checker is[-6.7789177e-06]
# gradient using back prop is[-6.77890453e-06]
# gradient using grad checker is[-2.83228584e-05]
# gradient using back prop is[-2.83228549e-05]
# gradient using grad checker is[-2.44672772e-06]
# gradient using back prop is[-2.44672813e-06]
# gradient using grad checker is[1.26743277e-05]
# gradient using back prop is[1.26743304e-05]
# gradient using grad checker is[1.05705874e-05]
# gradient using back prop is[1.05705827e-05]
# gradient using grad checker is[-2.42736321e-05]
# gradient using back prop is[-2.42736384e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-4.33594133e-08]
# gradient using back prop is[-4.33744467e-08]
# gradient using grad checker is[9.89421219e-08]
# gradient using back prop is[9.89436892e-08]
# gradient using grad checker is[-1.71872065e-07]
# gradient using back prop is[-1.71863487e-07]
# gradient using grad checker is[2.25887017e-07]
# gradient using back prop is[2.2587372e-07]
# gradient using grad checker is[8.54871729e-08]
# gradient using back prop is[8.54908299e-08]
# gradient using grad checker is[-3.28970792e-07]
# gradient using back prop is[-3.28969318e-07]
# gradient using grad checker is[-6.88750272e-08]
# gradient using back prop is[-6.88804161e-08]
# gradient using grad checker is[-2.93630138e-07]
# gradient using back prop is[-2.9362973e-07]
# gradient using grad checker is[3.56268834e-09]
# gradient using back prop is[3.54798412e-09]
# gradient using grad checker is[-7.3866694e-08]
# gradient using back prop is[-7.38651296e-08]
# gradient using grad checker is[-2.03006015e-08]
# gradient using back prop is[-2.03024716e-08]
# gradient using grad checker is[-4.83261434e-07]
# gradient using back prop is[-4.83271589e-07]
# gradient using grad checker is[4.75487705e-08]
# gradient using back prop is[4.7547553e-08]
# gradient using grad checker is[1.73363927e-08]
# gradient using back prop is[1.73247397e-08]
# gradient using grad checker is[-6.02187571e-08]
# gradient using back prop is[-6.02166883e-08]
# gradient using grad checker is[-5.61616725e-09]
# gradient using back prop is[-5.61251556e-09]
# gradient using grad checker is[-1.27812257e-07]
# gradient using back prop is[-1.27799128e-07]
# gradient using grad checker is[-1.71303943e-10]
# gradient using back prop is[-1.70090527e-10]
# gradient using grad checker is[2.0518743e-07]
# gradient using back prop is[2.05175235e-07]
# gradient using grad checker is[-2.84483808e-07]
# gradient using back prop is[-2.84490419e-07]
# gradient using grad checker is[-4.83142172e-08]
# gradient using back prop is[-4.8317958e-08]
# gradient using grad checker is[-4.76760558e-07]
# gradient using back prop is[-4.76764642e-07]
# gradient using grad checker is[-3.54603499e-07]
# gradient using back prop is[-3.54613796e-07]
# gradient using grad checker is[-6.76980173e-07]
# gradient using back prop is[-6.76971841e-07]
# gradient using grad checker is[-2.15381098e-07]
# gradient using back prop is[-2.15374578e-07]
# gradient using grad checker is[-2.51101223e-09]
# gradient using back prop is[-2.5110559e-09]
# gradient using grad checker is[-5.37770783e-07]
# gradient using back prop is[-5.37744832e-07]
# gradient using grad checker is[-8.12151995e-07]
# gradient using back prop is[-8.12146997e-07]
# gradient using grad checker is[-1.36934734e-08]
# gradient using back prop is[-1.37032353e-08]
# gradient using grad checker is[-1.16178768e-07]
# gradient using back prop is[-1.16168551e-07]
# gradient using grad checker is[-2.83223965e-07]
# gradient using back prop is[-2.83212456e-07]
# gradient using grad checker is[-3.45275024e-08]
# gradient using back prop is[-3.45273476e-08]
# gradient using grad checker is[-4.28418152e-07]
# gradient using back prop is[-4.2841185e-07]
# gradient using grad checker is[-1.60099798e-07]
# gradient using back prop is[-1.60111719e-07]
# gradient using grad checker is[-4.4251278e-07]
# gradient using back prop is[-4.42512636e-07]
# gradient using grad checker is[-4.21819697e-08]
# gradient using back prop is[-4.2178854e-08]
# gradient using grad checker is[-8.26812577e-08]
# gradient using back prop is[-8.26989625e-08]
# gradient using grad checker is[-7.17659439e-07]
# gradient using back prop is[-7.17656831e-07]
# gradient using grad checker is[3.96536103e-08]
# gradient using back prop is[3.96496723e-08]
# gradient using grad checker is[-3.96043528e-05]
# gradient using back prop is[-3.96043549e-05]
# gradient using grad checker is[-0.00018225]
# gradient using back prop is[-0.00018225]
# gradient using grad checker is[4.82400534e-05]
# gradient using back prop is[4.82400502e-05]
# gradient using grad checker is[-3.51455605e-05]
# gradient using back prop is[-3.51455648e-05]
# gradient using grad checker is[9.59330055e-05]
# gradient using back prop is[9.59329994e-05]
# gradient using grad checker is[-9.51408397e-05]
# gradient using back prop is[-9.51408458e-05]
# gradient using grad checker is[-1.78890908e-05]
# gradient using back prop is[-1.78890846e-05]
# gradient using grad checker is[-1.79320881e-05]
# gradient using back prop is[-1.7932098e-05]
# gradient using grad checker is[-0.00012022]
# gradient using back prop is[-0.00012022]
# gradient using grad checker is[6.20407978e-05]
# gradient using back prop is[6.20408056e-05]
# gradient using grad checker is[7.44971793e-06]
# gradient using back prop is[7.4497273e-06]
# gradient using grad checker is[-0.00020049]
# gradient using back prop is[-0.00020049]
# gradient using grad checker is[9.82328368e-07]
# gradient using back prop is[9.82329543e-07]
# gradient using grad checker is[-1.52982141e-05]
# gradient using back prop is[-1.52982187e-05]
# gradient using grad checker is[-0.00011953]
# gradient using back prop is[-0.00011953]
# gradient using grad checker is[-0.00011054]
# gradient using back prop is[-0.00011054]
# gradient using grad checker is[8.94867687e-05]
# gradient using back prop is[8.94867936e-05]
# gradient using grad checker is[4.18238144e-06]
# gradient using back prop is[4.18237067e-06]
# gradient using grad checker is[-4.57473837e-05]
# gradient using back prop is[-4.57473992e-05]
# gradient using grad checker is[-2.91922129e-05]
# gradient using back prop is[-2.91922171e-05]
# gradient using grad checker is[0.00022836]
# gradient using back prop is[0.00022836]
# gradient using grad checker is[6.86975932e-05]
# gradient using back prop is[6.86975942e-05]
# gradient using grad checker is[-7.1492005e-05]
# gradient using back prop is[-7.14920026e-05]
# gradient using grad checker is[1.92698049e-05]
# gradient using back prop is[1.92697812e-05]
# gradient using grad checker is[-7.52557717e-05]
# gradient using back prop is[-7.52557834e-05]
# gradient using grad checker is[2.44719804e-05]
# gradient using back prop is[2.44719809e-05]
# gradient using grad checker is[-0.00024496]
# gradient using back prop is[-0.00024496]
# gradient using grad checker is[-6.73001021e-05]
# gradient using back prop is[-6.73001e-05]
# gradient using grad checker is[-8.78012875e-05]
# gradient using back prop is[-8.78012785e-05]
# gradient using grad checker is[-4.46578538e-07]
# gradient using back prop is[-4.46570406e-07]
# gradient using grad checker is[0.00041976]
# gradient using back prop is[0.00041976]
# gradient using grad checker is[0.00036033]
# gradient using back prop is[0.00036033]
# gradient using grad checker is[-6.30408681e-05]
# gradient using back prop is[-6.3040859e-05]
# gradient using grad checker is[-0.00013725]
# gradient using back prop is[-0.00013725]
# gradient using grad checker is[0.00029988]
# gradient using back prop is[0.00029988]
# gradient using grad checker is[0.00041697]
# gradient using back prop is[0.00041697]
# gradient using grad checker is[-9.15679555e-05]
# gradient using back prop is[-9.15679422e-05]
# gradient using grad checker is[-0.00023551]
# gradient using back prop is[-0.00023551]
# gradient using grad checker is[0.0005416]
# gradient using back prop is[0.0005416]
# gradient using grad checker is[-0.00048763]
# gradient using back prop is[-0.00048763]
# gradient using grad checker is[-0.00051723]
# gradient using back prop is[-0.00051723]
# gradient using grad checker is[0.00060097]
# gradient using back prop is[0.00060097]
# gradient using grad checker is[-1.86023744e-05]
# gradient using back prop is[-1.86023774e-05]
# gradient using grad checker is[-8.19588343e-05]
# gradient using back prop is[-8.19588299e-05]
# gradient using grad checker is[0.0004442]
# gradient using back prop is[0.0004442]
# gradient using grad checker is[-0.00071648]
# gradient using back prop is[-0.00071648]
# gradient using grad checker is[-0.00059425]
# gradient using back prop is[-0.00059425]
# gradient using grad checker is[-0.00010525]
# gradient using back prop is[-0.00010525]
# gradient using grad checker is[0.00036894]
# gradient using back prop is[0.00036894]
# gradient using grad checker is[9.36409197e-05]
# gradient using back prop is[9.36409302e-05]
# gradient using grad checker is[-0.00047853]
# gradient using back prop is[-0.00047853]
# gradient using grad checker is[-0.00022745]
# gradient using back prop is[-0.00022745]
# gradient using grad checker is[-0.00024699]
# gradient using back prop is[-0.00024699]
# gradient using grad checker is[-0.00064232]
# gradient using back prop is[-0.00064232]
# gradient using grad checker is[0.00018544]
# gradient using back prop is[0.00018544]
# gradient using grad checker is[-0.00014496]
# gradient using back prop is[-0.00014496]
# gradient using grad checker is[0.00048039]
# gradient using back prop is[0.00048039]
# gradient using grad checker is[0.00033258]
# gradient using back prop is[0.00033258]
# gradient using grad checker is[0.00011548]
# gradient using back prop is[0.00011548]
# gradient using grad checker is[3.71501593e-05]
# gradient using back prop is[3.7150163e-05]
# gradient using grad checker is[3.15738538e-06]
# gradient using back prop is[3.15740038e-06]
# Your back prop is working absolutely fine. Difference is 5.4438653354856467e-08
