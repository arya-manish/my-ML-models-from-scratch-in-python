# %% [markdown]
# ### Load 2D Dataset

# %%
import numpy as np
from Sigmoid_Necessary_Functions_With_Dropout import *
from Gradient_Checker_With_Dropout import *
from Load_2D_Dataset import load_2D_dataset

import matplotlib.pyplot as plt
# Out:
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
X_train, Y_train, X_test, Y_test = load_2D_dataset()

# %%
print('X_train has shape :' +str(X_train.shape))
print('Y_train has shape :' +str(Y_train.shape))
print('X_test has shape :' +str(X_test.shape))
print('Y_test has shape :' +str(X_test.shape))
# Out:
# X_train has shape :(2, 211)
# Y_train has shape :(1, 211)
# X_test has shape :(2, 200)
# Y_test has shape :(2, 200)

# %%
parameters = dropout_model_sigmoid(X_train, Y_train, 0.3, 300, [X_train.shape[0],20,3,1], 0.8) # keep_prob = 0.8
train_accuracy = predict_accuracy_with_dropout(X_train, Y_train, parameters, 0.8)
test_accuracy = predict_accuracy(X_test, Y_test, parameters)
print('Train accuracy is: '+str(train_accuracy))
print('Test accuracy is: '+str(test_accuracy))
# Out:
# cost after 0 epochs is 0.6179678727499818
# cost after 100 epochs is 0.36169158052814454
# cost after 200 epochs is 0.3241527180844036
# Train accuracy is: 0.9052132701421801
# Test accuracy is: 0.925

# %%
AL, cache = forward_prop_with_dropout(X_train, parameters, 0.8)
gradients = back_prop_with_dropout(X_train, Y_train, cache, 0.8)
difference = dropout_gradient_checker(X_train, Y_train, parameters, gradients, 0.8)
# Out:
# gradient using grad checker is[-0.0012517]
# gradient using back prop is[-0.0012517]
# gradient using grad checker is[0.00354216]
# gradient using back prop is[0.00354216]
# gradient using grad checker is[-0.0011842]
# gradient using back prop is[-0.0011842]
# gradient using grad checker is[-0.00013312]
# gradient using back prop is[-0.00013312]
# gradient using grad checker is[-2.58454369e-05]
# gradient using back prop is[-2.58458886e-05]
# gradient using grad checker is[0.00206965]
# gradient using back prop is[0.00206965]
# gradient using grad checker is[0.00084628]
# gradient using back prop is[0.00084628]
# gradient using grad checker is[-0.00043683]
# gradient using back prop is[-0.00043683]
# gradient using grad checker is[-0.00075982]
# gradient using back prop is[-0.00075982]
# gradient using grad checker is[-0.00021675]
# gradient using back prop is[-0.00021675]
# gradient using grad checker is[0.00090583]
# gradient using back prop is[0.00090583]
# gradient using grad checker is[-0.00531586]
# gradient using back prop is[-0.00531586]
# gradient using grad checker is[0.00029518]
# gradient using back prop is[0.00029518]
# gradient using grad checker is[-0.00171132]
# gradient using back prop is[-0.00171132]
# gradient using grad checker is[0.00085099]
# gradient using back prop is[0.00085099]
# gradient using grad checker is[9.78123138e-05]
# gradient using back prop is[9.78123931e-05]
# gradient using grad checker is[-0.00241613]
# gradient using back prop is[-0.00241613]
# gradient using grad checker is[-0.00073632]
# gradient using back prop is[-0.00073632]
# gradient using grad checker is[-0.00387317]
# gradient using back prop is[-0.00387317]
# gradient using grad checker is[-0.00461266]
# gradient using back prop is[-0.00461266]
# gradient using grad checker is[0.00025218]
# gradient using back prop is[0.00025218]
# gradient using grad checker is[-0.00347779]
# gradient using back prop is[-0.00347779]
# gradient using grad checker is[-0.0016507]
# gradient using back prop is[-0.0016507]
# gradient using grad checker is[-0.00260877]
# gradient using back prop is[-0.00260877]
# gradient using grad checker is[0.00143879]
# gradient using back prop is[0.00143879]
# gradient using grad checker is[0.0035445]
# gradient using back prop is[0.0035445]
# gradient using grad checker is[0.001942]
# gradient using back prop is[0.001942]
# gradient using grad checker is[0.00064061]
# gradient using back prop is[0.00064061]
# gradient using grad checker is[0.00191175]
# gradient using back prop is[0.00191175]
# gradient using grad checker is[-0.00136936]
# gradient using back prop is[-0.00136936]
# gradient using grad checker is[0.00133313]
# gradient using back prop is[0.00133313]
# gradient using grad checker is[-0.00199182]
# gradient using back prop is[-0.00199182]
# gradient using grad checker is[0.00291235]
# gradient using back prop is[0.00291235]
# gradient using grad checker is[-0.00638819]
# gradient using back prop is[-0.00638819]
# gradient using grad checker is[0.00069694]
# gradient using back prop is[0.00069694]
# gradient using grad checker is[-0.00011457]
# gradient using back prop is[-0.00011457]
# gradient using grad checker is[0.00301871]
# gradient using back prop is[0.00301871]
# gradient using grad checker is[0.00291476]
# gradient using back prop is[0.00291476]
# gradient using grad checker is[-0.00282565]
# gradient using back prop is[-0.00282565]
# gradient using grad checker is[0.00074235]
# gradient using back prop is[0.00074235]
# gradient using grad checker is[0.00789836]
# gradient using back prop is[0.00789836]
# gradient using grad checker is[0.00409707]
# gradient using back prop is[0.00409707]
# gradient using grad checker is[0.00227131]
# gradient using back prop is[0.00227131]
# gradient using grad checker is[0.00317232]
# gradient using back prop is[0.00317232]
# gradient using grad checker is[0.0021755]
# gradient using back prop is[0.0021755]
# gradient using grad checker is[-0.00637296]
# gradient using back prop is[-0.00637296]
# gradient using grad checker is[-0.00079979]
# gradient using back prop is[-0.00079979]
# gradient using grad checker is[0.00124492]
# gradient using back prop is[0.00124492]
# gradient using grad checker is[0.00380233]
# gradient using back prop is[0.00380233]
# gradient using grad checker is[0.01041982]
# gradient using back prop is[0.01041982]
# gradient using grad checker is[-0.00201778]
# gradient using back prop is[-0.00201778]
# gradient using grad checker is[0.00506342]
# gradient using back prop is[0.00506342]
# gradient using grad checker is[-0.00055899]
# gradient using back prop is[-0.00055899]
# gradient using grad checker is[0.00144797]
# gradient using back prop is[0.00144797]
# gradient using grad checker is[-0.00635076]
# gradient using back prop is[-0.00635076]
# gradient using grad checker is[-0.01266505]
# gradient using back prop is[-0.01266505]
# gradient using grad checker is[-0.00775167]
# gradient using back prop is[-0.00775167]
# gradient using grad checker is[0.00157113]
# gradient using back prop is[0.00157113]
# gradient using grad checker is[-0.01068681]
# gradient using back prop is[-0.01068681]
# gradient using grad checker is[0.01741658]
# gradient using back prop is[0.01741658]
# gradient using grad checker is[-0.00014334]
# gradient using back prop is[-0.00014334]
# gradient using grad checker is[0.00213867]
# gradient using back prop is[0.00213867]
# gradient using grad checker is[-0.00020651]
# gradient using back prop is[-0.00020651]
# gradient using grad checker is[-0.00017487]
# gradient using back prop is[-0.00017487]
# gradient using grad checker is[-0.00082665]
# gradient using back prop is[-0.00082665]
# gradient using grad checker is[0.00060547]
# gradient using back prop is[0.00060547]
# gradient using grad checker is[0.00186944]
# gradient using back prop is[0.00186944]
# gradient using grad checker is[-0.00035534]
# gradient using back prop is[-0.00035534]
# gradient using grad checker is[-0.00501807]
# gradient using back prop is[-0.00501807]
# gradient using grad checker is[-0.00107546]
# gradient using back prop is[-0.00107546]
# gradient using grad checker is[-0.0022156]
# gradient using back prop is[-0.0022156]
# gradient using grad checker is[0.00138448]
# gradient using back prop is[0.00138448]
# gradient using grad checker is[0.00120829]
# gradient using back prop is[0.00120829]
# gradient using grad checker is[0.00037456]
# gradient using back prop is[0.00037456]
# gradient using grad checker is[-0.00252853]
# gradient using back prop is[-0.00252853]
# gradient using grad checker is[-0.0022281]
# gradient using back prop is[-0.0022281]
# gradient using grad checker is[-0.00227307]
# gradient using back prop is[-0.00227307]
# gradient using grad checker is[-0.00588682]
# gradient using back prop is[-0.00588682]
# gradient using grad checker is[-0.01307033]
# gradient using back prop is[-0.01307033]
# gradient using grad checker is[0.00146666]
# gradient using back prop is[0.00146666]
# gradient using grad checker is[-3.97029631e-05]
# gradient using back prop is[-3.97031641e-05]
# gradient using grad checker is[0.00306448]
# gradient using back prop is[0.00306448]
# gradient using grad checker is[0.00357843]
# gradient using back prop is[0.00357842]
# gradient using grad checker is[0.00164149]
# gradient using back prop is[0.00164149]
# gradient using grad checker is[-0.00134777]
# gradient using back prop is[-0.00134777]
# gradient using grad checker is[0.00222531]
# gradient using back prop is[0.00222531]
# gradient using grad checker is[-0.0056602]
# gradient using back prop is[-0.0056602]
# gradient using grad checker is[0.00082489]
# gradient using back prop is[0.00082489]
# gradient using grad checker is[-0.00056776]
# gradient using back prop is[-0.00056776]
# gradient using grad checker is[0.0017139]
# gradient using back prop is[0.0017139]
# gradient using grad checker is[0.00051356]
# gradient using back prop is[0.00051356]
# gradient using grad checker is[-0.00196963]
# gradient using back prop is[-0.00196963]
# gradient using grad checker is[-0.0058388]
# gradient using back prop is[-0.0058388]
# gradient using grad checker is[0.00127335]
# gradient using back prop is[0.00127335]
# gradient using grad checker is[0.00039201]
# gradient using back prop is[0.00039201]
# gradient using grad checker is[0.00224963]
# gradient using back prop is[0.00224963]
# gradient using grad checker is[0.00369964]
# gradient using back prop is[0.00369964]
# gradient using grad checker is[0.00078811]
# gradient using back prop is[0.00078811]
# gradient using grad checker is[-0.00375229]
# gradient using back prop is[-0.00375229]
# gradient using grad checker is[0.00240954]
# gradient using back prop is[0.00240954]
# gradient using grad checker is[0.0015696]
# gradient using back prop is[0.0015696]
# gradient using grad checker is[0.004016]
# gradient using back prop is[0.004016]
# gradient using grad checker is[0.00059655]
# gradient using back prop is[0.00059655]
# gradient using grad checker is[0.00088127]
# gradient using back prop is[0.00088127]
# gradient using grad checker is[0.00144708]
# gradient using back prop is[0.00144708]
# gradient using grad checker is[-0.00783412]
# gradient using back prop is[-0.00783412]
# gradient using grad checker is[-0.0016163]
# gradient using back prop is[-0.0016163]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.00068965]
# gradient using back prop is[0.00068965]
# gradient using grad checker is[0.00073125]
# gradient using back prop is[0.00073125]
# gradient using grad checker is[-0.00341673]
# gradient using back prop is[-0.00341673]
# gradient using grad checker is[0.00357666]
# gradient using back prop is[0.00357666]
# gradient using grad checker is[0.00503537]
# gradient using back prop is[0.00503537]
# gradient using grad checker is[0.00135323]
# gradient using back prop is[0.00135323]
# gradient using grad checker is[-0.00294225]
# gradient using back prop is[-0.00294225]
# gradient using grad checker is[-0.01071423]
# gradient using back prop is[-0.01071423]
# gradient using grad checker is[-0.00087]
# gradient using back prop is[-0.00087]
# gradient using grad checker is[0.00352667]
# gradient using back prop is[0.00352667]
# gradient using grad checker is[0.00054626]
# gradient using back prop is[0.00054626]
# gradient using grad checker is[0.00346859]
# gradient using back prop is[0.00346859]
# gradient using grad checker is[-0.00658319]
# gradient using back prop is[-0.00658319]
# gradient using grad checker is[0.00421502]
# gradient using back prop is[0.00421502]
# gradient using grad checker is[-0.00040962]
# gradient using back prop is[-0.00040962]
# gradient using grad checker is[-0.0069915]
# gradient using back prop is[-0.0069915]
# gradient using grad checker is[0.00230722]
# gradient using back prop is[0.00230722]
# gradient using grad checker is[-0.0165004]
# gradient using back prop is[-0.0165004]
# gradient using grad checker is[0.01262971]
# gradient using back prop is[0.01262971]
# Your back prop is working absolutely fine. Difference is 2.3163330852850148e-08
