# %% [markdown]
# ### Load 2D Dataset

# %%
import numpy as np
from Sigmoid_Necessary_Functions_With_Regularization_Or_Dropout_With_Optimizers_Model import *
from Gradient_Checker_With_Regularization_Or_Dropout_With_Optimizers import *
from Load_Dataset import load_dataset
import matplotlib.pyplot as plt
# Out:
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
X_train, Y_train = load_dataset()

# %%
print('X_train has shape :' +str(X_train.shape))
print('Y_train has shape :' +str(Y_train.shape))
# Out:
# X_train has shape :(2, 300)
# Y_train has shape :(1, 300)

# %%
optimizers = ['gd', 'momentum', 'rms_prop', 'adam']
lst = []

for optimizer in optimizers:
    parameters = regularized_or_dropout_optimizers_model_sigmoid(X_train, Y_train, layers_dims = [X_train.shape[0], 5, 2, 1], minibatch_size = 64, lambd = 0, keep_prob = 0, optimizer = optimizer,  num_epochs = 1000, learning_rate = 0.0007, beta1 = 0.9, beta2 = 0.999, epsilon = 1e-8) 
    train_accuracy = predict_accuracy(X_train, Y_train, parameters)
    t = (parameters, train_accuracy)
    lst.append(t)
    parameters, max_train_accuracy = max(lst,key=lambda item:item[1])
    if max_train_accuracy > 0.95:
        break
    print('Train accuracy is: '+str(train_accuracy))
    print('Maximum Train accuracy until now is ' +str(max_train_accuracy))
# Out:
# cost after 0 epochs is 0.6693952460453744
# cost after 100 epochs is 0.6609270898479466
# cost after 200 epochs is 0.6507574599309045
# cost after 300 epochs is 0.6463878983242329
# cost after 400 epochs is 0.6416928046846033
# cost after 500 epochs is 0.6441074497976661
# cost after 600 epochs is 0.6173392890945018
# cost after 700 epochs is 0.6249759347162359
# cost after 800 epochs is 0.6003301720615185
# cost after 900 epochs is 0.5500696870257108
# Train accuracy is: 0.8366666666666667
# Maximum Train accuracy until now is 0.8366666666666667
# cost after 0 epochs is 0.5828792567056483
# cost after 100 epochs is 0.6332014488830974
# cost after 200 epochs is 0.6167385312472639
# cost after 300 epochs is 0.6442619382214633
# cost after 400 epochs is 0.5088477956525022
# cost after 500 epochs is 0.6621620792831299
# cost after 600 epochs is 0.5697172493381231
# cost after 700 epochs is 0.608674061376855
# cost after 800 epochs is 0.5807892320056146
# cost after 900 epochs is 0.5413927835134024
# Train accuracy is: 0.7366666666666667
# Maximum Train accuracy until now is 0.8366666666666667
# cost after 0 epochs is 0.6637022402312895
# cost after 100 epochs is 0.6274252619286332
# cost after 200 epochs is 0.36176793916953026
# cost after 300 epochs is 0.2960730488202016
# cost after 400 epochs is 0.38102528539989583
# cost after 500 epochs is 0.4830298389467412
# cost after 600 epochs is 0.31134581109502546
# cost after 700 epochs is 0.3918042334204163
# cost after 800 epochs is 0.14146437855533633
# cost after 900 epochs is 0.15998668244767944
# Train accuracy is: 0.8766666666666667
# Maximum Train accuracy until now is 0.8766666666666667
# cost after 0 epochs is 0.7893985799477409
# cost after 100 epochs is 0.5054507882451994
# cost after 200 epochs is 0.34445057637495285
# cost after 300 epochs is 0.27937665477316653
# cost after 400 epochs is 0.3759672970726949
# cost after 500 epochs is 0.3941111075392349
# cost after 600 epochs is 0.4979192370637875
# cost after 700 epochs is 0.3115004732706115
# cost after 800 epochs is 0.423023654467935
# cost after 900 epochs is 0.2609914089276022
# Train accuracy is: 0.8833333333333333
# Maximum Train accuracy until now is 0.8833333333333333

# %%
AL, cache = forward_prop_with_dropout(X_train, parameters, keep_prob =0.7)
gradients = back_prop_with_dropout(X_train, Y_train, cache, keep_prob = 0.7)
difference = gradient_checker_with_regularization_or_dropout(X_train, Y_train, parameters, gradients, 0, 0.7)
# Out:
# gradient using grad checker is[0.26163768]
# gradient using back prop is[0.26163768]
# gradient using grad checker is[0.07564835]
# gradient using back prop is[0.07564835]
# gradient using grad checker is[-0.24453132]
# gradient using back prop is[-0.24453132]
# gradient using grad checker is[-0.0209893]
# gradient using back prop is[-0.0209893]
# gradient using grad checker is[0.02037916]
# gradient using back prop is[0.02037916]
# gradient using grad checker is[-0.01150397]
# gradient using back prop is[-0.01150397]
# gradient using grad checker is[-0.1952124]
# gradient using back prop is[-0.1952124]
# gradient using grad checker is[-0.01531785]
# gradient using back prop is[-0.01531785]
# gradient using grad checker is[-0.09089517]
# gradient using back prop is[-0.09089517]
# gradient using grad checker is[0.06251538]
# gradient using back prop is[0.06251538]
# gradient using grad checker is[0.28390852]
# gradient using back prop is[0.28390852]
# gradient using grad checker is[-0.13977919]
# gradient using back prop is[-0.13977919]
# gradient using grad checker is[0.04602589]
# gradient using back prop is[0.04602589]
# gradient using grad checker is[-0.15628386]
# gradient using back prop is[-0.15628386]
# gradient using grad checker is[0.13197947]
# gradient using back prop is[0.13197947]
# gradient using grad checker is[0.39616669]
# gradient using back prop is[0.39616669]
# gradient using grad checker is[0.06213665]
# gradient using back prop is[0.06213665]
# gradient using grad checker is[0.09967425]
# gradient using back prop is[0.09967425]
# gradient using grad checker is[0.085383]
# gradient using back prop is[0.085383]
# gradient using grad checker is[0.07466842]
# gradient using back prop is[0.07466842]
# gradient using grad checker is[-0.02603393]
# gradient using back prop is[-0.02603393]
# gradient using grad checker is[-0.00581166]
# gradient using back prop is[-0.00581166]
# gradient using grad checker is[0.00144923]
# gradient using back prop is[0.00144923]
# gradient using grad checker is[-0.01338527]
# gradient using back prop is[-0.01338527]
# gradient using grad checker is[0.08460144]
# gradient using back prop is[0.08460144]
# gradient using grad checker is[0.23026048]
# gradient using back prop is[0.23026048]
# gradient using grad checker is[0.03212011]
# gradient using back prop is[0.03212011]
# gradient using grad checker is[-0.16149464]
# gradient using back prop is[-0.16149464]
# gradient using grad checker is[0.24141208]
# gradient using back prop is[0.24141209]
# gradient using grad checker is[0.00770074]
# gradient using back prop is[0.00770074]
# Your back prop is working absolutely fine. Difference is 3.732340474634956e-09

# %%
# Out:
# [2, 17, 13, 19, 19, 1]

# %%
# Out:
# 0.00612717093373762

# %%
# Out:
# 32

# %%
# Out:
# momentum

# %%
def automated_hypertuning(X_train, Y_train):
    lst_param_accuracy = []
    train_accuracy = 0

    while(train_accuracy < 0.99):
        layers_dims = random_layers_dims(X_train)
        learning_rate = random_alpha()
        minibatch_size = random_minibatch_size(X_train)
        optimizer = random_optimizer()
        lambd = random_lambd()
        parameters = regularized_or_dropout_optimizers_model_sigmoid(X_train, Y_train, layers_dims = layers_dims, minibatch_size = minibatch_size, lambd = lambd, keep_prob = 0, optimizer = optimizer,  num_epochs = 1000, learning_rate = learning_rate, beta1 = 0.9, beta2 = 0.999, epsilon = 1e-8)
        train_accuracy = predict_accuracy(X_train, Y_train, parameters)
        t = (parameters, train_accuracy)
        lst_param_accuracy.append(t)
        parameters_for_max_train_accuracy, max_train_accuracy = max(lst_param_accuracy,key=lambda item:item[1])
        hyperparameters_for_max_train_accuracy = (layers_dims, minibatch_size, lambd, optimizer, learning_rate)
        
        print('Train accuracy is: '+str(train_accuracy))
        print('Maximum Train accuracy until now is ' +str(max_train_accuracy))
        
    return parameters_for_max_train_accuracy, hyperparameters_for_max_train_accuracy

# %%
parameters = automated_hypertuning(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ed36324f5765> in <module>()
# ----> 1 parameters = automated_hypertuning(X_train, Y_train)
#
# <ipython-input-9-768be6751a87> in automated_hypertuning(X_train, Y_train)
#       8         minibatch_size = random_minibatch_size(X_train)
#       9         optimizer = random_optimizer()
# ---> 10         parameters = regularized_or_dropout_optimizers_model_sigmoid(X_train, Y_train, layers_dims = layers_dims, minibatch_size = minibatch_size, lambd = lambd, keep_prob = 0, optimizer = optimizer,  num_epochs = 1000, learning_rate = learning_rate, beta1 = 0.9, beta2 = 0.999, epsilon = 1e-8)
#      11         train_accuracy = predict_accuracy(X_train, Y_train, parameters)
#      12         t = (parameters, train_accuracy)
#
# NameError: name 'lambd' is not defined

# %%
print(parameters_max)
print(max_train_accuracy)
# Out:
# {'b5': array([[-0.43069788]]), 'W3': array([[-3.72466795e-01,  6.79576913e-01,  5.12853578e-01,
#          2.46634748e-01, -1.99232730e-01, -1.23159021e+00,
#          3.18671411e-01, -4.43218734e-01,  1.91649242e+00,
#          5.31928599e-01,  1.98676667e-01],
#        [ 4.00667732e-01,  2.07315551e+00, -2.66711196e-01,
#          6.70616354e-02,  4.11424012e-01, -2.04078482e+00,
#         -1.87109478e+00,  1.01937555e+00,  1.24686920e-01,
#         -5.87596989e-01,  6.40145240e-02],
#        [-5.76762342e-01, -1.77932718e-02, -6.17205073e-01,
#          9.36334320e-02,  4.76289168e-01,  1.05884260e-01,
#         -1.92629554e-01,  2.07517965e-01,  3.04493438e-01,
#         -8.28102194e-02, -2.64052956e-01],
#        [ 1.28605376e-01, -1.20617933e+00, -3.48036581e-01,
#         -8.52089122e-01,  1.01019883e-01, -1.15373769e+00,
#          1.16493700e+00, -1.23975560e+00, -5.88928506e-01,
#          5.94373162e-01, -3.55884079e-02],
#        [-5.06371295e-02,  4.72944707e-01,  6.87082075e-01,
#          6.25059553e-02, -2.55395789e-01,  2.49240574e-03,
#         -1.15512765e-01,  1.84958917e-01, -1.12607145e+00,
#          3.69342234e-01, -1.71757959e-01],
#         -1.62177165e-01,  1.63400603e-02, -2.76737858e-01,
#          4.61663634e-01, -1.24186926e+00,  1.02117780e+00,
#         -2.18495205e-01, -3.69829693e-01],
#        [ 2.65582166e-01, -8.26687552e-01, -4.87969430e-01,
#         -1.13806067e+00, -1.03820839e-01, -3.12285928e-01,
#         -3.66624503e-01,  6.30048548e-01,  5.23586869e-01,
#         -3.41086616e-01,  2.99854925e-01]]), 'b2': array([[-0.16938886],
#        [ 0.84606688],
#        [-0.50523374],
#        [-0.57417343],
#        [-0.47701887],
#        [-0.53214699],
#        [-0.10666751],
#        [ 0.01327916],
#        [-0.54446079],
#        [-0.07719856],
#        [-0.16446268]]), 'W5': array([[ 0.64135368, -0.00605828, -0.76410056, -0.88368302, -0.28734438,
#         -0.83552244, -0.53570472,  0.5319985 , -0.06667069,  1.07316061,
#         -0.72034886,  0.03717363,  0.91451762, -1.57352816, -0.0273099 ,
#         -0.01411737, -0.3962903 ,  1.85115875,  0.92682407]]), 'b3': array([[ 0.32594353],
#        [-0.28076546],
#        [-0.48886082],
#        [-0.64161091],
#        [ 0.0871131 ],
#        [-1.04156534],
#        [-0.65065684],
#        [-0.2495504 ],
#        [ 0.42555292],
#        [-0.0320617 ],
#        [ 0.48933992],
#        [-0.20253614],
#        [ 0.52696872],
#        [-0.09157426],
#        [-1.22512849],
#        [-0.83457176],
#        [ 0.12491286],
#        [-0.57758159],
#        [-0.37517394]]), 'W1': array([[ 1.35729997, -0.81605097],
#        [ 0.46617968,  2.03863397],
#        [-0.70872605, -0.81262966],
#        [-0.63220116,  1.2609843 ],
#        [ 1.03586898, -1.22158899],
#        [-0.88249875, -2.65854991],
#        [-0.97692491, -2.43455318],
#        [-1.13615385, -0.24265806],
#        [ 0.6495798 , -0.85260517],
#        [ 0.94614753,  1.21828308],
#        [-1.79141277, -1.98870247],
#        [ 0.55161613, -1.96762876],
#        [ 0.60750871, -0.92529272],
#        [-0.23206344,  1.14871305],
#        [-3.35765448, -0.2703385 ],
#        [-2.09731577,  0.34969517]]), 'b4': array([[-0.11856822],
#        [-0.29717417],
#        [ 0.29068469],
#        [ 0.33218112],
#        [-0.20572751],
#        [ 0.41818616],
#        [ 0.39973136],
#        [-0.13895179],
#        [-0.2630743 ],
#        [-0.07884097],
#        [ 0.75113216],
#        [-0.43636834],
#        [-1.15868459],
#        [ 0.15274617],
#        [-0.12085003],
#        [-0.53228833],
#        [ 0.41292526],
#        [ 0.53471373],
#        [ 0.05248262]]), 'W4': array([[ 6.25575331e-01,  1.30667980e+00, -3.10573456e-02,
#         -1.07901948e+00,  2.86318773e-01,  9.80130697e-01,
#          4.17382220e-01,  1.17944700e-01,  5.29922203e-01,
#          5.23751213e-02, -1.43113211e-01,  7.64635421e-01,
#         -1.47601962e+00,  6.96938853e-01,  5.62597140e-01,
#          2.76675754e-01, -7.83076778e-01,  4.95942631e-01,
#         -6.09727766e-02],
#        [-4.34487782e-01, -4.90882858e-02, -3.55560937e-01,
#         -0.69678795],
#        [ 0.3238648 ,  0.43992884, -0.70002901,  1.41737983,  0.82203153,
#         -1.04110277, -0.82108233, -1.15992664,  0.36439769,  0.93536249,
#          3.13405307, -0.1307803 , -0.07723979,  0.2431035 ,  1.64382257,
#          2.10361468],
#        [-0.81025604, -0.04294892,  0.36015339,  1.55524953, -0.45931657,
#          1.39818408,  1.25396389,  1.48799366,  0.20447891, -0.9596271 ,
#         -0.85111091, -0.04536641,  1.15168641, -0.26789597, -1.04960957,
#         -2.61640048],
#        [-0.79490829,  0.66451932, -0.61289606, -1.04495164, -0.8831791 ,
#          0.26167045,  1.45284882, -0.49814392, -1.76346636,  0.41731513,
#          0.77779183,  0.18910559, -0.00664939,  0.75969379,  0.7404149 ,
#          2.15864656],
#        [ 0.72207274, -1.86788737, -0.50828458,  0.05907403,  1.21580541,
#         -1.7315834 , -1.25125693, -0.91466599,  0.28258908, -0.39717178,
#          0.20810448,  0.42428126,  0.5260911 ,  0.60980634,  0.22147727,
#          0.68961417],
#        [ 0.02930059, -0.22872178, -0.56019734,  0.1943628 , -0.27928567,
#         -0.67149608, -0.77294353,  0.09731386,  0.17420033, -0.33077318,
#          0.24124247,  0.07224842, -0.12621362, -0.3806237 , -0.39907178,
#          0.43315693],
#        [-0.51573566, -0.48904763,  0.04872701,  0.06170999, -0.18279519,
#          0.26496225, -0.3549032 , -0.00950427, -0.57865205,  0.30705663,
#         -0.41239991,  0.03132207, -0.71039135, -0.31918299, -0.0495241 ,
#         -0.09547873]])}
# 0.9933333333333333

# %%
print(optimizer)
# Out:
# adam

# %%
parameters = regularized_or_dropout_optimizers_model_sigmoid(X_train, Y_train, layers_dims = layers_dims, minibatch_size = 512, lambd = 0.8, keep_prob = 0, optimizer = optimizer,  num_epochs = 1000, learning_rate = learning_rate, beta1 = 0.9, beta2 = 0.999)
train_accuracy = predict_accuracy(X_train, Y_train, parameters)
# Out:
# cost after 0 epochs is 0.9517173278962219
# cost after 100 epochs is 0.19225001915236598
# cost after 200 epochs is 0.16954889878345566
# cost after 300 epochs is 0.16400515795690693
# cost after 400 epochs is 0.16159999301813827
# cost after 500 epochs is 0.16028676339936088
# cost after 600 epochs is 0.158759003017155
# cost after 700 epochs is 0.15751260575521692
# cost after 800 epochs is 0.15521530238954517
# cost after 900 epochs is 0.15221996052583014

# %%
print(train_accuracy)
# Out:
# 0.96

# %%
parameters = automated_hyperparameters_tuning(X_train, Y_train)
# Out:
# cost after 0 epochs is 0.8708525603133541
# cost after 100 epochs is 0.31578042786806054
# cost after 200 epochs is 0.258443105767716
# cost after 300 epochs is 0.2467876696786601
# cost after 400 epochs is 0.24379084104826093
# cost after 500 epochs is 0.24300456592576564
# cost after 600 epochs is 0.24262618455149118
# cost after 700 epochs is 0.2425327510509363
# cost after 800 epochs is 0.2423783342284369
# cost after 900 epochs is 0.24239526207450984
# Train accuracy is: 0.9433333333333334
# Maximum Train accuracy until now is 0.9433333333333334
# cost after 0 epochs is 0.7748076240363018
# cost after 100 epochs is 0.25058288982314314
# cost after 200 epochs is 0.17573214964294492
# cost after 300 epochs is 0.16508819904380434
# cost after 400 epochs is 0.16665787969985862
# cost after 500 epochs is 0.1756798858214037
# cost after 600 epochs is 0.17366222212439858
# cost after 700 epochs is 0.17083905112859896
# cost after 800 epochs is 0.16463848413605783
# cost after 900 epochs is 0.16658430819487882
# Train accuracy is: 0.94
# Maximum Train accuracy until now is 0.94
# cost after 0 epochs is 0.8829922422934628
# cost after 100 epochs is 0.37555190400458704
# cost after 200 epochs is 0.18755854113979212
# cost after 300 epochs is 0.17436230854735574
# cost after 400 epochs is 0.16747991624843822
# cost after 500 epochs is 0.16280507298756824
# cost after 600 epochs is 0.15967146213448075
# cost after 700 epochs is 0.15743327971299917
# cost after 800 epochs is 0.15577567360710948
# cost after 900 epochs is 0.15442826872114368
# Train accuracy is: 0.9466666666666667
# Maximum Train accuracy until now is 0.9466666666666667
# cost after 0 epochs is 0.668920094159928
# cost after 100 epochs is 0.3515672435482488
# cost after 200 epochs is 0.3330556003293917
# cost after 300 epochs is 0.31649651469610207
# cost after 400 epochs is 0.29940771137583866
# cost after 500 epochs is 0.2833412058095973
# cost after 600 epochs is 0.26775509178168727
# cost after 700 epochs is 0.2502177707193542
# cost after 800 epochs is 0.2338250668580381
# cost after 900 epochs is 0.2181927062349542
# Train accuracy is: 0.9266666666666666
# Maximum Train accuracy until now is 0.9266666666666666
# cost after 0 epochs is 1.3355243786391269
# cost after 100 epochs is 0.2790961188982219
# cost after 200 epochs is 0.23012259308925465
# cost after 300 epochs is 0.22009738515932614
# cost after 400 epochs is 0.21670686472784817
# cost after 500 epochs is 0.21480317642952435
# cost after 600 epochs is 0.21344985593777527
# cost after 700 epochs is 0.2127979203623435
# cost after 800 epochs is 0.21244142408159172
# cost after 900 epochs is 0.212247885900122
# Train accuracy is: 0.94
# Maximum Train accuracy until now is 0.94
# cost after 0 epochs is 1.7133532960655256
# cost after 100 epochs is 1.5189311166321957
# cost after 200 epochs is 1.4316864646243037
# cost after 300 epochs is 1.3975623910766322
# cost after 400 epochs is 1.3056402860486833
# cost after 500 epochs is 1.3187444775478383
# cost after 600 epochs is 1.2633194329466217
# cost after 700 epochs is 1.1063804198112788
# cost after 800 epochs is 1.0294711169940007
# cost after 900 epochs is 1.0207333481079324
# Train accuracy is: 0.8766666666666667
# Maximum Train accuracy until now is 0.8766666666666667
# cost after 0 epochs is 0.6427599927743317
# cost after 100 epochs is 0.22955701906594703
# cost after 200 epochs is 0.22516903035601282
# cost after 300 epochs is 0.22483532537511364
# cost after 400 epochs is 0.22477380682102716
# cost after 500 epochs is 0.22489773883073255
# cost after 600 epochs is 0.224811114922023
# cost after 700 epochs is 0.22471403520566996
# cost after 800 epochs is 0.2247740932276006
# cost after 900 epochs is 0.22468499668418607
# Train accuracy is: 0.9366666666666666
# Maximum Train accuracy until now is 0.9366666666666666
# cost after 0 epochs is 0.9291633782586614
# cost after 100 epochs is 0.2944873808372131
# cost after 200 epochs is 0.29355965036918374
# cost after 300 epochs is 0.2934396214094373
# cost after 400 epochs is 0.29337772690433894
# cost after 500 epochs is 0.29313441410312835
# cost after 600 epochs is 0.29300229093652486
# cost after 700 epochs is 0.2934150113838022
# cost after 800 epochs is 0.2929757243412823
# cost after 900 epochs is 0.29294641141771205
# Train accuracy is: 0.9333333333333333
# Maximum Train accuracy until now is 0.9333333333333333
# cost after 0 epochs is 1.281340820647637
# cost after 100 epochs is 0.2307960493314162
# cost after 200 epochs is 0.19233734489432902
# cost after 300 epochs is 0.18430613383941552
# cost after 400 epochs is 0.1808439320315832
# cost after 500 epochs is 0.17906975736691652
# cost after 600 epochs is 0.17783826475911468
# cost after 700 epochs is 0.17707615515323216
# cost after 800 epochs is 0.17658026180763087
# cost after 900 epochs is 0.1762344588566153
# Train accuracy is: 0.9433333333333334
# Maximum Train accuracy until now is 0.9433333333333334
# cost after 0 epochs is 1.751287308258485
# cost after 100 epochs is 0.6277255890691122
# cost after 200 epochs is 0.501852047615634
# cost after 300 epochs is 0.5411696580386798
# cost after 400 epochs is 0.42263154140842707
# cost after 500 epochs is 0.509325046785557
# cost after 600 epochs is 0.5001859595306956
# cost after 700 epochs is 0.5846326654409483
# cost after 800 epochs is 0.6431143998731417
# cost after 900 epochs is 0.5461749794539779
# Train accuracy is: 0.8433333333333334
# Maximum Train accuracy until now is 0.8433333333333334
# cost after 0 epochs is 2.212832922506121
# cost after 100 epochs is 2.021660408472844
# cost after 200 epochs is 1.941718609552185
# cost after 300 epochs is 1.8762572469698195
# cost after 400 epochs is 1.8747647834963266
# cost after 500 epochs is 1.8148316193286178
# cost after 600 epochs is 1.8895381214285782
# cost after 700 epochs is 1.7948032673301628
# cost after 800 epochs is 1.8022942796912231
# cost after 900 epochs is 1.844871320156486
# Train accuracy is: 0.8566666666666667
# Maximum Train accuracy until now is 0.8566666666666667
# cost after 0 epochs is 1.039981197679898
# cost after 100 epochs is 0.9264931011428273
# cost after 200 epochs is 0.823738430322642
# cost after 300 epochs is 0.7418341563541233
# cost after 400 epochs is 0.6781823671090135
# cost after 500 epochs is 0.6291829324185433
# cost after 600 epochs is 0.5915990710125343
# cost after 700 epochs is 0.562736729746406
# cost after 800 epochs is 0.5403660160345358
# cost after 900 epochs is 0.5228148090756071
# Train accuracy is: 0.8433333333333334
# Maximum Train accuracy until now is 0.8433333333333334
# cost after 0 epochs is 0.7256574423043863
# cost after 100 epochs is 0.323278987691146
# cost after 200 epochs is 0.29226139858408456
# cost after 300 epochs is 0.26320098593335456
# cost after 400 epochs is 0.23372586169373488
# cost after 500 epochs is 0.20323060088129474
# cost after 600 epochs is 0.17790369779402948
# cost after 700 epochs is 0.16111726317083183
# cost after 800 epochs is 0.14832476568107203
# cost after 900 epochs is 0.14105498178949827
# Train accuracy is: 0.9433333333333334
# Maximum Train accuracy until now is 0.9433333333333334
# cost after 0 epochs is 0.7604983363161929
# cost after 100 epochs is 0.22727072072658033
# cost after 200 epochs is 0.22521985716386833
# cost after 300 epochs is 0.22480304511408752
# cost after 400 epochs is 0.22424838264807662
# cost after 500 epochs is 0.2241242222821838
# cost after 600 epochs is 0.2241727038585005
# cost after 700 epochs is 0.22420015373589736
# cost after 800 epochs is 0.22423465874664228
# cost after 900 epochs is 0.22415873423588184
# Train accuracy is: 0.9433333333333334
# Maximum Train accuracy until now is 0.9433333333333334
# cost after 0 epochs is 10.006219519246667
# cost after 100 epochs is 1.317412109914948
# /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Sigmoid_With_Regularization_Or_Dropout_With_Optimizers_Model/Sigmoid_With_Regularization_Or_Dropout_With_Optimizers_Model(Moon Problem)/Sigmoid_Necessary_Functions_With_Regularization_Or_Dropout_With_Optimizers_Model.py:39: RuntimeWarning: overflow encountered in exp
#   s = 1/(1+np.exp(-x))
# /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Sigmoid_With_Regularization_Or_Dropout_With_Optimizers_Model/Sigmoid_With_Regularization_Or_Dropout_With_Optimizers_Model(Moon Problem)/Sigmoid_Necessary_Functions_With_Regularization_Or_Dropout_With_Optimizers_Model.py:68: RuntimeWarning: divide by zero encountered in log
#   J_Cross_Entropy = -(1/m)*np.nansum((np.multiply(Y, np.log(AL)) + np.multiply((1 - Y), np.log(1 - AL))))
# /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Sigmoid_With_Regularization_Or_Dropout_With_Optimizers_Model/Sigmoid_With_Regularization_Or_Dropout_With_Optimizers_Model(Moon Problem)/Sigmoid_Necessary_Functions_With_Regularization_Or_Dropout_With_Optimizers_Model.py:68: RuntimeWarning: invalid value encountered in multiply
#   J_Cross_Entropy = -(1/m)*np.nansum((np.multiply(Y, np.log(AL)) + np.multiply((1 - Y), np.log(1 - AL))))
# cost after 200 epochs is 0.8944724142319317
# cost after 300 epochs is 0.6779540850840096
# cost after 400 epochs is 0.5533127677025199
# cost after 500 epochs is 0.4657995829421535
# cost after 600 epochs is 0.39999474078739305
# cost after 700 epochs is 0.3405232183131143
# cost after 800 epochs is 0.3049307717726515
# cost after 900 epochs is 0.28367338006957865
# Train accuracy is: 0.9366666666666666
# Maximum Train accuracy until now is 0.9366666666666666
# cost after 0 epochs is 1.7809269260353333
# cost after 100 epochs is 1.0672161815200845
# cost after 200 epochs is 0.43116323575420257
# cost after 300 epochs is 0.5637931958900572
# cost after 400 epochs is 0.4004179623562719

# %%
        train_accuracy = predict_accuracy(X_train, Y_train, parameters)

        lst_param_accuracy = []
        tpl_param_accuracy = (parameters, train_accuracy)
        lst_param_accuracy.append(tpl_param_accuracy)
        parameters_for_max_train_accuracy, max_train_accuracy = max(lst_param_accuracy,key=lambda item:item[1])
        
        
        print('Train accuracy for current model is: '+str(train_accuracy))
        print('Maximum Train accuracy until now using different set of hyperparameters is ' +str(max_train_accuracy))
        hyperparameters_for_max_train_accuracy = (layers_dims, minibatch_size, lambd, optimizer, learning_rate)
