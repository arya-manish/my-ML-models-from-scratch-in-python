# %% [markdown]
# ### Load 2D Dataset

# %%
import numpy as np
from Sigmoid_Necessary_Functions_With_Regularization import *
from Gradient_Checker_With_Regularization import *
from Load_2D_Dataset import load_2D_dataset

import matplotlib.pyplot as plt
# Out:
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
X_train, Y_train, X_test, Y_test = load_2D_dataset()

# %%
print('X_train has shape :' +str(X_train.shape))
print('Y_train has shape :' +str(Y_train.shape))
print('X_test has shape :' +str(X_test.shape))
print('Y_test has shape :' +str(X_test.shape))
# Out:
# X_train has shape :(2, 211)
# Y_train has shape :(1, 211)
# X_test has shape :(2, 200)
# Y_test has shape :(2, 200)

# %%
parameters = regularized_model_sigmoid(X_train, Y_train, 0.03, 30000, [X_train.shape[0],25,12,1], lambd = 0.7)
train_accuracy = predict_accuracy(X_train, Y_train, parameters)
test_accuracy = predict_accuracy(X_test, Y_test, parameters)
print('Train accuracy is: '+str(train_accuracy))
print('Test accuracy is: '+str(test_accuracy))
# Out:
# cost after 0 epochs is 0.9232491012780867
# cost after 100 epochs is 0.6348578421805322
# cost after 200 epochs is 0.49052521864686327
# cost after 300 epochs is 0.4254820362965333
# cost after 400 epochs is 0.39894335195097663
# cost after 500 epochs is 0.38584474645267897
# cost after 600 epochs is 0.3777903382298911
# cost after 700 epochs is 0.3719073342498294
# cost after 800 epochs is 0.3679848041568777
# cost after 900 epochs is 0.36506598490088304
# cost after 1000 epochs is 0.36249540444959216
# cost after 1100 epochs is 0.3601210381052568
# cost after 1200 epochs is 0.3578955103281668
# cost after 1300 epochs is 0.3554674868672162
# cost after 1400 epochs is 0.353017175263875
# cost after 1500 epochs is 0.3507828056414321
# cost after 1600 epochs is 0.3487473161353768
# cost after 1700 epochs is 0.3468556390795164
# cost after 1800 epochs is 0.3450478616608041
# cost after 1900 epochs is 0.34330494814660645
# cost after 2000 epochs is 0.34162476708921796
# cost after 2100 epochs is 0.33998779970279125
# cost after 2200 epochs is 0.3383936616245762
# cost after 2300 epochs is 0.3368360518412258
# cost after 2400 epochs is 0.3353192556400378
# cost after 2500 epochs is 0.33383686329197376
# cost after 2600 epochs is 0.3323908004660739
# cost after 2700 epochs is 0.3309745664812828
# cost after 2800 epochs is 0.32958414741769737
# cost after 2900 epochs is 0.3282246127657573
# cost after 3000 epochs is 0.326887746479219
# cost after 3100 epochs is 0.32555857506618774
# cost after 3200 epochs is 0.3242601992273819
# cost after 3300 epochs is 0.3230034979990817
# cost after 3400 epochs is 0.32177390319892396
# cost after 3500 epochs is 0.3205753765487968
# cost after 3600 epochs is 0.3194041398244051
# cost after 3700 epochs is 0.31825686423350863
# cost after 3800 epochs is 0.3170745760678968
# cost after 3900 epochs is 0.3158844438380804
# cost after 4000 epochs is 0.31475795179533245
# cost after 4100 epochs is 0.3136559988246607
# cost after 4200 epochs is 0.3125556095558666
# cost after 4300 epochs is 0.31146391161068326
# cost after 4400 epochs is 0.31030794821907326
# cost after 4500 epochs is 0.30917865017055707
# cost after 4600 epochs is 0.3081302502955041
# cost after 4700 epochs is 0.3071143694422176
# cost after 4800 epochs is 0.30617385363880045
# cost after 4900 epochs is 0.3052858350350804
# cost after 5000 epochs is 0.30437132641080633
# cost after 5100 epochs is 0.3034969524794903
# cost after 5200 epochs is 0.302658496120784
# cost after 5300 epochs is 0.3018454647725929
# cost after 5400 epochs is 0.30105067704366484
# cost after 5500 epochs is 0.3002728434961165
# cost after 5600 epochs is 0.2994752337802331
# cost after 5700 epochs is 0.2986839421326801
# cost after 5800 epochs is 0.2978883337203474
# cost after 5900 epochs is 0.2970706515587373
# cost after 6000 epochs is 0.29628591428038437
# cost after 6100 epochs is 0.2954894932431174
# cost after 6200 epochs is 0.29464903819478083
# cost after 6300 epochs is 0.293828714532017
# cost after 6400 epochs is 0.2930794876960951
# cost after 6500 epochs is 0.2923986298163599
# cost after 6600 epochs is 0.29176240866541403
# cost after 6700 epochs is 0.2911488653242879
# cost after 6800 epochs is 0.29054527789120366
# cost after 6900 epochs is 0.2899536085797069
# cost after 7000 epochs is 0.28937942382517995
# cost after 7100 epochs is 0.28882851628736733
# cost after 7200 epochs is 0.2882801738236821
# cost after 7300 epochs is 0.28777312446846864
# cost after 7400 epochs is 0.28728569612426036
# cost after 7500 epochs is 0.28681089961693373
# cost after 7600 epochs is 0.2863484548422222
# cost after 7700 epochs is 0.2858972727542508
# cost after 7800 epochs is 0.2854566931240022
# cost after 7900 epochs is 0.2850270262305311
# cost after 8000 epochs is 0.28460737058466445
# cost after 8100 epochs is 0.2841534789497332
# cost after 8200 epochs is 0.28371075182174754
# cost after 8300 epochs is 0.2832622192159379
# cost after 8400 epochs is 0.2828208979654294
# cost after 8500 epochs is 0.2824164523859808
# cost after 8600 epochs is 0.2820224847492782
# cost after 8700 epochs is 0.2816440229278282
# cost after 8800 epochs is 0.28127102082222144
# cost after 8900 epochs is 0.28090424277591064
# cost after 9000 epochs is 0.28055653016806625
# cost after 9100 epochs is 0.28022044565665244
# cost after 9200 epochs is 0.27989646463830326
# cost after 9300 epochs is 0.279576896577811
# cost after 9400 epochs is 0.2792640828998106
# cost after 9500 epochs is 0.2789613152278569
# cost after 9600 epochs is 0.2786688678032288
# cost after 9700 epochs is 0.27838314452535234
# cost after 9800 epochs is 0.27810404427615254
# cost after 9900 epochs is 0.27783174145726786
# cost after 10000 epochs is 0.2775656094953489
# cost after 10100 epochs is 0.27730588818444035
# cost after 10200 epochs is 0.277052390559965
# cost after 10300 epochs is 0.2768052903315613
# cost after 10400 epochs is 0.27656310253813887
# cost after 10500 epochs is 0.2763269150445249
# cost after 10600 epochs is 0.27609718987373294
# cost after 10700 epochs is 0.27587230278101105
# cost after 10800 epochs is 0.2756529185666397
# cost after 10900 epochs is 0.2754377343590078
# cost after 11000 epochs is 0.27522799037067985
# cost after 11100 epochs is 0.2749470273839542
# cost after 11200 epochs is 0.27469204243800555
# cost after 11300 epochs is 0.2744491944893296
# cost after 11400 epochs is 0.27423537162585515
# cost after 11500 epochs is 0.274030810608838
# cost after 11600 epochs is 0.2738393914357883
# cost after 11700 epochs is 0.27365543440838197
# cost after 11800 epochs is 0.27347722357978566
# cost after 11900 epochs is 0.2733040003805715
# cost after 12000 epochs is 0.2731345245933438
# cost after 12100 epochs is 0.2729693348762574
# cost after 12200 epochs is 0.2728071309112881
# cost after 12300 epochs is 0.27264881757190473
# cost after 12400 epochs is 0.272494197766367
# cost after 12500 epochs is 0.2723426096225711
# cost after 12600 epochs is 0.2721947298040538
# cost after 12700 epochs is 0.2720501270433371
# cost after 12800 epochs is 0.2719083772304457
# cost after 12900 epochs is 0.271771081922096
# cost after 13000 epochs is 0.2716366599719027
# cost after 13100 epochs is 0.2715053165334653
# cost after 13200 epochs is 0.2713772347558429
# cost after 13300 epochs is 0.27125222629058576
# cost after 13400 epochs is 0.2711265237775375
# cost after 13500 epochs is 0.2710066065655148
# cost after 13600 epochs is 0.2708898715318306
# cost after 13700 epochs is 0.2707755435619125
# cost after 13800 epochs is 0.2706642768388598
# cost after 13900 epochs is 0.27055573806021316
# cost after 14000 epochs is 0.27044899156242713
# cost after 14100 epochs is 0.27034500513528487
# cost after 14200 epochs is 0.270243093707167
# cost after 14300 epochs is 0.27014336883917794
# cost after 14400 epochs is 0.27004591138223033
# cost after 14500 epochs is 0.2699502447155294
# cost after 14600 epochs is 0.26985705582457337
# cost after 14700 epochs is 0.26976581469452743
# cost after 14800 epochs is 0.26967650081524974
# cost after 14900 epochs is 0.2695891907329911
# cost after 15000 epochs is 0.2695033672839149
# cost after 15100 epochs is 0.26942042000795224
# cost after 15200 epochs is 0.2693382788149291
# cost after 15300 epochs is 0.269258317828391
# cost after 15400 epochs is 0.2691797570866739
# cost after 15500 epochs is 0.2691026653382641
# cost after 15600 epochs is 0.26902705317845604
# cost after 15700 epochs is 0.268952800663581
# cost after 15800 epochs is 0.268880878927407
# cost after 15900 epochs is 0.2688102382686301
# cost after 16000 epochs is 0.2687413844418399
# cost after 16100 epochs is 0.26867410509642536
# cost after 16200 epochs is 0.2686082972983451
# cost after 16300 epochs is 0.268543573065473
# cost after 16400 epochs is 0.26848046080931076
# cost after 16500 epochs is 0.26841832140898947
# cost after 16600 epochs is 0.2683575993516642
# cost after 16700 epochs is 0.26829789929001163
# cost after 16800 epochs is 0.2682393720580956
# cost after 16900 epochs is 0.2681822932202639
# cost after 17000 epochs is 0.2681266124517129
# cost after 17100 epochs is 0.2680718518982352
# cost after 17200 epochs is 0.26801895946510385
# cost after 17300 epochs is 0.2679656832900097
# cost after 17400 epochs is 0.26791440385239634
# cost after 17500 epochs is 0.2678634891344761
# cost after 17600 epochs is 0.26781354336639
# cost after 17700 epochs is 0.2677645042937737
# cost after 17800 epochs is 0.2677176540849455
# cost after 17900 epochs is 0.26767019858414254
# cost after 18000 epochs is 0.2676249213916453
# cost after 18100 epochs is 0.2675795383383679
# cost after 18200 epochs is 0.26753627575053807
# cost after 18300 epochs is 0.26749219913577393
# cost after 18400 epochs is 0.26745033910661176
# cost after 18500 epochs is 0.2674082423348026
# cost after 18600 epochs is 0.26736770249221686
# cost after 18700 epochs is 0.2673277805842119
# cost after 18800 epochs is 0.26728970782037453
# cost after 18900 epochs is 0.26725140158656946
# cost after 19000 epochs is 0.26721352720133396
# cost after 19100 epochs is 0.2671765560441626
# cost after 19200 epochs is 0.2671399948423757
# cost after 19300 epochs is 0.26710485085858143
# cost after 19400 epochs is 0.26706985949293605
# cost after 19500 epochs is 0.26703622815547523
# cost after 19600 epochs is 0.26700277751400747
# cost after 19700 epochs is 0.266969280247461
# cost after 19800 epochs is 0.2669364009444557
# cost after 19900 epochs is 0.2669052968202123
# cost after 20000 epochs is 0.2668737424812812
# cost after 20100 epochs is 0.2668429865013997
# cost after 20200 epochs is 0.26681307204104254
# cost after 20300 epochs is 0.2667835897309388
# cost after 20400 epochs is 0.2667549052138518
# cost after 20500 epochs is 0.26672573184208453
# cost after 20600 epochs is 0.26669749787350766
# cost after 20700 epochs is 0.26667098775854875
# cost after 20800 epochs is 0.26664376656547356
# cost after 20900 epochs is 0.2666160212047982
# cost after 21000 epochs is 0.26659038746441516
# cost after 21100 epochs is 0.26656397923700753
# cost after 21200 epochs is 0.26653912305758537
# cost after 21300 epochs is 0.26651331172026743
# cost after 21400 epochs is 0.2664893219215928
# cost after 21500 epochs is 0.2664646511775507
# cost after 21600 epochs is 0.26644078422487283
# cost after 21700 epochs is 0.26641738390747116
# cost after 21800 epochs is 0.26639243724656514
# cost after 21900 epochs is 0.26636830460273103
# cost after 22000 epochs is 0.2663446153812869
# cost after 22100 epochs is 0.26632097604609584
# cost after 22200 epochs is 0.26629886387898993
# cost after 22300 epochs is 0.26627654268520573
# cost after 22400 epochs is 0.26625573773249944
# cost after 22500 epochs is 0.26623505101275885
# cost after 22600 epochs is 0.2662149807158443
# cost after 22700 epochs is 0.26619545365110575
# cost after 22800 epochs is 0.26617548374320976
# cost after 22900 epochs is 0.26615550104966884
# cost after 23000 epochs is 0.26613671986886994
# cost after 23100 epochs is 0.26611700557167806
# cost after 23200 epochs is 0.26609734590570744
# cost after 23300 epochs is 0.2660779025514906
# cost after 23400 epochs is 0.26605906784558186
# cost after 23500 epochs is 0.2660415628447046
# cost after 23600 epochs is 0.26602294988509734
# cost after 23700 epochs is 0.26600593952997875
# cost after 23800 epochs is 0.26599048338855125
# cost after 23900 epochs is 0.26597353352426323
# cost after 24000 epochs is 0.26595732015958795
# cost after 24100 epochs is 0.2659410818590416
# cost after 24200 epochs is 0.2659255424487623
# cost after 24300 epochs is 0.26591014754036746
# cost after 24400 epochs is 0.265894513885522
# cost after 24500 epochs is 0.26588014786571096
# cost after 24600 epochs is 0.26586541264164865
# cost after 24700 epochs is 0.2658515100512331
# cost after 24800 epochs is 0.26583685915313515
# cost after 24900 epochs is 0.26582276191782445
# cost after 25000 epochs is 0.26580859987814565
# cost after 25100 epochs is 0.2657947227850162
# cost after 25200 epochs is 0.26578116213040504
# cost after 25300 epochs is 0.2657682859781519
# cost after 25400 epochs is 0.26575626793963697
# cost after 25500 epochs is 0.2657433318062605
# cost after 25600 epochs is 0.2657291017596596
# cost after 25700 epochs is 0.2657173643492939
# cost after 25800 epochs is 0.2657050789089559
# cost after 25900 epochs is 0.26569196634629577
# cost after 26000 epochs is 0.2656796590841109
# cost after 26100 epochs is 0.26566771407098905
# cost after 26200 epochs is 0.26565637627256056
# cost after 26300 epochs is 0.2656438308537864
# cost after 26400 epochs is 0.2656325020699184
# cost after 26500 epochs is 0.2656224822731486
# cost after 26600 epochs is 0.2656100075850214
# cost after 26700 epochs is 0.26559922298406735
# cost after 26800 epochs is 0.2655893235339733
# cost after 26900 epochs is 0.26557726391622377
# cost after 27000 epochs is 0.26556677739433027
# cost after 27100 epochs is 0.2655571524089507
# cost after 27200 epochs is 0.26554645502941676
# cost after 27300 epochs is 0.26553695647095055
# cost after 27400 epochs is 0.2655260492458879
# cost after 27500 epochs is 0.2655156468890994
# cost after 27600 epochs is 0.2655055144671104
# cost after 27700 epochs is 0.2654960570474154
# cost after 27800 epochs is 0.2654874058811748
# cost after 27900 epochs is 0.26547692681699564
# cost after 28000 epochs is 0.26546761505342076
# cost after 28100 epochs is 0.2654581759192966
# cost after 28200 epochs is 0.26545068281116246
# cost after 28300 epochs is 0.2654408962008647
# cost after 28400 epochs is 0.2654312028019353
# cost after 28500 epochs is 0.265422840826612
# cost after 28600 epochs is 0.2654137624678533
# cost after 28700 epochs is 0.2654059200333615
# cost after 28800 epochs is 0.265397271539072
# cost after 28900 epochs is 0.2653881518748908
# cost after 29000 epochs is 0.2653796654223687
# cost after 29100 epochs is 0.26537134133697765
# cost after 29200 epochs is 0.26536309668073044
# cost after 29300 epochs is 0.26535508488980797
# cost after 29400 epochs is 0.26534745644628355
# cost after 29500 epochs is 0.2653405876784301
# cost after 29600 epochs is 0.2653318002687933
# cost after 29700 epochs is 0.2653235958827929
# cost after 29800 epochs is 0.26531629668019197
# cost after 29900 epochs is 0.26530932659510387
# Train accuracy is: 0.9289099526066351
# Test accuracy is: 0.94

# %%
AL, cache = forward_prop(X_train, parameters)
gradients = back_prop_with_regularization(X_train, Y_train, cache, lambd = 0.7)
difference = regularized_gradient_checker(X_train, Y_train, parameters, gradients, lambd = 0.7)
# Out:
# gradient using grad checker is[3.59268171e-05]
# gradient using back prop is[3.59269354e-05]
# gradient using grad checker is[-7.15436044e-05]
# gradient using back prop is[-7.15433822e-05]
# gradient using grad checker is[-0.00012833]
# gradient using back prop is[-0.00012833]
# gradient using grad checker is[-0.00011542]
# gradient using back prop is[-0.00011542]
# gradient using grad checker is[1.27342581e-06]
# gradient using back prop is[1.27313354e-06]
# gradient using grad checker is[-5.60618219e-05]
# gradient using back prop is[-5.60616475e-05]
# gradient using grad checker is[5.69411185e-05]
# gradient using back prop is[5.69404767e-05]
# gradient using grad checker is[-7.23887617e-05]
# gradient using back prop is[-7.23888065e-05]
# gradient using grad checker is[4.58022509e-05]
# gradient using back prop is[4.58018137e-05]
# gradient using grad checker is[-7.23451854e-05]
# gradient using back prop is[-7.23452543e-05]
# gradient using grad checker is[-0.00037767]
# gradient using back prop is[-0.00037767]
# gradient using grad checker is[6.15849038e-05]
# gradient using back prop is[6.15849388e-05]
# gradient using grad checker is[0.0014544]
# gradient using back prop is[0.0014544]
# gradient using grad checker is[0.00142892]
# gradient using back prop is[0.00142892]
# gradient using grad checker is[4.17149648e-05]
# gradient using back prop is[4.17150439e-05]
# gradient using grad checker is[-0.00010161]
# gradient using back prop is[-0.00010161]
# gradient using grad checker is[4.60353977e-06]
# gradient using back prop is[4.6036084e-06]
# gradient using grad checker is[-0.00016985]
# gradient using back prop is[-0.00016985]
# gradient using grad checker is[0.00015424]
# gradient using back prop is[0.00015424]
# gradient using grad checker is[-0.00018069]
# gradient using back prop is[-0.00018069]
# gradient using grad checker is[-0.00016546]
# gradient using back prop is[-0.00016546]
# gradient using grad checker is[-0.00010111]
# gradient using back prop is[-0.00010111]
# gradient using grad checker is[-0.00044116]
# gradient using back prop is[-0.00044116]
# gradient using grad checker is[3.95078414e-05]
# gradient using back prop is[3.95080988e-05]
# gradient using grad checker is[-0.00013282]
# gradient using back prop is[-0.00013282]
# gradient using grad checker is[-0.00017675]
# gradient using back prop is[-0.00017675]
# gradient using grad checker is[0.00018899]
# gradient using back prop is[0.00018899]
# gradient using grad checker is[2.25069963e-06]
# gradient using back prop is[2.25099734e-06]
# gradient using grad checker is[8.62826477e-05]
# gradient using back prop is[8.62826928e-05]
# gradient using grad checker is[0.00011901]
# gradient using back prop is[0.00011901]
# gradient using grad checker is[0.00128017]
# gradient using back prop is[0.00128017]
# gradient using grad checker is[0.00127879]
# gradient using back prop is[0.00127879]
# gradient using grad checker is[-8.15375545e-05]
# gradient using back prop is[-8.15376152e-05]
# gradient using grad checker is[-7.66078867e-05]
# gradient using back prop is[-7.66080362e-05]
# gradient using grad checker is[-0.00019309]
# gradient using back prop is[-0.00019309]
# gradient using grad checker is[-0.00016165]
# gradient using back prop is[-0.00016165]
# gradient using grad checker is[-0.00025004]
# gradient using back prop is[-0.00025004]
# gradient using grad checker is[-6.57329746e-05]
# gradient using back prop is[-6.57333972e-05]
# gradient using grad checker is[-0.00042164]
# gradient using back prop is[-0.00042164]
# gradient using grad checker is[3.40896755e-05]
# gradient using back prop is[3.40895204e-05]
# gradient using grad checker is[-0.0002367]
# gradient using back prop is[-0.0002367]
# gradient using grad checker is[-0.00033685]
# gradient using back prop is[-0.00033685]
# gradient using grad checker is[-3.60322883e-06]
# gradient using back prop is[-3.60321148e-06]
# gradient using grad checker is[-0.00019185]
# gradient using back prop is[-0.00019185]
# gradient using grad checker is[-8.0367657e-05]
# gradient using back prop is[-8.036789e-05]
# gradient using grad checker is[-4.44730364e-05]
# gradient using back prop is[-4.44729369e-05]
# gradient using grad checker is[-9.15489906e-05]
# gradient using back prop is[-9.15489691e-05]
# gradient using grad checker is[-7.09368675e-05]
# gradient using back prop is[-7.09371322e-05]
# gradient using grad checker is[-0.00032029]
# gradient using back prop is[-0.00032029]
# gradient using grad checker is[-0.00019377]
# gradient using back prop is[-0.00019377]
# gradient using grad checker is[0.00229508]
# gradient using back prop is[0.00229508]
# gradient using grad checker is[-0.00043675]
# gradient using back prop is[-0.00043675]
# gradient using grad checker is[-0.00067735]
# gradient using back prop is[-0.00067735]
# gradient using grad checker is[0.00017547]
# gradient using back prop is[0.00017547]
# gradient using grad checker is[0.0001411]
# gradient using back prop is[0.0001411]
# gradient using grad checker is[0.00075943]
# gradient using back prop is[0.00075943]
# gradient using grad checker is[-0.0050021]
# gradient using back prop is[-0.0050021]
# gradient using grad checker is[0.00048521]
# gradient using back prop is[0.00048521]
# gradient using grad checker is[-0.00171582]
# gradient using back prop is[-0.00171582]
# gradient using grad checker is[-3.31226713e-05]
# gradient using back prop is[-3.31226257e-05]
# gradient using grad checker is[-0.00055271]
# gradient using back prop is[-0.00055271]
# gradient using grad checker is[0.001339]
# gradient using back prop is[0.001339]
# gradient using grad checker is[-0.00031913]
# gradient using back prop is[-0.00031913]
# gradient using grad checker is[0.0004929]
# gradient using back prop is[0.0004929]
# gradient using grad checker is[-0.00011706]
# gradient using back prop is[-0.00011706]
# gradient using grad checker is[-0.00438737]
# gradient using back prop is[-0.00438737]
# gradient using grad checker is[-6.63635813e-06]
# gradient using back prop is[-6.63627108e-06]
# gradient using grad checker is[-0.00074232]
# gradient using back prop is[-0.00074232]
# gradient using grad checker is[0.0003199]
# gradient using back prop is[0.0003199]
# gradient using grad checker is[0.00126213]
# gradient using back prop is[0.00126213]
# gradient using grad checker is[-0.00182475]
# gradient using back prop is[-0.00182475]
# gradient using grad checker is[-0.00189716]
# gradient using back prop is[-0.00189716]
# gradient using grad checker is[0.00015426]
# gradient using back prop is[0.00015426]
# gradient using grad checker is[-0.00028039]
# gradient using back prop is[-0.00028039]
# gradient using grad checker is[-0.00105903]
# gradient using back prop is[-0.00105903]
# gradient using grad checker is[4.90921193e-05]
# gradient using back prop is[4.909187e-05]
# gradient using grad checker is[7.09132753e-05]
# gradient using back prop is[7.09131746e-05]
# gradient using grad checker is[3.76923492e-05]
# gradient using back prop is[3.76921585e-05]
# gradient using grad checker is[0.00010223]
# gradient using back prop is[0.00010223]
# gradient using grad checker is[0.00011799]
# gradient using back prop is[0.00011799]
# gradient using grad checker is[-0.00013952]
# gradient using back prop is[-0.00013952]
# gradient using grad checker is[0.00011753]
# gradient using back prop is[0.00011753]
# gradient using grad checker is[5.25191002e-06]
# gradient using back prop is[5.25197994e-06]
# gradient using grad checker is[-1.11280429e-05]
# gradient using back prop is[-1.11282045e-05]
# gradient using grad checker is[-6.31500408e-05]
# gradient using back prop is[-6.3149985e-05]
# gradient using grad checker is[7.03864744e-05]
# gradient using back prop is[7.03863474e-05]
# gradient using grad checker is[-8.14009971e-05]
# gradient using back prop is[-8.14010053e-05]
# gradient using grad checker is[2.27315389e-05]
# gradient using back prop is[2.27313491e-05]
# gradient using grad checker is[0.00015265]
# gradient using back prop is[0.00015265]
# gradient using grad checker is[4.00873779e-06]
# gradient using back prop is[4.00876831e-06]
# gradient using grad checker is[8.48537907e-05]
# gradient using back prop is[8.48543224e-05]
# gradient using grad checker is[-2.76692558e-05]
# gradient using back prop is[-2.7669473e-05]
# gradient using grad checker is[-1.10658704e-05]
# gradient using back prop is[-1.1065793e-05]
# gradient using grad checker is[5.0606741e-06]
# gradient using back prop is[5.06047497e-06]
# gradient using grad checker is[-4.42962333e-05]
# gradient using back prop is[-4.42961057e-05]
# gradient using grad checker is[-3.16657811e-05]
# gradient using back prop is[-3.16656069e-05]
# gradient using grad checker is[6.62087052e-05]
# gradient using back prop is[6.62087042e-05]
# gradient using grad checker is[-1.12410081e-06]
# gradient using back prop is[-1.12421538e-06]
# gradient using grad checker is[8.17118595e-05]
# gradient using back prop is[8.17116917e-05]
# gradient using grad checker is[4.41172099e-05]
# gradient using back prop is[4.41172059e-05]
# gradient using grad checker is[2.08386086e-05]
# gradient using back prop is[2.08386606e-05]
# gradient using grad checker is[5.98701644e-05]
# gradient using back prop is[5.98701825e-05]
# gradient using grad checker is[2.30515607e-05]
# gradient using back prop is[2.30513716e-05]
# gradient using grad checker is[-0.00012316]
# gradient using back prop is[-0.00012316]
# gradient using grad checker is[1.07064357e-05]
# gradient using back prop is[1.07067117e-05]
# gradient using grad checker is[3.55299123e-05]
# gradient using back prop is[3.55295957e-05]
# gradient using grad checker is[-1.78004833e-05]
# gradient using back prop is[-1.78003295e-05]
# gradient using grad checker is[-4.92694774e-05]
# gradient using back prop is[-4.9269641e-05]
# gradient using grad checker is[-1.39449563e-05]
# gradient using back prop is[-1.39450402e-05]
# gradient using grad checker is[2.41495712e-05]
# gradient using back prop is[2.41492445e-05]
# gradient using grad checker is[4.29511982e-05]
# gradient using back prop is[4.29513669e-05]
# gradient using grad checker is[0.00012926]
# gradient using back prop is[0.00012926]
# gradient using grad checker is[-3.8246073e-05]
# gradient using back prop is[-3.82461757e-05]
# gradient using grad checker is[-0.00024273]
# gradient using back prop is[-0.00024273]
# gradient using grad checker is[-7.59139973e-05]
# gradient using back prop is[-7.59138526e-05]
# gradient using grad checker is[-5.64845393e-05]
# gradient using back prop is[-5.64842989e-05]
# gradient using grad checker is[3.09613446e-05]
# gradient using back prop is[3.09613271e-05]
# gradient using grad checker is[-7.72187869e-06]
# gradient using back prop is[-7.72219333e-06]
# gradient using grad checker is[9.13633058e-05]
# gradient using back prop is[9.13632021e-05]
# gradient using grad checker is[0.00010024]
# gradient using back prop is[0.00010024]
# gradient using grad checker is[1.73405734e-05]
# gradient using back prop is[1.73406001e-05]
# gradient using grad checker is[5.98390781e-05]
# gradient using back prop is[5.98393447e-05]
# gradient using grad checker is[-3.58735264e-05]
# gradient using back prop is[-3.58733984e-05]
# gradient using grad checker is[-1.48206447e-05]
# gradient using back prop is[-1.48203994e-05]
# gradient using grad checker is[0.00010035]
# gradient using back prop is[0.00010035]
# gradient using grad checker is[3.06940584e-05]
# gradient using back prop is[3.06941362e-05]
# gradient using grad checker is[-5.87888072e-05]
# gradient using back prop is[-5.87889061e-05]
# gradient using grad checker is[-1.09928733e-05]
# gradient using back prop is[-1.0992622e-05]
# gradient using grad checker is[1.44539936e-05]
# gradient using back prop is[1.4454327e-05]
# gradient using grad checker is[4.8789861e-05]
# gradient using back prop is[4.87903004e-05]
# gradient using grad checker is[-2.8033964e-05]
# gradient using back prop is[-2.80338456e-05]
# gradient using grad checker is[-3.32064931e-05]
# gradient using back prop is[-3.32064678e-05]
# gradient using grad checker is[-9.33086941e-06]
# gradient using back prop is[-9.33086373e-06]
# gradient using grad checker is[2.46030973e-05]
# gradient using back prop is[2.46030774e-05]
# gradient using grad checker is[1.91921479e-05]
# gradient using back prop is[1.91924073e-05]
# gradient using grad checker is[-4.31796265e-05]
# gradient using back prop is[-4.31794798e-05]
# gradient using grad checker is[-7.18966553e-05]
# gradient using back prop is[-7.18967241e-05]
# gradient using grad checker is[-3.6919634e-05]
# gradient using back prop is[-3.69198503e-05]
# gradient using grad checker is[2.89027136e-05]
# gradient using back prop is[2.89030451e-05]
# gradient using grad checker is[-2.59486876e-05]
# gradient using back prop is[-2.59487234e-05]
# gradient using grad checker is[2.26205166e-05]
# gradient using back prop is[2.26206787e-05]
# gradient using grad checker is[6.67549349e-06]
# gradient using back prop is[6.67522522e-06]
# gradient using grad checker is[1.6397439e-05]
# gradient using back prop is[1.63972097e-05]
# gradient using grad checker is[-7.22497062e-05]
# gradient using back prop is[-7.22493529e-05]
# gradient using grad checker is[2.29816166e-07]
# gradient using back prop is[2.29729131e-07]
# gradient using grad checker is[-3.00726111e-05]
# gradient using back prop is[-3.00723907e-05]
# gradient using grad checker is[1.48189794e-05]
# gradient using back prop is[1.48190163e-05]
# gradient using grad checker is[-3.94204114e-05]
# gradient using back prop is[-3.94203573e-05]
# gradient using grad checker is[-9.54097912e-05]
# gradient using back prop is[-9.54097668e-05]
# gradient using grad checker is[-2.20834462e-05]
# gradient using back prop is[-2.20836622e-05]
# gradient using grad checker is[-3.27057825e-05]
# gradient using back prop is[-3.27057335e-05]
# gradient using grad checker is[2.54890553e-05]
# gradient using back prop is[2.54891156e-05]
# gradient using grad checker is[3.53900242e-05]
# gradient using back prop is[3.5389969e-05]
# gradient using grad checker is[-0.00057296]
# gradient using back prop is[-0.00057296]
# gradient using grad checker is[-0.00053176]
# gradient using back prop is[-0.00053176]
# gradient using grad checker is[0.00018707]
# gradient using back prop is[0.00018707]
# gradient using grad checker is[-0.00019655]
# gradient using back prop is[-0.00019655]
# gradient using grad checker is[-0.00010453]
# gradient using back prop is[-0.00010453]
# gradient using grad checker is[1.508349e-05]
# gradient using back prop is[1.50836027e-05]
# gradient using grad checker is[3.69818065e-05]
# gradient using back prop is[3.69818007e-05]
# gradient using grad checker is[-0.00028135]
# gradient using back prop is[-0.00028135]
# gradient using grad checker is[-0.0001037]
# gradient using back prop is[-0.0001037]
# gradient using grad checker is[-6.57249255e-05]
# gradient using back prop is[-6.57250134e-05]
# gradient using grad checker is[-0.00088725]
# gradient using back prop is[-0.00088725]
# gradient using grad checker is[-0.00013199]
# gradient using back prop is[-0.000132]
# gradient using grad checker is[-0.00028919]
# gradient using back prop is[-0.00028919]
# gradient using grad checker is[0.00012658]
# gradient using back prop is[0.00012658]
# gradient using grad checker is[6.29080121e-05]
# gradient using back prop is[6.29076784e-05]
# gradient using grad checker is[0.00019703]
# gradient using back prop is[0.00019703]
# gradient using grad checker is[-0.00010021]
# gradient using back prop is[-0.00010021]
# gradient using grad checker is[8.98159325e-05]
# gradient using back prop is[8.98157227e-05]
# gradient using grad checker is[6.12734863e-05]
# gradient using back prop is[6.1273635e-05]
# gradient using grad checker is[2.2605251e-05]
# gradient using back prop is[2.26051881e-05]
# gradient using grad checker is[-5.11221621e-05]
# gradient using back prop is[-5.11220229e-05]
# gradient using grad checker is[-0.00030346]
# gradient using back prop is[-0.00030346]
# gradient using grad checker is[-4.09680623e-05]
# gradient using back prop is[-4.09680281e-05]
# gradient using grad checker is[4.98753816e-05]
# gradient using back prop is[4.98753731e-05]
# gradient using grad checker is[-5.79802872e-05]
# gradient using back prop is[-5.7980455e-05]
# gradient using grad checker is[2.50688359e-06]
# gradient using back prop is[2.50712074e-06]
# gradient using grad checker is[-1.27675648e-07]
# gradient using back prop is[-1.27854982e-07]
# gradient using grad checker is[2.07223128e-05]
# gradient using back prop is[2.07221899e-05]
# gradient using grad checker is[-3.40863449e-05]
# gradient using back prop is[-3.40864304e-05]
# gradient using grad checker is[-1.81438198e-06]
# gradient using back prop is[-1.81440029e-06]
# gradient using grad checker is[-7.35300709e-06]
# gradient using back prop is[-7.3530404e-06]
# gradient using grad checker is[4.66154892e-05]
# gradient using back prop is[4.66156654e-05]
# gradient using grad checker is[-3.74980602e-05]
# gradient using back prop is[-3.74981039e-05]
# gradient using grad checker is[3.33510997e-06]
# gradient using back prop is[3.33492276e-06]
# gradient using grad checker is[-1.25510713e-05]
# gradient using back prop is[-1.25508904e-05]
# gradient using grad checker is[-6.173978e-05]
# gradient using back prop is[-6.17397565e-05]
# gradient using grad checker is[0.00012686]
# gradient using back prop is[0.00012686]
# gradient using grad checker is[-2.98761016e-06]
# gradient using back prop is[-2.98766327e-06]
# gradient using grad checker is[-7.05269176e-05]
# gradient using back prop is[-7.05270692e-05]
# gradient using grad checker is[6.56338872e-05]
# gradient using back prop is[6.56338209e-05]
# gradient using grad checker is[-5.109968e-05]
# gradient using back prop is[-5.10996343e-05]
# gradient using grad checker is[1.74116277e-05]
# gradient using back prop is[1.74117333e-05]
# gradient using grad checker is[4.15945056e-05]
# gradient using back prop is[4.15944165e-05]
# gradient using grad checker is[-3.15539261e-05]
# gradient using back prop is[-3.15539311e-05]
# gradient using grad checker is[-2.06534789e-05]
# gradient using back prop is[-2.06533771e-05]
# gradient using grad checker is[-2.53852495e-05]
# gradient using back prop is[-2.53851457e-05]
# gradient using grad checker is[-5.64964742e-06]
# gradient using back prop is[-5.6495507e-06]
# gradient using grad checker is[-7.99352251e-05]
# gradient using back prop is[-7.99352194e-05]
# gradient using grad checker is[-6.06242834e-05]
# gradient using back prop is[-6.06244404e-05]
# gradient using grad checker is[-7.32525152e-06]
# gradient using back prop is[-7.32487915e-06]
# gradient using grad checker is[3.6178005e-05]
# gradient using back prop is[3.61778346e-05]
# gradient using grad checker is[1.81152315e-05]
# gradient using back prop is[1.81150531e-05]
# gradient using grad checker is[8.81023032e-05]
# gradient using back prop is[8.81023234e-05]
# gradient using grad checker is[3.35825812e-05]
# gradient using back prop is[3.35827319e-05]
# gradient using grad checker is[-2.42345033e-05]
# gradient using back prop is[-2.42344939e-05]
# gradient using grad checker is[-7.78571652e-06]
# gradient using back prop is[-7.78564168e-06]
# gradient using grad checker is[-9.63515379e-05]
# gradient using back prop is[-9.63513761e-05]
# gradient using grad checker is[-4.94881913e-05]
# gradient using back prop is[-4.94879501e-05]
# gradient using grad checker is[-6.1468608e-05]
# gradient using back prop is[-6.14683548e-05]
# gradient using grad checker is[9.52987689e-06]
# gradient using back prop is[9.5296679e-06]
# gradient using grad checker is[1.09376397e-05]
# gradient using back prop is[1.09377679e-05]
# gradient using grad checker is[-2.65709676e-05]
# gradient using back prop is[-2.6571243e-05]
# gradient using grad checker is[-2.5920377e-05]
# gradient using back prop is[-2.59201701e-05]
# gradient using grad checker is[-7.47316098e-05]
# gradient using back prop is[-7.47314801e-05]
# gradient using grad checker is[-9.04637476e-06]
# gradient using back prop is[-9.04649838e-06]
# gradient using grad checker is[9.94093696e-06]
# gradient using back prop is[9.94090789e-06]
# gradient using grad checker is[9.25481913e-06]
# gradient using back prop is[9.25477551e-06]
# gradient using grad checker is[-3.13910009e-05]
# gradient using back prop is[-3.13908464e-05]
# gradient using grad checker is[9.21146492e-05]
# gradient using back prop is[9.21146929e-05]
# gradient using grad checker is[5.55810953e-05]
# gradient using back prop is[5.55809868e-05]
# gradient using grad checker is[-5.46396262e-06]
# gradient using back prop is[-5.46395511e-06]
# gradient using grad checker is[-2.88380431e-05]
# gradient using back prop is[-2.88382038e-05]
# gradient using grad checker is[-4.44311254e-06]
# gradient using back prop is[-4.44312219e-06]
# gradient using grad checker is[6.02476402e-05]
# gradient using back prop is[6.02477834e-05]
# gradient using grad checker is[-1.53604907e-05]
# gradient using back prop is[-1.53602164e-05]
# gradient using grad checker is[7.95211119e-05]
# gradient using back prop is[7.95210659e-05]
# gradient using grad checker is[9.23383592e-05]
# gradient using back prop is[9.23384342e-05]
# gradient using grad checker is[-6.37481734e-05]
# gradient using back prop is[-6.37479972e-05]
# gradient using grad checker is[0.00011162]
# gradient using back prop is[0.00011162]
# gradient using grad checker is[0.00010189]
# gradient using back prop is[0.00010189]
# gradient using grad checker is[5.23403543e-05]
# gradient using back prop is[5.23398778e-05]
# gradient using grad checker is[2.66364708e-05]
# gradient using back prop is[2.66366371e-05]
# gradient using grad checker is[-2.35009234e-05]
# gradient using back prop is[-2.35007622e-05]
# gradient using grad checker is[-5.99084671e-05]
# gradient using back prop is[-5.99087282e-05]
# gradient using grad checker is[1.28960731e-05]
# gradient using back prop is[1.28961181e-05]
# gradient using grad checker is[0.0001775]
# gradient using back prop is[0.0001775]
# gradient using grad checker is[2.3872293e-05]
# gradient using back prop is[2.38723962e-05]
# gradient using grad checker is[6.81854573e-05]
# gradient using back prop is[6.81853456e-05]
# gradient using grad checker is[1.51165191e-05]
# gradient using back prop is[1.51163473e-05]
# gradient using grad checker is[6.85879131e-05]
# gradient using back prop is[6.8588214e-05]
# gradient using grad checker is[8.68222161e-06]
# gradient using back prop is[8.68169389e-06]
# gradient using grad checker is[-0.00015023]
# gradient using back prop is[-0.00015023]
# gradient using grad checker is[-4.14382417e-05]
# gradient using back prop is[-4.14386077e-05]
# gradient using grad checker is[3.71519482e-05]
# gradient using back prop is[3.71517728e-05]
# gradient using grad checker is[-1.91829885e-05]
# gradient using back prop is[-1.91831794e-05]
# gradient using grad checker is[6.32519037e-05]
# gradient using back prop is[6.32517794e-05]
# gradient using grad checker is[-2.05579997e-05]
# gradient using back prop is[-2.05580867e-05]
# gradient using grad checker is[0.00010862]
# gradient using back prop is[0.00010862]
# gradient using grad checker is[-9.99647587e-05]
# gradient using back prop is[-9.99647848e-05]
# gradient using grad checker is[-8.06021916e-07]
# gradient using back prop is[-8.06139548e-07]
# gradient using grad checker is[7.79420972e-05]
# gradient using back prop is[7.79420258e-05]
# gradient using grad checker is[3.24926197e-05]
# gradient using back prop is[3.2492394e-05]
# gradient using grad checker is[-1.03528297e-05]
# gradient using back prop is[-1.03531831e-05]
# gradient using grad checker is[6.07172645e-05]
# gradient using back prop is[6.0717438e-05]
# gradient using grad checker is[3.05588888e-06]
# gradient using back prop is[3.05560702e-06]
# gradient using grad checker is[4.2791326e-05]
# gradient using back prop is[4.27917262e-05]
# gradient using grad checker is[0.00015215]
# gradient using back prop is[0.00015215]
# gradient using grad checker is[-1.42641454e-05]
# gradient using back prop is[-1.42643568e-05]
# gradient using grad checker is[3.3372749e-05]
# gradient using back prop is[3.3373055e-05]
# gradient using grad checker is[-2.82254775e-05]
# gradient using back prop is[-2.82254545e-05]
# gradient using grad checker is[9.73535141e-05]
# gradient using back prop is[9.73534929e-05]
# gradient using grad checker is[-6.71276923e-05]
# gradient using back prop is[-6.71277517e-05]
# gradient using grad checker is[1.87702631e-05]
# gradient using back prop is[1.87699747e-05]
# gradient using grad checker is[0.00011555]
# gradient using back prop is[0.00011555]
# gradient using grad checker is[8.98209285e-05]
# gradient using back prop is[8.98211316e-05]
# gradient using grad checker is[3.84117738e-05]
# gradient using back prop is[3.84117314e-05]
# gradient using grad checker is[7.06232295e-05]
# gradient using back prop is[7.06232621e-05]
# gradient using grad checker is[1.42449941e-05]
# gradient using back prop is[1.42449313e-05]
# gradient using grad checker is[5.58914026e-05]
# gradient using back prop is[5.58916111e-05]
# gradient using grad checker is[0.00010392]
# gradient using back prop is[0.00010392]
# gradient using grad checker is[3.29145045e-05]
# gradient using back prop is[3.29142612e-05]
# gradient using grad checker is[-5.44125855e-05]
# gradient using back prop is[-5.44125408e-05]
# gradient using grad checker is[8.04112332e-05]
# gradient using back prop is[8.04112995e-05]
# gradient using grad checker is[-0.00011047]
# gradient using back prop is[-0.00011047]
# gradient using grad checker is[-2.77669554e-05]
# gradient using back prop is[-2.77667316e-05]
# gradient using grad checker is[6.21086516e-06]
# gradient using back prop is[6.2113534e-06]
# gradient using grad checker is[-4.91787167e-05]
# gradient using back prop is[-4.91786916e-05]
# gradient using grad checker is[-9.12797615e-06]
# gradient using back prop is[-9.12795388e-06]
# gradient using grad checker is[-3.12566639e-05]
# gradient using back prop is[-3.12563956e-05]
# gradient using grad checker is[-2.98880365e-05]
# gradient using back prop is[-2.98879271e-05]
# gradient using grad checker is[0.00012767]
# gradient using back prop is[0.00012767]
# gradient using grad checker is[3.25245386e-05]
# gradient using back prop is[3.25246614e-05]
# gradient using grad checker is[-6.88477053e-06]
# gradient using back prop is[-6.88471116e-06]
# gradient using grad checker is[5.59441382e-05]
# gradient using back prop is[5.59440511e-05]
# gradient using grad checker is[-1.39724343e-05]
# gradient using back prop is[-1.39722101e-05]
# gradient using grad checker is[3.12419535e-05]
# gradient using back prop is[3.12421113e-05]
# gradient using grad checker is[1.49588675e-05]
# gradient using back prop is[1.49588681e-05]
# gradient using grad checker is[7.50582929e-05]
# gradient using back prop is[7.50584775e-05]
# gradient using grad checker is[-6.9690087e-05]
# gradient using back prop is[-6.96900559e-05]
# gradient using grad checker is[3.52676222e-05]
# gradient using back prop is[3.52679587e-05]
# gradient using grad checker is[4.66127137e-06]
# gradient using back prop is[4.6612445e-06]
# gradient using grad checker is[-6.09157169e-05]
# gradient using back prop is[-6.09157572e-05]
# gradient using grad checker is[4.79863371e-05]
# gradient using back prop is[4.79865901e-05]
# gradient using grad checker is[-4.1608661e-05]
# gradient using back prop is[-4.16090414e-05]
# gradient using grad checker is[7.56272822e-05]
# gradient using back prop is[7.56272804e-05]
# gradient using grad checker is[2.13223883e-05]
# gradient using back prop is[2.13225008e-05]
# gradient using grad checker is[2.64288591e-05]
# gradient using back prop is[2.64287987e-05]
# gradient using grad checker is[1.82209803e-05]
# gradient using back prop is[1.82210528e-05]
# gradient using grad checker is[5.97843997e-05]
# gradient using back prop is[5.97845268e-05]
# gradient using grad checker is[-7.05430159e-05]
# gradient using back prop is[-7.05429653e-05]
# gradient using grad checker is[1.72120651e-05]
# gradient using back prop is[1.72118689e-05]
# gradient using grad checker is[-1.84702253e-05]
# gradient using back prop is[-1.84702564e-05]
# gradient using grad checker is[0.00011092]
# gradient using back prop is[0.00011092]
# gradient using grad checker is[-1.92759697e-05]
# gradient using back prop is[-1.92761726e-05]
# gradient using grad checker is[-3.93221566e-05]
# gradient using back prop is[-3.9322115e-05]
# gradient using grad checker is[-2.30016006e-05]
# gradient using back prop is[-2.30012868e-05]
# gradient using grad checker is[9.93913285e-05]
# gradient using back prop is[9.93912072e-05]
# gradient using grad checker is[0.00013359]
# gradient using back prop is[0.00013359]
# gradient using grad checker is[0.00013103]
# gradient using back prop is[0.00013103]
# gradient using grad checker is[-1.11577414e-06]
# gradient using back prop is[-1.11560819e-06]
# gradient using grad checker is[3.20199423e-05]
# gradient using back prop is[3.20199938e-05]
# gradient using grad checker is[3.61594088e-05]
# gradient using back prop is[3.61593989e-05]
# gradient using grad checker is[7.03515024e-05]
# gradient using back prop is[7.03516085e-05]
# gradient using grad checker is[-1.31517019e-05]
# gradient using back prop is[-1.315189e-05]
# gradient using grad checker is[-1.21819221e-05]
# gradient using back prop is[-1.21815762e-05]
# gradient using grad checker is[-1.40160106e-05]
# gradient using back prop is[-1.40158583e-05]
# gradient using grad checker is[7.78585529e-05]
# gradient using back prop is[7.78580072e-05]
# gradient using grad checker is[-5.00419151e-05]
# gradient using back prop is[-5.00414986e-05]
# gradient using grad checker is[3.49276164e-05]
# gradient using back prop is[3.49276035e-05]
# gradient using grad checker is[-5.11091169e-05]
# gradient using back prop is[-5.11091286e-05]
# gradient using grad checker is[8.05253086e-05]
# gradient using back prop is[8.05252592e-05]
# gradient using grad checker is[8.72973915e-05]
# gradient using back prop is[8.72978034e-05]
# gradient using grad checker is[-4.87868079e-05]
# gradient using back prop is[-4.87867776e-05]
# gradient using grad checker is[-4.88104002e-05]
# gradient using back prop is[-4.88104241e-05]
# gradient using grad checker is[-2.9014291e-05]
# gradient using back prop is[-2.90142624e-05]
# gradient using grad checker is[6.63291644e-05]
# gradient using back prop is[6.63291963e-05]
# gradient using grad checker is[-4.02536338e-05]
# gradient using back prop is[-4.02536873e-05]
# gradient using grad checker is[-7.07631176e-05]
# gradient using back prop is[-7.07631362e-05]
# gradient using grad checker is[-2.34146036e-06]
# gradient using back prop is[-2.34166242e-06]
# gradient using grad checker is[1.76908488e-05]
# gradient using back prop is[1.76909038e-05]
# gradient using grad checker is[-3.11403681e-05]
# gradient using back prop is[-3.11403109e-05]
# gradient using grad checker is[7.67275132e-05]
# gradient using back prop is[7.67272795e-05]
# gradient using grad checker is[1.13925536e-05]
# gradient using back prop is[1.13926415e-05]
# gradient using grad checker is[2.14644968e-05]
# gradient using back prop is[2.14645521e-05]
# gradient using grad checker is[-4.05342426e-05]
# gradient using back prop is[-4.0534426e-05]
# gradient using grad checker is[-1.88238314e-06]
# gradient using back prop is[-1.88236658e-06]
# gradient using grad checker is[-7.41573469e-06]
# gradient using back prop is[-7.41573073e-06]
# gradient using grad checker is[-0.00010766]
# gradient using back prop is[-0.00010766]
# gradient using grad checker is[1.36290979e-05]
# gradient using back prop is[1.36289593e-05]
# gradient using grad checker is[-8.50364223e-05]
# gradient using back prop is[-8.50364588e-05]
# gradient using grad checker is[-1.36390899e-06]
# gradient using back prop is[-1.36383985e-06]
# gradient using grad checker is[-6.98341385e-05]
# gradient using back prop is[-6.98341805e-05]
# gradient using grad checker is[9.56892898e-05]
# gradient using back prop is[9.56893611e-05]
# gradient using grad checker is[1.54581903e-05]
# gradient using back prop is[1.54580341e-05]
# gradient using grad checker is[4.08104106e-05]
# gradient using back prop is[4.08104046e-05]
# gradient using grad checker is[4.35418368e-05]
# gradient using back prop is[4.35418379e-05]
# gradient using grad checker is[-6.2753136e-05]
# gradient using back prop is[-6.27531686e-05]
# gradient using grad checker is[-0.00011001]
# gradient using back prop is[-0.00011001]
# gradient using grad checker is[-3.16541238e-05]
# gradient using back prop is[-3.1654056e-05]
# gradient using grad checker is[3.99480449e-05]
# gradient using back prop is[3.99480907e-05]
# gradient using grad checker is[-2.58792987e-06]
# gradient using back prop is[-2.58769465e-06]
# gradient using grad checker is[3.13987725e-05]
# gradient using back prop is[3.13987844e-05]
# gradient using grad checker is[4.43767245e-05]
# gradient using back prop is[4.43768693e-05]
# gradient using grad checker is[-7.07084391e-05]
# gradient using back prop is[-7.07085286e-05]
# gradient using grad checker is[1.13814513e-05]
# gradient using back prop is[1.13812946e-05]
# gradient using grad checker is[8.08764167e-05]
# gradient using back prop is[8.08766561e-05]
# gradient using grad checker is[-3.79479781e-05]
# gradient using back prop is[-3.79480397e-05]
# gradient using grad checker is[-9.8147046e-05]
# gradient using back prop is[-9.81472836e-05]
# gradient using grad checker is[-1.55575552e-05]
# gradient using back prop is[-1.5557496e-05]
# gradient using grad checker is[-2.67297295e-05]
# gradient using back prop is[-2.67298745e-05]
# gradient using grad checker is[1.30240263e-05]
# gradient using back prop is[1.30238559e-05]
# gradient using grad checker is[-4.35251835e-05]
# gradient using back prop is[-4.3525193e-05]
# gradient using grad checker is[4.29822844e-06]
# gradient using back prop is[4.29808496e-06]
# gradient using grad checker is[-0.0001091]
# gradient using back prop is[-0.00010911]
# gradient using grad checker is[2.10262363e-05]
# gradient using back prop is[2.10262698e-05]
# gradient using grad checker is[6.77827239e-05]
# gradient using back prop is[6.7782759e-05]
# gradient using grad checker is[5.60518298e-05]
# gradient using back prop is[5.60518612e-05]
# gradient using grad checker is[-7.17997883e-05]
# gradient using back prop is[-7.17999478e-05]
# gradient using grad checker is[2.94764213e-07]
# gradient using back prop is[2.94602588e-07]
# gradient using grad checker is[-0.00014594]
# gradient using back prop is[-0.00014594]
# gradient using grad checker is[1.32927003e-05]
# gradient using back prop is[1.32927721e-05]
# gradient using grad checker is[-5.19750909e-06]
# gradient using back prop is[-5.19770279e-06]
# gradient using grad checker is[-0.00020219]
# gradient using back prop is[-0.00020219]
# gradient using grad checker is[-0.00018975]
# gradient using back prop is[-0.00018975]
# gradient using grad checker is[-6.15685281e-05]
# gradient using back prop is[-6.1568738e-05]
# gradient using grad checker is[-0.00132689]
# gradient using back prop is[-0.00132689]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-2.79551382e-05]
# gradient using back prop is[-2.7955003e-05]
# gradient using grad checker is[-0.00019379]
# gradient using back prop is[-0.00019379]
# gradient using grad checker is[-1.75831572e-05]
# gradient using back prop is[-1.75831627e-05]
# gradient using grad checker is[-2.05502282e-05]
# gradient using back prop is[-2.05506529e-05]
# gradient using grad checker is[-0.00030661]
# gradient using back prop is[-0.00030661]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-1.77724502e-05]
# gradient using back prop is[-1.77723261e-05]
# gradient using grad checker is[-3.7322645e-05]
# gradient using back prop is[-3.73227194e-05]
# gradient using grad checker is[-2.97506464e-05]
# gradient using back prop is[-2.97504888e-05]
# gradient using grad checker is[-4.74550954e-05]
# gradient using back prop is[-4.74551403e-05]
# gradient using grad checker is[-8.70414851e-07]
# gradient using back prop is[-8.70430156e-07]
# gradient using grad checker is[2.44135268e-05]
# gradient using back prop is[2.44133331e-05]
# gradient using grad checker is[-1.59150471e-06]
# gradient using back prop is[-1.59127225e-06]
# gradient using grad checker is[-0.00015181]
# gradient using back prop is[-0.00015181]
# gradient using grad checker is[5.12034859e-06]
# gradient using back prop is[5.12022526e-06]
# gradient using grad checker is[-1.70904957e-05]
# gradient using back prop is[-1.70906344e-05]
# gradient using grad checker is[-4.30766534e-07]
# gradient using back prop is[-4.30747884e-07]
# gradient using grad checker is[9.86849491e-05]
# gradient using back prop is[9.86849966e-05]
# gradient using grad checker is[-9.51996815e-05]
# gradient using back prop is[-9.51997231e-05]
# check your back prop..Error in back prop. Differnece is 2.0467588438791052e-07
