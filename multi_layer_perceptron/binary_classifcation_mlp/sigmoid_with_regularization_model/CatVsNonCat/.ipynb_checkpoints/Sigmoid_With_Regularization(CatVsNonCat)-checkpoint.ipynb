# %% [markdown]
# ##  Cat Vs. Non-Cat (binary class) Simple Feed-Forward Application ( With regularization, no MiniBatch)

# %%
import numpy as np
from Sigmoid_Necessary_Functions_With_Regularization import *
from Regularized_Gradient_Checker import *
from Load_Dataset import load_data
# Out:
# /Users/Apple/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
X_train, Y_train, X_test, Y_test, classes = load_data()

# %%
print('X_train has shape: ' +str(X_train.shape))
print('Y_train has shape: ' +str(Y_train.shape))
print('X_test has shape: ' +str(X_test.shape))
print('Y_test has shape: ' +str(Y_test.shape))
# Out:
# X_train has shape: (12288, 209)
# Y_train has shape: (1, 209)
# X_test has shape: (12288, 50)
# Y_test has shape: (1, 50)

# %%
parameters = regularized_model_sigmoid(X_train, Y_train, 0.005, 3000, [12288,25,12,1], lambd = 0.8)
train_accuracy = predict_accuracy(X_train, Y_train, parameters)
test_accuracy = predict_accuracy(X_test, Y_test, parameters)
print('Train accuracy is: '+str(train_accuracy))
print('Test accuracy is: '+str(test_accuracy))
# Out:
# cost after 0 epochs is 0.7901031824997761
# cost after 100 epochs is 0.6756334447199831
# cost after 200 epochs is 0.6172085630416745
# cost after 300 epochs is 0.5768832942702076
# cost after 400 epochs is 0.536547663811111
# cost after 500 epochs is 0.5114295013901504
# cost after 600 epochs is 0.46485040331314387
# cost after 700 epochs is 0.4583635831816809
# cost after 800 epochs is 0.4295678555266304
# cost after 900 epochs is 0.39751312101629854
# cost after 1000 epochs is 0.39796269979547083
# cost after 1100 epochs is 0.36375114770987527
# cost after 1200 epochs is 0.3516990029204626
# cost after 1300 epochs is 0.33716305374461053
# cost after 1400 epochs is 0.32772125747369396
# cost after 1500 epochs is 0.32794442357852205
# cost after 1600 epochs is 0.3127327257723792
# cost after 1700 epochs is 0.3054476671520071
# cost after 1800 epochs is 0.30444859633370014
# cost after 1900 epochs is 0.28989605637050553
# cost after 2000 epochs is 0.2870681886795987
# cost after 2100 epochs is 0.28278120424532444
# cost after 2200 epochs is 0.27290331976127247
# cost after 2300 epochs is 0.2622098629714668
# cost after 2400 epochs is 0.2642959621812788
# cost after 2500 epochs is 0.2598088721122631
# cost after 2600 epochs is 0.24803775492123026
# cost after 2700 epochs is 0.24509469235537165
# cost after 2800 epochs is 0.24025778690551974
# cost after 2900 epochs is 0.23571661804454536
# Train accuracy is: 1.0
# Test accuracy is: 0.6

# %% [markdown]
# ### checking my back prop

# %%
AL, cache = forward_prop(X_train, parameters)
gradients = back_prop_with_regularization(X_train, Y_train, cache, lambd = 0.8)
difference = regularized_gradient_checker(X_train, Y_train, parameters, gradients, lambd = 0.8)
# Out:
# gradient using grad checker is[-0.00336786]
# gradient using back prop is[-0.00336785]
# gradient using grad checker is[-0.00339673]
# gradient using back prop is[-0.00339673]
# gradient using grad checker is[-0.00295301]
# gradient using back prop is[-0.00295301]
# gradient using grad checker is[-0.00352933]
# gradient using back prop is[-0.00352933]
# gradient using grad checker is[-0.00358159]
# gradient using back prop is[-0.00358159]
# gradient using grad checker is[-0.00298565]
# gradient using back prop is[-0.00298565]
# gradient using grad checker is[-0.0034606]
# gradient using back prop is[-0.0034606]
# gradient using grad checker is[-0.00347026]
# gradient using back prop is[-0.00347026]
# gradient using grad checker is[-0.00280804]
# gradient using back prop is[-0.00280804]
# gradient using grad checker is[-0.00331454]
# gradient using back prop is[-0.00331454]
# gradient using grad checker is[-0.00334118]
# gradient using back prop is[-0.00334118]
# gradient using grad checker is[-0.00264961]
# gradient using back prop is[-0.00264961]
# gradient using grad checker is[-0.00314158]
# gradient using back prop is[-0.00314158]
# gradient using grad checker is[-0.00325806]
# gradient using back prop is[-0.00325806]
# gradient using grad checker is[-0.00253928]
# gradient using back prop is[-0.00253928]
# gradient using grad checker is[-0.00310029]
# gradient using back prop is[-0.00310029]
# gradient using grad checker is[-0.00317413]
# gradient using back prop is[-0.00317413]
# gradient using grad checker is[-0.00252792]
# gradient using back prop is[-0.00252792]
# gradient using grad checker is[-0.00349123]
# gradient using back prop is[-0.00349123]
# gradient using grad checker is[-0.00355708]
# gradient using back prop is[-0.00355708]
# gradient using grad checker is[-0.00290287]
# gradient using back prop is[-0.00290288]
# gradient using grad checker is[-0.00362811]
# gradient using back prop is[-0.00362811]
# gradient using grad checker is[-0.0035793]
# gradient using back prop is[-0.0035793]
# gradient using grad checker is[-0.00309249]
# gradient using back prop is[-0.00309249]
# gradient using grad checker is[-0.00364994]
# gradient using back prop is[-0.00364994]
# gradient using grad checker is[-0.00351024]
# gradient using back prop is[-0.00351024]
# gradient using grad checker is[-0.00290694]
# gradient using back prop is[-0.00290694]
# gradient using grad checker is[-0.00358512]
# gradient using back prop is[-0.00358512]
# gradient using grad checker is[-0.00358964]
# gradient using back prop is[-0.00358964]
# gradient using grad checker is[-0.00289477]
# gradient using back prop is[-0.00289477]
# gradient using grad checker is[-0.00345871]
# gradient using back prop is[-0.00345871]
# gradient using grad checker is[-0.00361744]
# gradient using back prop is[-0.00361744]
# gradient using grad checker is[-0.00280876]
# gradient using back prop is[-0.00280876]
# gradient using grad checker is[-0.0037427]
# gradient using back prop is[-0.0037427]
# gradient using grad checker is[-0.00370003]
# gradient using back prop is[-0.00370003]
# gradient using grad checker is[-0.00308245]
# gradient using back prop is[-0.00308245]
# gradient using grad checker is[-0.00388245]
# gradient using back prop is[-0.00388245]
# gradient using grad checker is[-0.00368184]
# gradient using back prop is[-0.00368185]
# gradient using grad checker is[-0.00312004]
# gradient using back prop is[-0.00312004]
# gradient using grad checker is[-0.0037729]
# gradient using back prop is[-0.0037729]
# gradient using grad checker is[-0.00366174]
# gradient using back prop is[-0.00366174]
# gradient using grad checker is[-0.0030594]
# gradient using back prop is[-0.0030594]
# gradient using grad checker is[-0.00363281]
# gradient using back prop is[-0.00363281]
# gradient using grad checker is[-0.0034704]
# gradient using back prop is[-0.0034704]
# gradient using grad checker is[-0.00293176]
# gradient using back prop is[-0.00293176]
# gradient using grad checker is[-0.00347525]
# gradient using back prop is[-0.00347525]
# gradient using grad checker is[-0.00336064]
# gradient using back prop is[-0.00336064]
# gradient using grad checker is[-0.00279975]
# gradient using back prop is[-0.00279975]
# gradient using grad checker is[-0.00353329]
# gradient using back prop is[-0.00353329]
# gradient using grad checker is[-0.00334719]
# gradient using back prop is[-0.00334719]
# gradient using grad checker is[-0.00277828]
# gradient using back prop is[-0.00277828]
# gradient using grad checker is[-0.00347462]
# gradient using back prop is[-0.00347462]
# gradient using grad checker is[-0.00335665]
# gradient using back prop is[-0.00335665]
# gradient using grad checker is[-0.00277446]
# gradient using back prop is[-0.00277446]
# gradient using grad checker is[-0.00349515]
# gradient using back prop is[-0.00349515]
# gradient using grad checker is[-0.00329011]
# gradient using back prop is[-0.00329011]
# gradient using grad checker is[-0.00271565]
# gradient using back prop is[-0.00271565]
# gradient using grad checker is[-0.0034756]
# gradient using back prop is[-0.0034756]
# gradient using grad checker is[-0.00325354]
# gradient using back prop is[-0.00325354]
# gradient using grad checker is[-0.00260126]
# gradient using back prop is[-0.00260126]
# gradient using grad checker is[-0.00335051]
# gradient using back prop is[-0.00335051]
# gradient using grad checker is[-0.00320774]
# gradient using back prop is[-0.00320774]
# gradient using grad checker is[-0.00239137]
# gradient using back prop is[-0.00239137]
# gradient using grad checker is[-0.00324597]
# gradient using back prop is[-0.00324597]
# gradient using grad checker is[-0.00308087]
# gradient using back prop is[-0.00308087]
# gradient using grad checker is[-0.00241594]
# gradient using back prop is[-0.00241594]
# gradient using grad checker is[-0.00323479]
# gradient using back prop is[-0.00323479]
# gradient using grad checker is[-0.00306944]
# gradient using back prop is[-0.00306944]
# gradient using grad checker is[-0.00241571]
# gradient using back prop is[-0.00241571]
# gradient using grad checker is[-0.00320795]
# gradient using back prop is[-0.00320795]
# gradient using grad checker is[-0.00314883]
# gradient using back prop is[-0.00314883]
# gradient using grad checker is[-0.00242617]
# gradient using back prop is[-0.00242617]
# gradient using grad checker is[-0.0032741]
# gradient using back prop is[-0.0032741]
# gradient using grad checker is[-0.00325444]
# gradient using back prop is[-0.00325444]
# gradient using grad checker is[-0.00248665]
# gradient using back prop is[-0.00248665]
# gradient using grad checker is[-0.00345988]
# gradient using back prop is[-0.00345988]
# gradient using grad checker is[-0.00337281]
# gradient using back prop is[-0.00337281]
# gradient using grad checker is[-0.00266807]
# gradient using back prop is[-0.00266807]
# gradient using grad checker is[-0.00346784]
# gradient using back prop is[-0.00346784]
# gradient using grad checker is[-0.00338796]
# gradient using back prop is[-0.00338796]
# gradient using grad checker is[-0.00267685]
# gradient using back prop is[-0.00267685]
# gradient using grad checker is[-0.00354585]
# gradient using back prop is[-0.00354585]
# gradient using grad checker is[-0.00340154]
# gradient using back prop is[-0.00340154]
# gradient using grad checker is[-0.00257112]
# gradient using back prop is[-0.00257112]
# gradient using grad checker is[-0.00365007]
# gradient using back prop is[-0.00365007]
# gradient using grad checker is[-0.0035096]
# gradient using back prop is[-0.0035096]
# gradient using grad checker is[-0.00265082]
# gradient using back prop is[-0.00265082]
# gradient using grad checker is[-0.00341677]
# gradient using back prop is[-0.00341677]
# gradient using grad checker is[-0.00348933]
# gradient using back prop is[-0.00348933]
# gradient using grad checker is[-0.00248249]
# gradient using back prop is[-0.00248249]
# gradient using grad checker is[-0.00329289]
# gradient using back prop is[-0.00329289]
# gradient using grad checker is[-0.00327382]
# gradient using back prop is[-0.00327383]
# gradient using grad checker is[-0.00245281]
# gradient using back prop is[-0.00245281]
# gradient using grad checker is[-0.00329266]
# gradient using back prop is[-0.00329266]
# gradient using grad checker is[-0.00332455]
# gradient using back prop is[-0.00332455]
# gradient using grad checker is[-0.0025048]
# gradient using back prop is[-0.0025048]
# gradient using grad checker is[-0.00341489]
# gradient using back prop is[-0.00341489]
# gradient using grad checker is[-0.00321243]
# gradient using back prop is[-0.00321243]
# gradient using grad checker is[-0.00253803]
# gradient using back prop is[-0.00253803]
# gradient using grad checker is[-0.00366276]
# gradient using back prop is[-0.00366276]
# gradient using grad checker is[-0.00354128]
# gradient using back prop is[-0.00354128]
# gradient using grad checker is[-0.00274707]
# gradient using back prop is[-0.00274707]
# gradient using grad checker is[-0.00373423]
# gradient using back prop is[-0.00373423]
# gradient using grad checker is[-0.00356281]
# gradient using back prop is[-0.00356281]
# gradient using grad checker is[-0.00280945]
# gradient using back prop is[-0.00280945]
# gradient using grad checker is[-0.00385067]
# gradient using back prop is[-0.00385067]
# gradient using grad checker is[-0.0035888]
# gradient using back prop is[-0.0035888]
# gradient using grad checker is[-0.0028863]
# gradient using back prop is[-0.0028863]
# gradient using grad checker is[-0.00408359]
# gradient using back prop is[-0.00408359]
# gradient using grad checker is[-0.00384749]
# gradient using back prop is[-0.00384749]
# gradient using grad checker is[-0.00309567]
# gradient using back prop is[-0.00309567]
# gradient using grad checker is[-0.00389574]
# gradient using back prop is[-0.00389574]
# gradient using grad checker is[-0.0036767]
# gradient using back prop is[-0.0036767]
# gradient using grad checker is[-0.00284948]
# gradient using back prop is[-0.00284948]
# gradient using grad checker is[-0.0036736]
# gradient using back prop is[-0.0036736]
# gradient using grad checker is[-0.00339768]
# gradient using back prop is[-0.00339768]
# gradient using grad checker is[-0.00250599]
# gradient using back prop is[-0.00250599]
# gradient using grad checker is[-0.00366854]
# gradient using back prop is[-0.00366854]
# gradient using grad checker is[-0.00345716]
# gradient using back prop is[-0.00345716]
# gradient using grad checker is[-0.0025322]
# gradient using back prop is[-0.0025322]
# gradient using grad checker is[-0.00366951]
# gradient using back prop is[-0.00366951]
# gradient using grad checker is[-0.00334442]
# gradient using back prop is[-0.00334442]
# gradient using grad checker is[-0.00259908]
# gradient using back prop is[-0.00259908]
# gradient using grad checker is[-0.00380556]
# gradient using back prop is[-0.00380556]
# gradient using grad checker is[-0.00349432]
# gradient using back prop is[-0.00349432]
# gradient using grad checker is[-0.00272808]
# gradient using back prop is[-0.00272808]
# gradient using grad checker is[-0.00374137]
# gradient using back prop is[-0.00374137]
# gradient using grad checker is[-0.00352143]
# gradient using back prop is[-0.00352143]
# gradient using grad checker is[-0.00274466]
# gradient using back prop is[-0.00274466]
# gradient using grad checker is[-0.00372642]
# gradient using back prop is[-0.00372642]
# gradient using grad checker is[-0.00364133]
# gradient using back prop is[-0.00364133]
# gradient using grad checker is[-0.00282393]
# gradient using back prop is[-0.00282393]
# gradient using grad checker is[-0.00380975]
# gradient using back prop is[-0.00380975]
# gradient using grad checker is[-0.0038617]
# gradient using back prop is[-0.0038617]
# gradient using grad checker is[-0.00303879]
# gradient using back prop is[-0.00303879]
# gradient using grad checker is[-0.00394779]
# gradient using back prop is[-0.00394779]
# gradient using grad checker is[-0.00390097]
# gradient using back prop is[-0.00390097]
# gradient using grad checker is[-0.00308373]
# gradient using back prop is[-0.00308373]
# gradient using grad checker is[-0.00365171]
# gradient using back prop is[-0.00365171]
# gradient using grad checker is[-0.00383442]
# gradient using back prop is[-0.00383442]
# gradient using grad checker is[-0.00305068]
# gradient using back prop is[-0.00305068]
# gradient using grad checker is[-0.00367388]
# gradient using back prop is[-0.00367388]
# gradient using grad checker is[-0.00369947]
# gradient using back prop is[-0.00369947]
# gradient using grad checker is[-0.00292216]
# gradient using back prop is[-0.00292216]
# gradient using grad checker is[-0.00365669]
# gradient using back prop is[-0.00365669]
# gradient using grad checker is[-0.00374636]
# gradient using back prop is[-0.00374636]
# gradient using grad checker is[-0.00287601]
# gradient using back prop is[-0.00287601]
# gradient using grad checker is[-0.00345994]
# gradient using back prop is[-0.00345994]
# gradient using grad checker is[-0.00364114]
# gradient using back prop is[-0.00364114]
# gradient using grad checker is[-0.00293749]
# gradient using back prop is[-0.00293749]
# gradient using grad checker is[-0.00357304]
# gradient using back prop is[-0.00357304]
# gradient using grad checker is[-0.00375118]
# gradient using back prop is[-0.00375118]
# gradient using grad checker is[-0.00300547]
# gradient using back prop is[-0.00300547]
# gradient using grad checker is[-0.00377932]
# gradient using back prop is[-0.00377932]
# gradient using grad checker is[-0.00384913]
# gradient using back prop is[-0.00384913]
# gradient using grad checker is[-0.00320599]
# gradient using back prop is[-0.00320599]
# gradient using grad checker is[-0.0036679]
# gradient using back prop is[-0.0036679]
# gradient using grad checker is[-0.00364374]
# gradient using back prop is[-0.00364374]
# gradient using grad checker is[-0.00317735]
# gradient using back prop is[-0.00317735]
# gradient using grad checker is[-0.0037192]
# gradient using back prop is[-0.0037192]
# gradient using grad checker is[-0.00363893]
# gradient using back prop is[-0.00363893]
# gradient using grad checker is[-0.00312901]
# gradient using back prop is[-0.00312901]
# gradient using grad checker is[-0.00368621]
# gradient using back prop is[-0.00368621]
# gradient using grad checker is[-0.00349199]
# gradient using back prop is[-0.00349199]
# gradient using grad checker is[-0.00296113]
# gradient using back prop is[-0.00296113]
# gradient using grad checker is[-0.00348878]
# gradient using back prop is[-0.00348878]
# gradient using grad checker is[-0.00341793]
# gradient using back prop is[-0.00341793]
# gradient using grad checker is[-0.00304094]
# gradient using back prop is[-0.00304094]
# gradient using grad checker is[-0.00352951]
# gradient using back prop is[-0.00352951]
# gradient using grad checker is[-0.00350283]
# gradient using back prop is[-0.00350283]
# gradient using grad checker is[-0.00305247]
# gradient using back prop is[-0.00305247]
# gradient using grad checker is[-0.00362258]
# gradient using back prop is[-0.00362258]
# gradient using grad checker is[-0.00361973]
# gradient using back prop is[-0.00361973]
# gradient using grad checker is[-0.00313244]
# gradient using back prop is[-0.00313244]
# gradient using grad checker is[-0.00361636]
# gradient using back prop is[-0.00361636]
# gradient using grad checker is[-0.00369188]
# gradient using back prop is[-0.00369188]
# gradient using grad checker is[-0.00334596]
# gradient using back prop is[-0.00334596]
# gradient using grad checker is[-0.00355342]
# gradient using back prop is[-0.00355342]
# gradient using grad checker is[-0.00364331]
# gradient using back prop is[-0.00364331]
# gradient using grad checker is[-0.00303885]
# gradient using back prop is[-0.00303885]
# gradient using grad checker is[-0.00339321]
# gradient using back prop is[-0.00339321]
# gradient using grad checker is[-0.00354036]
# gradient using back prop is[-0.00354036]
# gradient using grad checker is[-0.00292206]
# gradient using back prop is[-0.00292206]
# gradient using grad checker is[-0.00316029]
# gradient using back prop is[-0.00316029]
# gradient using grad checker is[-0.00341679]
# gradient using back prop is[-0.00341679]
# gradient using grad checker is[-0.00266964]
# gradient using back prop is[-0.00266964]
# gradient using grad checker is[-0.00322982]
# gradient using back prop is[-0.00322982]
# gradient using grad checker is[-0.00311745]
# gradient using back prop is[-0.00311745]
# gradient using grad checker is[-0.00267458]
# gradient using back prop is[-0.00267458]
# gradient using grad checker is[-0.00323703]
# gradient using back prop is[-0.00323703]
# gradient using grad checker is[-0.00319025]
# gradient using back prop is[-0.00319025]
# gradient using grad checker is[-0.0025906]
# gradient using back prop is[-0.0025906]
# gradient using grad checker is[-0.00349401]
# gradient using back prop is[-0.00349401]
# gradient using grad checker is[-0.00343727]
# gradient using back prop is[-0.00343727]
# gradient using grad checker is[-0.00272936]
# gradient using back prop is[-0.00272936]
# gradient using grad checker is[-0.00358814]
# gradient using back prop is[-0.00358814]
# gradient using grad checker is[-0.00361633]
# gradient using back prop is[-0.00361633]
# gradient using grad checker is[-0.00300289]
# gradient using back prop is[-0.00300289]
# gradient using grad checker is[-0.00357148]
# gradient using back prop is[-0.00357148]
# gradient using grad checker is[-0.00353805]
# gradient using back prop is[-0.00353805]
# gradient using grad checker is[-0.00283745]
# gradient using back prop is[-0.00283745]
# gradient using grad checker is[-0.00337921]
# gradient using back prop is[-0.00337921]
# gradient using grad checker is[-0.00347158]
# gradient using back prop is[-0.00347158]
# gradient using grad checker is[-0.00271655]
# gradient using back prop is[-0.00271655]
# gradient using grad checker is[-0.00342444]
# gradient using back prop is[-0.00342444]
# gradient using grad checker is[-0.0034143]
# gradient using back prop is[-0.0034143]
# gradient using grad checker is[-0.0026592]
# gradient using back prop is[-0.0026592]
# gradient using grad checker is[-0.00323651]
# gradient using back prop is[-0.00323651]
# gradient using grad checker is[-0.0033549]
# gradient using back prop is[-0.0033549]
# gradient using grad checker is[-0.00259472]
# gradient using back prop is[-0.00259472]
# gradient using grad checker is[-0.0035252]
# gradient using back prop is[-0.0035252]
# gradient using grad checker is[-0.00347087]
# gradient using back prop is[-0.00347087]
# gradient using grad checker is[-0.0027771]
# gradient using back prop is[-0.0027771]
# gradient using grad checker is[-0.00345583]
# gradient using back prop is[-0.00345583]
# gradient using grad checker is[-0.00352532]
# gradient using back prop is[-0.00352532]
# gradient using grad checker is[-0.00293403]
# gradient using back prop is[-0.00293403]
# gradient using grad checker is[-0.00355536]
# gradient using back prop is[-0.00355536]
# gradient using grad checker is[-0.00344924]
# gradient using back prop is[-0.00344923]
# gradient using grad checker is[-0.00289733]
# gradient using back prop is[-0.00289733]
# gradient using grad checker is[-0.00378784]
# gradient using back prop is[-0.00378784]
# gradient using grad checker is[-0.00370528]
# gradient using back prop is[-0.00370528]
# gradient using grad checker is[-0.00295844]
# gradient using back prop is[-0.00295844]
# gradient using grad checker is[-0.00375833]
# gradient using back prop is[-0.00375833]
# gradient using grad checker is[-0.00361922]
# gradient using back prop is[-0.00361922]
# gradient using grad checker is[-0.0028889]
# gradient using back prop is[-0.0028889]
# gradient using grad checker is[-0.00370577]
# gradient using back prop is[-0.00370577]
# gradient using grad checker is[-0.00357648]
# gradient using back prop is[-0.00357648]
# gradient using grad checker is[-0.00278643]
# gradient using back prop is[-0.00278643]
# gradient using grad checker is[-0.003777]
# gradient using back prop is[-0.003777]
# gradient using grad checker is[-0.0035623]
# gradient using back prop is[-0.0035623]
# gradient using grad checker is[-0.00305404]
# gradient using back prop is[-0.00305404]
# gradient using grad checker is[-0.00373227]
# gradient using back prop is[-0.00373227]
# gradient using grad checker is[-0.00349143]
# gradient using back prop is[-0.00349143]
# gradient using grad checker is[-0.00297851]
# gradient using back prop is[-0.00297851]
# gradient using grad checker is[-0.00381555]
# gradient using back prop is[-0.00381555]
# gradient using grad checker is[-0.00349273]
# gradient using back prop is[-0.00349273]
# gradient using grad checker is[-0.00292453]
# gradient using back prop is[-0.00292453]
# gradient using grad checker is[-0.00381531]
# gradient using back prop is[-0.00381531]
# gradient using grad checker is[-0.00349769]
# gradient using back prop is[-0.00349769]
# gradient using grad checker is[-0.00297051]
# gradient using back prop is[-0.00297052]
# gradient using grad checker is[-0.00373887]
# gradient using back prop is[-0.00373887]
# gradient using grad checker is[-0.00341613]
# gradient using back prop is[-0.00341613]
# gradient using grad checker is[-0.00286498]
# gradient using back prop is[-0.00286498]
# gradient using grad checker is[-0.00350239]
# gradient using back prop is[-0.00350239]
# gradient using grad checker is[-0.00338408]
# gradient using back prop is[-0.00338408]
# gradient using grad checker is[-0.00282457]
# gradient using back prop is[-0.00282457]
# gradient using grad checker is[-0.00347376]
# gradient using back prop is[-0.00347376]
# gradient using grad checker is[-0.00340449]
# gradient using back prop is[-0.00340449]
# gradient using grad checker is[-0.00279298]
# gradient using back prop is[-0.00279298]
# gradient using grad checker is[-0.0035988]
# gradient using back prop is[-0.0035988]
# gradient using grad checker is[-0.00328871]
# gradient using back prop is[-0.00328871]
# gradient using grad checker is[-0.00267275]
# gradient using back prop is[-0.00267275]
# gradient using grad checker is[-0.00342024]
# gradient using back prop is[-0.00342024]
# gradient using grad checker is[-0.00323062]
# gradient using back prop is[-0.00323062]
# gradient using grad checker is[-0.00254134]
# gradient using back prop is[-0.00254134]
# gradient using grad checker is[-0.0034564]
# gradient using back prop is[-0.0034564]
# gradient using grad checker is[-0.00327171]
# gradient using back prop is[-0.00327171]
# gradient using grad checker is[-0.00249637]
# gradient using back prop is[-0.00249637]
# gradient using grad checker is[-0.00322589]
# gradient using back prop is[-0.00322589]
# gradient using grad checker is[-0.00298045]
# gradient using back prop is[-0.00298045]
# gradient using grad checker is[-0.00236255]
# gradient using back prop is[-0.00236255]
# gradient using grad checker is[-0.00332465]
# gradient using back prop is[-0.00332465]
# gradient using grad checker is[-0.00320627]
# gradient using back prop is[-0.00320627]
# gradient using grad checker is[-0.00253633]
# gradient using back prop is[-0.00253633]
# gradient using grad checker is[-0.00336518]
# gradient using back prop is[-0.00336518]
# gradient using grad checker is[-0.00324095]
# gradient using back prop is[-0.00324095]
# gradient using grad checker is[-0.00253573]
# gradient using back prop is[-0.00253573]
# gradient using grad checker is[-0.00336419]
# gradient using back prop is[-0.00336419]
# gradient using grad checker is[-0.00331029]
# gradient using back prop is[-0.00331029]
# gradient using grad checker is[-0.00266878]
# gradient using back prop is[-0.00266878]
# gradient using grad checker is[-0.00351744]
# gradient using back prop is[-0.00351744]
# gradient using grad checker is[-0.00337551]
# gradient using back prop is[-0.00337551]
# gradient using grad checker is[-0.00261606]
# gradient using back prop is[-0.00261606]
# gradient using grad checker is[-0.00340007]
# gradient using back prop is[-0.00340007]
# gradient using grad checker is[-0.00344453]
# gradient using back prop is[-0.00344453]
# gradient using grad checker is[-0.00255949]
# gradient using back prop is[-0.00255949]
# gradient using grad checker is[-0.00348859]
# gradient using back prop is[-0.00348859]
# gradient using grad checker is[-0.00349105]
# gradient using back prop is[-0.00349105]
# gradient using grad checker is[-0.00264729]
# gradient using back prop is[-0.00264729]
# gradient using grad checker is[-0.00336155]
# gradient using back prop is[-0.00336155]
# gradient using grad checker is[-0.00341061]
# gradient using back prop is[-0.00341061]
# gradient using grad checker is[-0.00254695]
# gradient using back prop is[-0.00254695]
# gradient using grad checker is[-0.00331544]
# gradient using back prop is[-0.00331544]
# gradient using grad checker is[-0.00325018]
# gradient using back prop is[-0.00325018]
# gradient using grad checker is[-0.0025423]
# gradient using back prop is[-0.0025423]
# gradient using grad checker is[-0.00334837]
# gradient using back prop is[-0.00334837]
# gradient using grad checker is[-0.00320398]
# gradient using back prop is[-0.00320398]
# gradient using grad checker is[-0.00240669]
# gradient using back prop is[-0.00240669]
# gradient using grad checker is[-0.00338248]
# gradient using back prop is[-0.00338248]
# gradient using grad checker is[-0.00333461]
# gradient using back prop is[-0.00333461]
# gradient using grad checker is[-0.00262594]
# gradient using back prop is[-0.00262594]
# gradient using grad checker is[-0.00350712]
# gradient using back prop is[-0.00350712]
# gradient using grad checker is[-0.00334824]
# gradient using back prop is[-0.00334824]
# gradient using grad checker is[-0.00257562]
# gradient using back prop is[-0.00257562]
# gradient using grad checker is[-0.00358451]
# gradient using back prop is[-0.00358451]
# gradient using grad checker is[-0.0034757]
# gradient using back prop is[-0.0034757]
# gradient using grad checker is[-0.00266606]
# gradient using back prop is[-0.00266606]
# gradient using grad checker is[-0.00372214]
# gradient using back prop is[-0.00372214]
# gradient using grad checker is[-0.00359636]
# gradient using back prop is[-0.00359636]
# gradient using grad checker is[-0.00277982]
# gradient using back prop is[-0.00277982]
# gradient using grad checker is[-0.00391507]
# gradient using back prop is[-0.00391507]
# gradient using grad checker is[-0.0037005]
# gradient using back prop is[-0.0037005]
# gradient using grad checker is[-0.00297713]
# gradient using back prop is[-0.00297713]
# gradient using grad checker is[-0.00386316]
# gradient using back prop is[-0.00386316]
# gradient using grad checker is[-0.00360897]
# gradient using back prop is[-0.00360897]
# gradient using grad checker is[-0.00270663]
# gradient using back prop is[-0.00270663]
# gradient using grad checker is[-0.00361794]
# gradient using back prop is[-0.00361794]
# gradient using grad checker is[-0.00338317]
# gradient using back prop is[-0.00338318]
# gradient using grad checker is[-0.00267248]
# gradient using back prop is[-0.00267248]
# gradient using grad checker is[-0.00369431]
# gradient using back prop is[-0.00369431]
# gradient using grad checker is[-0.00356474]
# gradient using back prop is[-0.00356474]
# gradient using grad checker is[-0.00269323]
# gradient using back prop is[-0.00269323]
# gradient using grad checker is[-0.00365461]
# gradient using back prop is[-0.00365461]
# gradient using grad checker is[-0.00346949]
# gradient using back prop is[-0.00346949]
# gradient using grad checker is[-0.00270489]
# gradient using back prop is[-0.00270489]
# gradient using grad checker is[-0.0038027]
# gradient using back prop is[-0.0038027]
# gradient using grad checker is[-0.00371317]
# gradient using back prop is[-0.00371317]
# gradient using grad checker is[-0.00282114]
# gradient using back prop is[-0.00282114]
# gradient using grad checker is[-0.00384291]
# gradient using back prop is[-0.00384291]
# gradient using grad checker is[-0.00383122]
# gradient using back prop is[-0.00383122]
# gradient using grad checker is[-0.00315344]
# gradient using back prop is[-0.00315344]
# gradient using grad checker is[-0.00408035]
# gradient using back prop is[-0.00408035]
# gradient using grad checker is[-0.0039783]
# gradient using back prop is[-0.0039783]
# gradient using grad checker is[-0.00315624]
# gradient using back prop is[-0.00315624]
# gradient using grad checker is[-0.0039749]
# gradient using back prop is[-0.0039749]
# gradient using grad checker is[-0.00397342]
# gradient using back prop is[-0.00397342]
# gradient using grad checker is[-0.00321651]
# gradient using back prop is[-0.00321651]
# gradient using grad checker is[-0.00383534]
# gradient using back prop is[-0.00383534]
# gradient using grad checker is[-0.00391595]
# gradient using back prop is[-0.00391595]
# gradient using grad checker is[-0.0032646]
# gradient using back prop is[-0.0032646]
# gradient using grad checker is[-0.00380076]
# gradient using back prop is[-0.00380076]
# gradient using grad checker is[-0.0038718]
# gradient using back prop is[-0.0038718]
# gradient using grad checker is[-0.00324705]
# gradient using back prop is[-0.00324705]
# gradient using grad checker is[-0.00381651]
# gradient using back prop is[-0.00381651]
# gradient using grad checker is[-0.00388414]
# gradient using back prop is[-0.00388414]
# gradient using grad checker is[-0.00324916]
# gradient using back prop is[-0.00324916]
# gradient using grad checker is[-0.00362386]
# gradient using back prop is[-0.00362386]
# gradient using grad checker is[-0.00382609]
# gradient using back prop is[-0.00382609]
# gradient using grad checker is[-0.00308478]
# gradient using back prop is[-0.00308478]
# gradient using grad checker is[-0.00357811]
# gradient using back prop is[-0.00357811]
# gradient using grad checker is[-0.00367247]
# gradient using back prop is[-0.00367247]
# gradient using grad checker is[-0.00294052]
# gradient using back prop is[-0.00294052]
# gradient using grad checker is[-0.00376193]
# gradient using back prop is[-0.00376193]
# gradient using grad checker is[-0.00371769]
# gradient using back prop is[-0.00371769]
# gradient using grad checker is[-0.00307364]
# gradient using back prop is[-0.00307364]
# gradient using grad checker is[-0.00374413]
# gradient using back prop is[-0.00374413]
# gradient using grad checker is[-0.00390884]
# gradient using back prop is[-0.00390884]
# gradient using grad checker is[-0.00327473]
# gradient using back prop is[-0.00327473]
# gradient using grad checker is[-0.00364079]
# gradient using back prop is[-0.00364079]
# gradient using grad checker is[-0.00372772]
# gradient using back prop is[-0.00372772]
# gradient using grad checker is[-0.00324152]
# gradient using back prop is[-0.00324152]
# gradient using grad checker is[-0.0037346]
# gradient using back prop is[-0.0037346]
# gradient using grad checker is[-0.00361375]
# gradient using back prop is[-0.00361375]
# gradient using grad checker is[-0.00310784]
# gradient using back prop is[-0.00310784]
# gradient using grad checker is[-0.00365695]
# gradient using back prop is[-0.00365695]
# gradient using grad checker is[-0.00360266]
# gradient using back prop is[-0.00360266]
# gradient using grad checker is[-0.00301422]
# gradient using back prop is[-0.00301422]
# gradient using grad checker is[-0.00348533]
# gradient using back prop is[-0.00348533]
# gradient using grad checker is[-0.00339157]
# gradient using back prop is[-0.00339157]
# gradient using grad checker is[-0.0030217]
# gradient using back prop is[-0.0030217]
# gradient using grad checker is[-0.00349151]
# gradient using back prop is[-0.00349151]
# gradient using grad checker is[-0.00352784]
# gradient using back prop is[-0.00352784]
# gradient using grad checker is[-0.00309205]
# gradient using back prop is[-0.00309205]
# gradient using grad checker is[-0.0036152]
# gradient using back prop is[-0.0036152]
# gradient using grad checker is[-0.00367614]
# gradient using back prop is[-0.00367614]
# gradient using grad checker is[-0.00329281]
# gradient using back prop is[-0.00329281]
# gradient using grad checker is[-0.00368872]
# gradient using back prop is[-0.00368872]
# gradient using grad checker is[-0.00375311]
# gradient using back prop is[-0.00375311]
# gradient using grad checker is[-0.00327403]
# gradient using back prop is[-0.00327403]
# gradient using grad checker is[-0.00360792]
# gradient using back prop is[-0.00360792]
# gradient using grad checker is[-0.0036653]
# gradient using back prop is[-0.0036653]
# gradient using grad checker is[-0.00313788]
# gradient using back prop is[-0.00313788]
# gradient using grad checker is[-0.00355281]
# gradient using back prop is[-0.00355281]
# gradient using grad checker is[-0.0035443]
# gradient using back prop is[-0.0035443]
# gradient using grad checker is[-0.00297864]
# gradient using back prop is[-0.00297864]
# gradient using grad checker is[-0.00346651]
# gradient using back prop is[-0.00346651]
# gradient using grad checker is[-0.00339186]
# gradient using back prop is[-0.00339186]
# gradient using grad checker is[-0.00283994]
# gradient using back prop is[-0.00283994]
# gradient using grad checker is[-0.00341571]
# gradient using back prop is[-0.00341571]
# gradient using grad checker is[-0.0033966]
# gradient using back prop is[-0.0033966]
# gradient using grad checker is[-0.0027339]
# gradient using back prop is[-0.0027339]
# gradient using grad checker is[-0.00339912]
# gradient using back prop is[-0.00339912]
# gradient using grad checker is[-0.00337499]
# gradient using back prop is[-0.00337499]
# gradient using grad checker is[-0.00281224]
# gradient using back prop is[-0.00281224]
# gradient using grad checker is[-0.00337571]
# gradient using back prop is[-0.00337571]
# gradient using grad checker is[-0.00341592]
# gradient using back prop is[-0.00341592]
# gradient using grad checker is[-0.0028184]
# gradient using back prop is[-0.0028184]
# gradient using grad checker is[-0.00359657]
# gradient using back prop is[-0.00359657]
# gradient using grad checker is[-0.00365377]
# gradient using back prop is[-0.00365377]
# gradient using grad checker is[-0.00296496]
# gradient using back prop is[-0.00296496]
# gradient using grad checker is[-0.00344085]
# gradient using back prop is[-0.00344085]
# gradient using grad checker is[-0.00359305]
# gradient using back prop is[-0.00359305]
# gradient using grad checker is[-0.00305801]
# gradient using back prop is[-0.00305801]
# gradient using grad checker is[-0.00351573]
# gradient using back prop is[-0.00351573]
# gradient using grad checker is[-0.00362625]
# gradient using back prop is[-0.00362625]
# gradient using grad checker is[-0.00302937]
# gradient using back prop is[-0.00302936]
# gradient using grad checker is[-0.00341699]
# gradient using back prop is[-0.00341699]
# gradient using grad checker is[-0.00372533]
# gradient using back prop is[-0.00372533]
# gradient using grad checker is[-0.0029316]
# gradient using back prop is[-0.0029316]
# gradient using grad checker is[-0.00340016]
# gradient using back prop is[-0.00340016]
# gradient using grad checker is[-0.00351414]
# gradient using back prop is[-0.00351414]
# gradient using grad checker is[-0.00280831]
# gradient using back prop is[-0.00280831]
# gradient using grad checker is[-0.00356174]
# gradient using back prop is[-0.00356174]
# gradient using grad checker is[-0.00356255]
# gradient using back prop is[-0.00356255]
# gradient using grad checker is[-0.0027256]
# gradient using back prop is[-0.00272561]
# gradient using grad checker is[-0.00357952]
# gradient using back prop is[-0.00357952]
# gradient using grad checker is[-0.00347374]
# gradient using back prop is[-0.00347374]
# gradient using grad checker is[-0.00300359]
# gradient using back prop is[-0.00300359]
# gradient using grad checker is[-0.00365891]
# gradient using back prop is[-0.00365891]
# gradient using grad checker is[-0.00351817]
# gradient using back prop is[-0.00351817]
# gradient using grad checker is[-0.00297018]
# gradient using back prop is[-0.00297018]
# gradient using grad checker is[-0.00369296]
# gradient using back prop is[-0.00369296]
# gradient using grad checker is[-0.00348533]
# gradient using back prop is[-0.00348533]
# gradient using grad checker is[-0.00294156]
# gradient using back prop is[-0.00294156]
# gradient using grad checker is[-0.00368845]
# gradient using back prop is[-0.00368846]
# gradient using grad checker is[-0.00361448]
# gradient using back prop is[-0.00361448]
# gradient using grad checker is[-0.0029816]
# gradient using back prop is[-0.0029816]
# gradient using grad checker is[-0.00370167]
# gradient using back prop is[-0.00370167]
# gradient using grad checker is[-0.00348834]
# gradient using back prop is[-0.00348834]
# gradient using grad checker is[-0.00286884]
# gradient using back prop is[-0.00286884]
# gradient using grad checker is[-0.00381438]
# gradient using back prop is[-0.00381438]
# gradient using grad checker is[-0.00358427]
# gradient using back prop is[-0.00358427]
# gradient using grad checker is[-0.00295692]
# gradient using back prop is[-0.00295692]
# gradient using grad checker is[-0.00363267]
# gradient using back prop is[-0.00363267]
# gradient using grad checker is[-0.00343865]
# gradient using back prop is[-0.00343865]
# gradient using grad checker is[-0.00282421]
# gradient using back prop is[-0.00282421]
# gradient using grad checker is[-0.00379126]
# gradient using back prop is[-0.00379126]
# gradient using grad checker is[-0.00351084]
# gradient using back prop is[-0.00351084]
# gradient using grad checker is[-0.00284016]
# gradient using back prop is[-0.00284016]
# gradient using grad checker is[-0.00372771]
# gradient using back prop is[-0.00372771]
# gradient using grad checker is[-0.00355627]
# gradient using back prop is[-0.00355627]
# gradient using grad checker is[-0.00312651]
# gradient using back prop is[-0.00312651]
# gradient using grad checker is[-0.00363606]
# gradient using back prop is[-0.00363606]
# gradient using grad checker is[-0.00345906]
# gradient using back prop is[-0.00345906]
# gradient using grad checker is[-0.00288838]
# gradient using back prop is[-0.00288838]
# gradient using grad checker is[-0.00351562]
# gradient using back prop is[-0.00351562]
# gradient using grad checker is[-0.00350563]
# gradient using back prop is[-0.00350563]
# gradient using grad checker is[-0.00293912]
# gradient using back prop is[-0.00293912]
# gradient using grad checker is[-0.00344829]
# gradient using back prop is[-0.00344829]
# gradient using grad checker is[-0.00341834]
# gradient using back prop is[-0.00341834]
# gradient using grad checker is[-0.00291817]
# gradient using back prop is[-0.00291817]
# gradient using grad checker is[-0.00346864]
# gradient using back prop is[-0.00346864]
# gradient using grad checker is[-0.00324911]
# gradient using back prop is[-0.00324911]
# gradient using grad checker is[-0.00264822]
# gradient using back prop is[-0.00264822]
# gradient using grad checker is[-0.00355738]
# gradient using back prop is[-0.00355738]
# gradient using grad checker is[-0.00318968]
# gradient using back prop is[-0.00318968]
# gradient using grad checker is[-0.00250952]
# gradient using back prop is[-0.00250952]
# gradient using grad checker is[-0.00334115]
# gradient using back prop is[-0.00334115]
# gradient using grad checker is[-0.00313277]
# gradient using back prop is[-0.00313277]
# gradient using grad checker is[-0.00248198]
# gradient using back prop is[-0.00248198]
# gradient using grad checker is[-0.00329649]
# gradient using back prop is[-0.00329649]
# gradient using grad checker is[-0.00297641]
# gradient using back prop is[-0.00297641]
# gradient using grad checker is[-0.00238153]
# gradient using back prop is[-0.00238153]
# gradient using grad checker is[-0.00335213]
# gradient using back prop is[-0.00335213]
# gradient using grad checker is[-0.00322334]
# gradient using back prop is[-0.00322334]
# gradient using grad checker is[-0.00237105]
# gradient using back prop is[-0.00237105]
# gradient using grad checker is[-0.00336181]
# gradient using back prop is[-0.00336181]
# gradient using grad checker is[-0.00334133]
# gradient using back prop is[-0.00334133]
# gradient using grad checker is[-0.00236947]
# gradient using back prop is[-0.00236947]
# gradient using grad checker is[-0.00342334]
# gradient using back prop is[-0.00342334]
# gradient using grad checker is[-0.00333276]
# gradient using back prop is[-0.00333276]
# gradient using grad checker is[-0.00258272]
# gradient using back prop is[-0.00258272]
# gradient using grad checker is[-0.00344711]
# gradient using back prop is[-0.00344711]
# gradient using grad checker is[-0.00351696]
# gradient using back prop is[-0.00351696]
# gradient using grad checker is[-0.0025493]
# gradient using back prop is[-0.0025493]
# gradient using grad checker is[-0.00347306]
# gradient using back prop is[-0.00347306]
# gradient using grad checker is[-0.00345179]
# gradient using back prop is[-0.00345179]
# gradient using grad checker is[-0.00261797]
# gradient using back prop is[-0.00261797]
# gradient using grad checker is[-0.00331879]
# gradient using back prop is[-0.0033188]
# gradient using grad checker is[-0.00351312]
# gradient using back prop is[-0.00351312]
# gradient using grad checker is[-0.00253453]
# gradient using back prop is[-0.00253453]
# gradient using grad checker is[-0.00326014]
# gradient using back prop is[-0.00326014]
# gradient using grad checker is[-0.00325657]
# gradient using back prop is[-0.00325657]
# gradient using grad checker is[-0.00260807]
# gradient using back prop is[-0.00260807]
# gradient using grad checker is[-0.00342158]
# gradient using back prop is[-0.00342158]
# gradient using grad checker is[-0.00335517]
# gradient using back prop is[-0.00335517]
# gradient using grad checker is[-0.00250668]
# gradient using back prop is[-0.00250668]
# gradient using grad checker is[-0.00343615]
# gradient using back prop is[-0.00343615]
# gradient using grad checker is[-0.00335877]
# gradient using back prop is[-0.00335877]
# gradient using grad checker is[-0.00265136]
# gradient using back prop is[-0.00265136]
# gradient using grad checker is[-0.00329901]
# gradient using back prop is[-0.00329901]
# gradient using grad checker is[-0.00331171]
# gradient using back prop is[-0.00331171]
# gradient using grad checker is[-0.00264871]
# gradient using back prop is[-0.00264871]
# gradient using grad checker is[-0.00342089]
# gradient using back prop is[-0.00342089]
# gradient using grad checker is[-0.00323158]
# gradient using back prop is[-0.00323158]
# gradient using grad checker is[-0.00270843]
# gradient using back prop is[-0.00270843]
# gradient using grad checker is[-0.00342986]
# gradient using back prop is[-0.00342986]
# gradient using grad checker is[-0.00328825]
# gradient using back prop is[-0.00328825]
# gradient using grad checker is[-0.00263043]
# gradient using back prop is[-0.00263043]
# gradient using grad checker is[-0.00364802]
# gradient using back prop is[-0.00364802]
# gradient using grad checker is[-0.00344497]
# gradient using back prop is[-0.00344497]
# gradient using grad checker is[-0.00267811]
# gradient using back prop is[-0.00267811]
# gradient using grad checker is[-0.00386725]
# gradient using back prop is[-0.00386725]
# gradient using grad checker is[-0.00369747]
# gradient using back prop is[-0.00369747]
# gradient using grad checker is[-0.00283516]
# gradient using back prop is[-0.00283516]
# gradient using grad checker is[-0.0038389]
# gradient using back prop is[-0.0038389]
# gradient using grad checker is[-0.00363375]
# gradient using back prop is[-0.00363375]
# gradient using grad checker is[-0.00282936]
# gradient using back prop is[-0.00282936]
# gradient using grad checker is[-0.00360297]
# gradient using back prop is[-0.00360297]
# gradient using grad checker is[-0.00342964]
# gradient using back prop is[-0.00342964]
# gradient using grad checker is[-0.00270711]
# gradient using back prop is[-0.00270711]
# gradient using grad checker is[-0.00373581]
# gradient using back prop is[-0.00373581]
# gradient using grad checker is[-0.00349249]
# gradient using back prop is[-0.00349249]
# gradient using grad checker is[-0.00274417]
# gradient using back prop is[-0.00274417]
# gradient using grad checker is[-0.00371543]
# gradient using back prop is[-0.00371543]
# gradient using grad checker is[-0.00360594]
# gradient using back prop is[-0.00360594]
# gradient using grad checker is[-0.00281538]
# gradient using back prop is[-0.00281538]
# gradient using grad checker is[-0.00380937]
# gradient using back prop is[-0.00380936]
# gradient using grad checker is[-0.00373587]
# gradient using back prop is[-0.00373587]
# gradient using grad checker is[-0.0029303]
# gradient using back prop is[-0.0029303]
# gradient using grad checker is[-0.00400595]
# gradient using back prop is[-0.00400595]
# gradient using grad checker is[-0.0039547]
# gradient using back prop is[-0.0039547]
# gradient using grad checker is[-0.00312734]
# gradient using back prop is[-0.00312734]
# gradient using grad checker is[-0.00414438]
# gradient using back prop is[-0.00414438]
# gradient using grad checker is[-0.00401557]
# gradient using back prop is[-0.00401557]
# gradient using grad checker is[-0.00334311]
# gradient using back prop is[-0.00334311]
# gradient using grad checker is[-0.00394624]
# gradient using back prop is[-0.00394624]
# gradient using grad checker is[-0.00400861]
# gradient using back prop is[-0.00400861]
# gradient using grad checker is[-0.00324912]
# gradient using back prop is[-0.00324912]
# gradient using grad checker is[-0.0038425]
# gradient using back prop is[-0.0038425]
# gradient using grad checker is[-0.00375102]
# gradient using back prop is[-0.00375102]
# gradient using grad checker is[-0.00315496]
# gradient using back prop is[-0.00315496]
# gradient using grad checker is[-0.00377959]
# gradient using back prop is[-0.00377959]
# gradient using grad checker is[-0.00381951]
# gradient using back prop is[-0.00381951]
# gradient using grad checker is[-0.00318959]
# gradient using back prop is[-0.00318959]
# gradient using grad checker is[-0.00373191]
# gradient using back prop is[-0.00373191]
# gradient using grad checker is[-0.00370738]
# gradient using back prop is[-0.00370738]
# gradient using grad checker is[-0.00317896]
# gradient using back prop is[-0.00317896]
# gradient using grad checker is[-0.00385849]
# gradient using back prop is[-0.00385849]
# gradient using grad checker is[-0.00385737]
# gradient using back prop is[-0.00385737]
# gradient using grad checker is[-0.00303209]
# gradient using back prop is[-0.00303209]
# gradient using grad checker is[-0.00370208]
# gradient using back prop is[-0.00370208]
# gradient using grad checker is[-0.00371863]
# gradient using back prop is[-0.00371863]
# gradient using grad checker is[-0.00296948]
# gradient using back prop is[-0.00296948]
# gradient using grad checker is[-0.00379374]
# gradient using back prop is[-0.00379374]
# gradient using grad checker is[-0.00365036]
# gradient using back prop is[-0.00365036]
# gradient using grad checker is[-0.00311932]
# gradient using back prop is[-0.00311932]
# gradient using grad checker is[-0.00377323]
# gradient using back prop is[-0.00377323]
# gradient using grad checker is[-0.00391643]
# gradient using back prop is[-0.00391643]
# gradient using grad checker is[-0.00327136]
# gradient using back prop is[-0.00327136]
# gradient using grad checker is[-0.0036538]
# gradient using back prop is[-0.0036538]
# gradient using grad checker is[-0.00363475]
# gradient using back prop is[-0.00363475]
# gradient using grad checker is[-0.00318267]
# gradient using back prop is[-0.00318267]
# gradient using grad checker is[-0.00364319]
# gradient using back prop is[-0.00364319]
# gradient using grad checker is[-0.00361716]
# gradient using back prop is[-0.00361716]
# gradient using grad checker is[-0.00311829]
# gradient using back prop is[-0.00311829]
# gradient using grad checker is[-0.00360068]
# gradient using back prop is[-0.00360067]
# gradient using grad checker is[-0.00356373]
# gradient using back prop is[-0.00356373]
# gradient using grad checker is[-0.00311349]
# gradient using back prop is[-0.00311349]
# gradient using grad checker is[-0.00345493]
# gradient using back prop is[-0.00345493]
# gradient using grad checker is[-0.00354379]
# gradient using back prop is[-0.00354379]
# gradient using grad checker is[-0.00307012]
# gradient using back prop is[-0.00307012]
# gradient using grad checker is[-0.00352051]
# gradient using back prop is[-0.00352051]
# gradient using grad checker is[-0.00345239]
# gradient using back prop is[-0.00345239]
# gradient using grad checker is[-0.00304354]
# gradient using back prop is[-0.00304354]
# gradient using grad checker is[-0.00372789]
# gradient using back prop is[-0.0037279]
# gradient using grad checker is[-0.00372271]
# gradient using back prop is[-0.00372271]
# gradient using grad checker is[-0.00333583]
# gradient using back prop is[-0.00333583]
# gradient using grad checker is[-0.00370171]
# gradient using back prop is[-0.00370171]
# gradient using grad checker is[-0.00391715]
# gradient using back prop is[-0.00391715]
# gradient using grad checker is[-0.0033854]
# gradient using back prop is[-0.0033854]
# gradient using grad checker is[-0.00374834]
# gradient using back prop is[-0.00374834]
# gradient using grad checker is[-0.00387483]
# gradient using back prop is[-0.00387483]
# gradient using grad checker is[-0.00321175]
# gradient using back prop is[-0.00321175]
# gradient using grad checker is[-0.0036479]
# gradient using back prop is[-0.0036479]
# gradient using grad checker is[-0.00365593]
# gradient using back prop is[-0.00365593]
# ...
# gradient using back prop is[-0.00380314]
# gradient using grad checker is[-0.00304843]
# gradient using back prop is[-0.00304843]
# gradient using grad checker is[-0.00213981]
# gradient using back prop is[-0.00213981]
# gradient using grad checker is[-0.00365835]
# gradient using back prop is[-0.00365835]
# gradient using grad checker is[-0.00293556]
# gradient using back prop is[-0.00293556]
# gradient using grad checker is[-0.00201751]
# gradient using back prop is[-0.00201751]
# gradient using grad checker is[-0.00335049]
# gradient using back prop is[-0.00335049]
# gradient using grad checker is[-0.00276167]
# gradient using back prop is[-0.00276167]
# gradient using grad checker is[-0.0018365]
# gradient using back prop is[-0.0018365]
# gradient using grad checker is[-0.00328378]
# gradient using back prop is[-0.00328378]
# gradient using grad checker is[-0.00249629]
# gradient using back prop is[-0.00249629]
# gradient using grad checker is[-0.00178851]
# gradient using back prop is[-0.00178851]
# gradient using grad checker is[-0.0030267]
# gradient using back prop is[-0.0030267]
# gradient using grad checker is[-0.00239787]
# gradient using back prop is[-0.00239787]
# gradient using grad checker is[-0.00165314]
# gradient using back prop is[-0.00165314]
# gradient using grad checker is[-0.00309837]
# gradient using back prop is[-0.00309837]
# gradient using grad checker is[-0.00265695]
# gradient using back prop is[-0.00265695]
# gradient using grad checker is[-0.00201083]
# gradient using back prop is[-0.00201083]
# gradient using grad checker is[-0.00299189]
# gradient using back prop is[-0.00299189]
# gradient using grad checker is[-0.00270641]
# gradient using back prop is[-0.00270641]
# gradient using grad checker is[-0.00186038]
# gradient using back prop is[-0.00186038]
# gradient using grad checker is[-0.00325202]
# gradient using back prop is[-0.00325202]
# gradient using grad checker is[-0.00273984]
# gradient using back prop is[-0.00273983]
# gradient using grad checker is[-0.00197453]
# gradient using back prop is[-0.00197453]
# gradient using grad checker is[-0.00340194]
# gradient using back prop is[-0.00340194]
# gradient using grad checker is[-0.00281394]
# gradient using back prop is[-0.00281394]
# gradient using grad checker is[-0.0022297]
# gradient using back prop is[-0.0022297]
# gradient using grad checker is[-0.00378258]
# gradient using back prop is[-0.00378258]
# gradient using grad checker is[-0.00310725]
# gradient using back prop is[-0.00310725]
# gradient using grad checker is[-0.00253238]
# gradient using back prop is[-0.00253238]
# gradient using grad checker is[-0.00356652]
# gradient using back prop is[-0.00356652]
# gradient using grad checker is[-0.00307556]
# gradient using back prop is[-0.00307556]
# gradient using grad checker is[-0.00244336]
# gradient using back prop is[-0.00244336]
# gradient using grad checker is[-0.00344539]
# gradient using back prop is[-0.00344539]
# gradient using grad checker is[-0.00302522]
# gradient using back prop is[-0.00302522]
# gradient using grad checker is[-0.00245675]
# gradient using back prop is[-0.00245675]
# gradient using grad checker is[-0.00351226]
# gradient using back prop is[-0.00351226]
# gradient using grad checker is[-0.0030021]
# gradient using back prop is[-0.0030021]
# gradient using grad checker is[-0.0022719]
# gradient using back prop is[-0.0022719]
# gradient using grad checker is[-0.00344209]
# gradient using back prop is[-0.00344209]
# gradient using grad checker is[-0.00307223]
# gradient using back prop is[-0.00307223]
# gradient using grad checker is[-0.00230525]
# gradient using back prop is[-0.00230525]
# gradient using grad checker is[-0.00341767]
# gradient using back prop is[-0.00341767]
# gradient using grad checker is[-0.00325833]
# gradient using back prop is[-0.00325833]
# gradient using grad checker is[-0.00250462]
# gradient using back prop is[-0.00250462]
# gradient using grad checker is[-0.00339828]
# gradient using back prop is[-0.00339828]
# gradient using grad checker is[-0.00311813]
# gradient using back prop is[-0.00311813]
# gradient using grad checker is[-0.00259467]
# gradient using back prop is[-0.00259467]
# gradient using grad checker is[-0.0035172]
# gradient using back prop is[-0.0035172]
# gradient using grad checker is[-0.00314562]
# gradient using back prop is[-0.00314563]
# gradient using grad checker is[-0.00251037]
# gradient using back prop is[-0.00251037]
# gradient using grad checker is[-0.00341178]
# gradient using back prop is[-0.00341178]
# gradient using grad checker is[-0.00326038]
# gradient using back prop is[-0.00326038]
# gradient using grad checker is[-0.00254519]
# gradient using back prop is[-0.00254519]
# gradient using grad checker is[-0.00330038]
# gradient using back prop is[-0.00330038]
# gradient using grad checker is[-0.00298475]
# gradient using back prop is[-0.00298475]
# gradient using grad checker is[-0.00224093]
# gradient using back prop is[-0.00224093]
# gradient using grad checker is[-0.00308586]
# gradient using back prop is[-0.00308586]
# gradient using grad checker is[-0.00284235]
# gradient using back prop is[-0.00284235]
# gradient using grad checker is[-0.0021727]
# gradient using back prop is[-0.0021727]
# gradient using grad checker is[-0.00318246]
# gradient using back prop is[-0.00318246]
# gradient using grad checker is[-0.00286116]
# gradient using back prop is[-0.00286116]
# gradient using grad checker is[-0.00221042]
# gradient using back prop is[-0.00221042]
# gradient using grad checker is[-0.00342379]
# gradient using back prop is[-0.00342379]
# gradient using grad checker is[-0.00328765]
# gradient using back prop is[-0.00328765]
# gradient using grad checker is[-0.00248295]
# gradient using back prop is[-0.00248295]
# gradient using grad checker is[-0.00351425]
# gradient using back prop is[-0.00351425]
# gradient using grad checker is[-0.00324548]
# gradient using back prop is[-0.00324548]
# gradient using grad checker is[-0.00246163]
# gradient using back prop is[-0.00246162]
# gradient using grad checker is[-0.00364841]
# gradient using back prop is[-0.00364841]
# gradient using grad checker is[-0.00327917]
# gradient using back prop is[-0.00327917]
# gradient using grad checker is[-0.00258327]
# gradient using back prop is[-0.00258327]
# gradient using grad checker is[-0.00342815]
# gradient using back prop is[-0.00342815]
# gradient using grad checker is[-0.00309107]
# gradient using back prop is[-0.00309107]
# gradient using grad checker is[-0.00246037]
# gradient using back prop is[-0.00246037]
# gradient using grad checker is[-0.00332874]
# gradient using back prop is[-0.00332874]
# gradient using grad checker is[-0.00314603]
# gradient using back prop is[-0.00314603]
# gradient using grad checker is[-0.00241773]
# gradient using back prop is[-0.00241773]
# gradient using grad checker is[-0.00314171]
# gradient using back prop is[-0.00314171]
# gradient using grad checker is[-0.0030159]
# gradient using back prop is[-0.00301589]
# gradient using grad checker is[-0.00225832]
# gradient using back prop is[-0.00225832]
# gradient using grad checker is[-0.00316804]
# gradient using back prop is[-0.00316804]
# gradient using grad checker is[-0.0029747]
# gradient using back prop is[-0.0029747]
# gradient using grad checker is[-0.00218131]
# gradient using back prop is[-0.00218131]
# gradient using grad checker is[-0.00321129]
# gradient using back prop is[-0.00321129]
# gradient using grad checker is[-0.00308152]
# gradient using back prop is[-0.00308152]
# gradient using grad checker is[-0.00233049]
# gradient using back prop is[-0.00233049]
# gradient using grad checker is[-0.00242242]
# gradient using back prop is[-0.00242242]
# gradient using grad checker is[-0.00255469]
# gradient using back prop is[-0.00255469]
# gradient using grad checker is[-0.00157894]
# gradient using back prop is[-0.00157894]
# gradient using grad checker is[-0.00231977]
# gradient using back prop is[-0.00231977]
# gradient using grad checker is[-0.00246913]
# gradient using back prop is[-0.00246913]
# gradient using grad checker is[-0.00145917]
# gradient using back prop is[-0.00145917]
# gradient using grad checker is[-0.0023237]
# gradient using back prop is[-0.0023237]
# gradient using grad checker is[-0.00233217]
# gradient using back prop is[-0.00233217]
# gradient using grad checker is[-0.00139865]
# gradient using back prop is[-0.00139865]
# gradient using grad checker is[-0.00250728]
# gradient using back prop is[-0.00250728]
# gradient using grad checker is[-0.00274554]
# gradient using back prop is[-0.00274554]
# gradient using grad checker is[-0.00178945]
# gradient using back prop is[-0.00178945]
# gradient using grad checker is[-0.00268386]
# gradient using back prop is[-0.00268386]
# gradient using grad checker is[-0.00302059]
# gradient using back prop is[-0.00302059]
# gradient using grad checker is[-0.00183587]
# gradient using back prop is[-0.00183587]
# gradient using grad checker is[-0.0028884]
# gradient using back prop is[-0.0028884]
# gradient using grad checker is[-0.00301184]
# gradient using back prop is[-0.00301184]
# gradient using grad checker is[-0.00214527]
# gradient using back prop is[-0.00214527]
# gradient using grad checker is[-0.0031705]
# gradient using back prop is[-0.0031705]
# gradient using grad checker is[-0.00315454]
# gradient using back prop is[-0.00315454]
# gradient using grad checker is[-0.00238488]
# gradient using back prop is[-0.00238488]
# gradient using grad checker is[-0.0032335]
# gradient using back prop is[-0.0032335]
# gradient using grad checker is[-0.00339187]
# gradient using back prop is[-0.00339187]
# gradient using grad checker is[-0.00243965]
# gradient using back prop is[-0.00243965]
# gradient using grad checker is[-0.00332785]
# gradient using back prop is[-0.00332785]
# gradient using grad checker is[-0.00337502]
# gradient using back prop is[-0.00337502]
# gradient using grad checker is[-0.00210616]
# gradient using back prop is[-0.00210616]
# gradient using grad checker is[-0.00298463]
# gradient using back prop is[-0.00298463]
# gradient using grad checker is[-0.00304383]
# gradient using back prop is[-0.00304383]
# gradient using grad checker is[-0.00165533]
# gradient using back prop is[-0.00165533]
# gradient using grad checker is[-0.0028921]
# gradient using back prop is[-0.0028921]
# gradient using grad checker is[-0.00279228]
# gradient using back prop is[-0.00279228]
# gradient using grad checker is[-0.00164938]
# gradient using back prop is[-0.00164938]
# gradient using grad checker is[-0.00297103]
# gradient using back prop is[-0.00297103]
# gradient using grad checker is[-0.0027563]
# gradient using back prop is[-0.0027563]
# gradient using grad checker is[-0.00196084]
# gradient using back prop is[-0.00196084]
# gradient using grad checker is[-0.00306378]
# gradient using back prop is[-0.00306378]
# gradient using grad checker is[-0.00281681]
# gradient using back prop is[-0.00281681]
# gradient using grad checker is[-0.00188195]
# gradient using back prop is[-0.00188195]
# gradient using grad checker is[-0.00302622]
# gradient using back prop is[-0.00302622]
# gradient using grad checker is[-0.00284896]
# gradient using back prop is[-0.00284896]
# gradient using grad checker is[-0.00189785]
# gradient using back prop is[-0.00189785]
# gradient using grad checker is[-0.00312201]
# gradient using back prop is[-0.00312201]
# gradient using grad checker is[-0.00287725]
# gradient using back prop is[-0.00287725]
# gradient using grad checker is[-0.00194543]
# gradient using back prop is[-0.00194543]
# gradient using grad checker is[-0.00318315]
# gradient using back prop is[-0.00318315]
# gradient using grad checker is[-0.00296055]
# gradient using back prop is[-0.00296055]
# gradient using grad checker is[-0.00230576]
# gradient using back prop is[-0.00230576]
# gradient using grad checker is[-0.00310405]
# gradient using back prop is[-0.00310405]
# gradient using grad checker is[-0.00285325]
# gradient using back prop is[-0.00285325]
# gradient using grad checker is[-0.00215175]
# gradient using back prop is[-0.00215175]
# gradient using grad checker is[-0.00333516]
# gradient using back prop is[-0.00333516]
# gradient using grad checker is[-0.00305379]
# gradient using back prop is[-0.00305379]
# gradient using grad checker is[-0.00225798]
# gradient using back prop is[-0.00225798]
# gradient using grad checker is[-0.0031744]
# gradient using back prop is[-0.0031744]
# gradient using grad checker is[-0.00274555]
# gradient using back prop is[-0.00274555]
# gradient using grad checker is[-0.00226483]
# gradient using back prop is[-0.00226483]
# gradient using grad checker is[-0.00321839]
# gradient using back prop is[-0.00321839]
# gradient using grad checker is[-0.00275255]
# gradient using back prop is[-0.00275255]
# gradient using grad checker is[-0.00193323]
# gradient using back prop is[-0.00193323]
# gradient using grad checker is[-0.00312379]
# gradient using back prop is[-0.00312379]
# gradient using grad checker is[-0.00271988]
# gradient using back prop is[-0.00271988]
# gradient using grad checker is[-0.00216178]
# gradient using back prop is[-0.00216178]
# gradient using grad checker is[-0.00317512]
# gradient using back prop is[-0.00317512]
# gradient using grad checker is[-0.00255189]
# gradient using back prop is[-0.00255189]
# gradient using grad checker is[-0.00197982]
# gradient using back prop is[-0.00197982]
# gradient using grad checker is[-0.00315253]
# gradient using back prop is[-0.00315253]
# gradient using grad checker is[-0.00236004]
# gradient using back prop is[-0.00236004]
# gradient using grad checker is[-0.00191949]
# gradient using back prop is[-0.00191949]
# gradient using grad checker is[-0.00329511]
# gradient using back prop is[-0.00329511]
# gradient using grad checker is[-0.00243416]
# gradient using back prop is[-0.00243416]
# gradient using grad checker is[-0.00185894]
# gradient using back prop is[-0.00185894]
# gradient using grad checker is[-0.00292321]
# gradient using back prop is[-0.00292321]
# gradient using grad checker is[-0.00218269]
# gradient using back prop is[-0.00218269]
# gradient using grad checker is[-0.00172804]
# gradient using back prop is[-0.00172804]
# gradient using grad checker is[-0.00266619]
# gradient using back prop is[-0.00266619]
# gradient using grad checker is[-0.00218989]
# gradient using back prop is[-0.00218989]
# gradient using grad checker is[-0.00167016]
# gradient using back prop is[-0.00167016]
# gradient using grad checker is[-0.00280311]
# gradient using back prop is[-0.00280311]
# gradient using grad checker is[-0.002314]
# gradient using back prop is[-0.002314]
# gradient using grad checker is[-0.00185953]
# gradient using back prop is[-0.00185953]
# gradient using grad checker is[-0.00279037]
# gradient using back prop is[-0.00279037]
# gradient using grad checker is[-0.00230251]
# gradient using back prop is[-0.00230251]
# gradient using grad checker is[-0.00158788]
# gradient using back prop is[-0.00158788]
# gradient using grad checker is[-0.0027487]
# gradient using back prop is[-0.0027487]
# gradient using grad checker is[-0.00203996]
# gradient using back prop is[-0.00203996]
# gradient using grad checker is[-0.00123114]
# gradient using back prop is[-0.00123114]
# gradient using grad checker is[-0.00300792]
# gradient using back prop is[-0.00300792]
# gradient using grad checker is[-0.00204815]
# gradient using back prop is[-0.00204815]
# gradient using grad checker is[-0.00146786]
# gradient using back prop is[-0.00146786]
# gradient using grad checker is[-0.00288942]
# gradient using back prop is[-0.00288942]
# gradient using grad checker is[-0.0018834]
# gradient using back prop is[-0.0018834]
# gradient using grad checker is[-0.00137017]
# gradient using back prop is[-0.00137017]
# gradient using grad checker is[-0.00308327]
# gradient using back prop is[-0.00308327]
# gradient using grad checker is[-0.00233506]
# gradient using back prop is[-0.00233506]
# gradient using grad checker is[-0.00161991]
# gradient using back prop is[-0.00161991]
# gradient using grad checker is[-0.00310939]
# gradient using back prop is[-0.00310939]
# gradient using grad checker is[-0.00233769]
# gradient using back prop is[-0.00233769]
# gradient using grad checker is[-0.00166779]
# gradient using back prop is[-0.00166779]
# gradient using grad checker is[-0.00314913]
# gradient using back prop is[-0.00314913]
# gradient using grad checker is[-0.00234912]
# gradient using back prop is[-0.00234912]
# gradient using grad checker is[-0.00171927]
# gradient using back prop is[-0.00171927]
