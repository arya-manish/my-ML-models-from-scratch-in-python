# %%
import numpy as np
import matplotlib.pyplot as plt
from Softmax_Necessary_Functions_With_Regularization import *
from Softmax_Gradient_Checker_With_Regularization import *
from Load_Dataset import read_input_file
import time
# Out:
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = read_input_file()
# Out:
# WARNING:tensorflow:From /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Softmax_With_Regularization_Model/Softmax_With_Regularization_Model(MNIST application)/Load_Dataset.py:15: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST/t10k-images-idx3-ubyte.gz
# Extracting MNIST/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X_train = X_train_orig.T
Y_train = Y_train_orig.T
X_test = X_test_orig.T
Y_test = Y_test_orig.T
print("X_train has shape: " +str(X_train.shape))
print("Y_train has shape: " +str(Y_train.shape))
print("X_test has shape: " + str(X_test.shape))
print("Y_test has shape: " +str(Y_test.shape))
# Out:
# X_train has shape: (784, 55000)
# Y_train has shape: (10, 55000)
# X_test has shape: (784, 10000)
# Y_test has shape: (10, 10000)

# %%
tic = time.time()
parameters = regularized_model_softmax(X_train, Y_train, 0.0075, 10, [784,6,3,10], lambd = 0.7)
tac = time.time()
print('Time taken in training is :' + str(tac-tic) +' seconds')
train_accuracy = pred_accuracy_softmax(X_train, Y_train, parameters)
test_accuracy = pred_accuracy_softmax(X_test, Y_test, parameters)
print('Train accuracy is : '+str(train_accuracy))
print('Test accuracy is : '+str(test_accuracy))
# Out:
# cost after 0 iterations is 2.5826663881542364
# Time taken in training is :12.297924995422363 seconds
# Train accuracy is : 0.15052727272727273
# Test accuracy is : 0.15380000000000002

# %%
AL, cache = forward_prop(X_train, parameters)
gradients = back_prop_with_regularization(X_train,Y_train,cache, 0.7)
difference = regularized_gradient_check(X_train,Y_train,parameters,gradients, lambd = 0.7)
# Out:
# gradient using grad checker is[1.28119737e-06]
# gradient using back prop is[1.28013161e-06]
# gradient using grad checker is[1.22124533e-07]
# gradient using back prop is[1.21946522e-07]
# gradient using grad checker is[-9.1038288e-07]
# gradient using back prop is[-9.10608621e-07]
# gradient using grad checker is[-5.72875081e-07]
# gradient using back prop is[-5.73417688e-07]
# gradient using grad checker is[6.50590692e-07]
# gradient using back prop is[6.49387146e-07]
# gradient using grad checker is[4.6629367e-07]
# gradient using back prop is[4.65492542e-07]
# gradient using grad checker is[7.63833441e-07]
# gradient using back prop is[7.64028685e-07]
# gradient using grad checker is[9.65894031e-07]
# gradient using back prop is[9.66505707e-07]
# gradient using grad checker is[-6.28386232e-07]
# gradient using back prop is[-6.28213741e-07]
# gradient using grad checker is[7.32747196e-08]
# gradient using back prop is[7.43610637e-08]
# gradient using grad checker is[2.42028619e-07]
# gradient using back prop is[2.41325494e-07]
# gradient using grad checker is[-1.46549439e-07]
# gradient using back prop is[-1.46028371e-07]
# gradient using grad checker is[1.687539e-07]
# gradient using back prop is[1.68662219e-07]
# gradient using grad checker is[1.53432822e-05]
# gradient using back prop is[1.53413557e-05]
# gradient using grad checker is[1.48259183e-05]
# gradient using back prop is[1.4824731e-05]
# gradient using grad checker is[1.53654867e-06]
# gradient using back prop is[1.53839902e-06]
# gradient using grad checker is[-7.99360578e-07]
# gradient using back prop is[-7.99682779e-07]
# gradient using grad checker is[6.99440506e-07]
# gradient using back prop is[7.00375567e-07]
# gradient using grad checker is[8.32667268e-07]
# gradient using back prop is[8.33095115e-07]
# gradient using grad checker is[-4.72955008e-07]
# gradient using back prop is[-4.72440944e-07]
# gradient using grad checker is[-1.38111744e-06]
# gradient using back prop is[-1.38120539e-06]
# gradient using grad checker is[2.22044605e-09]
# gradient using back prop is[2.90321414e-09]
# gradient using grad checker is[6.50590692e-07]
# gradient using back prop is[6.50639447e-07]
# gradient using grad checker is[-5.55111512e-08]
# gradient using back prop is[-5.67738995e-08]
# gradient using grad checker is[-4.30766534e-07]
# gradient using back prop is[-4.30836104e-07]
# gradient using grad checker is[-8.12683254e-07]
# gradient using back prop is[-8.12032456e-07]
# gradient using grad checker is[-2.66453526e-08]
# gradient using back prop is[-2.66799299e-08]
# gradient using grad checker is[2.19824159e-07]
# gradient using back prop is[2.19616044e-07]
# gradient using grad checker is[2.73114864e-07]
# gradient using back prop is[2.71877834e-07]
# gradient using grad checker is[1.31006317e-07]
# gradient using back prop is[1.31501468e-07]
# gradient using grad checker is[5.32907052e-08]
# gradient using back prop is[5.32427764e-08]
# gradient using grad checker is[-3.55271368e-07]
# gradient using back prop is[-3.55124926e-07]
# gradient using grad checker is[3.99680289e-07]
# gradient using back prop is[3.989558e-07]
# gradient using grad checker is[-2.81996648e-07]
# gradient using back prop is[-2.83051183e-07]
# gradient using grad checker is[-1.36113343e-06]
# gradient using back prop is[-1.36178559e-06]
# gradient using grad checker is[-1.02362563e-06]
# gradient using back prop is[-1.02493948e-06]
# gradient using grad checker is[3.3173464e-06]
# gradient using back prop is[3.31872268e-06]
# gradient using grad checker is[-1.58872915e-05]
# gradient using back prop is[-1.58882587e-05]
# gradient using grad checker is[-6.82964796e-05]
# gradient using back prop is[-6.82963986e-05]
# gradient using grad checker is[-0.00010623]
# gradient using back prop is[-0.00010623]
# gradient using grad checker is[-0.00015104]
# gradient using back prop is[-0.00015104]
# gradient using grad checker is[-0.00011479]
# gradient using back prop is[-0.00011479]
# gradient using grad checker is[-6.09179374e-05]
# gradient using back prop is[-6.09196356e-05]
# gradient using grad checker is[-0.00012108]
# gradient using back prop is[-0.00012108]
# gradient using grad checker is[-0.0001743]
# gradient using back prop is[-0.0001743]
# gradient using grad checker is[-0.00019688]
# gradient using back prop is[-0.00019688]
# gradient using grad checker is[-0.00015785]
# gradient using back prop is[-0.00015785]
# gradient using grad checker is[-0.00013514]
# gradient using back prop is[-0.00013514]
# gradient using grad checker is[-0.00010351]
# gradient using back prop is[-0.00010351]
# gradient using grad checker is[-3.30446781e-05]
# gradient using back prop is[-3.30444029e-05]
# gradient using grad checker is[-1.04516396e-05]
# gradient using back prop is[-1.04498036e-05]
# gradient using grad checker is[-8.8817842e-09]
# gradient using back prop is[-9.84257191e-09]
# gradient using grad checker is[1.21902488e-06]
# gradient using back prop is[1.2183812e-06]
# gradient using grad checker is[-2.88657986e-08]
# gradient using back prop is[-2.76127848e-08]
# gradient using grad checker is[8.65973959e-08]
# gradient using back prop is[8.65563115e-08]
# gradient using grad checker is[8.65973959e-07]
# gradient using back prop is[8.65307891e-07]
# gradient using grad checker is[2.59792188e-07]
# gradient using back prop is[2.59280954e-07]
# gradient using grad checker is[-4.86277685e-07]
# gradient using back prop is[-4.86675497e-07]
# gradient using grad checker is[7.70494779e-07]
# gradient using back prop is[7.70075874e-07]
# gradient using grad checker is[-2.30926389e-07]
# gradient using back prop is[-2.30485115e-07]
# gradient using grad checker is[-1.0000889e-05]
# gradient using back prop is[-1.00005924e-05]
# gradient using grad checker is[-3.5105252e-06]
# gradient using back prop is[-3.51113145e-06]
# gradient using grad checker is[-1.89137594e-05]
# gradient using back prop is[-1.89129905e-05]
# gradient using grad checker is[-1.86961557e-06]
# gradient using back prop is[-1.8693473e-06]
# gradient using grad checker is[2.30326869e-05]
# gradient using back prop is[2.30348092e-05]
# gradient using grad checker is[8.7871932e-05]
# gradient using back prop is[8.78731239e-05]
# gradient using grad checker is[5.91993121e-05]
# gradient using back prop is[5.92022089e-05]
# gradient using grad checker is[-6.8074435e-05]
# gradient using back prop is[-6.80740338e-05]
# gradient using grad checker is[-0.0003304]
# gradient using back prop is[-0.0003304]
# gradient using grad checker is[-0.00053108]
# gradient using back prop is[-0.00053108]
# gradient using grad checker is[-0.00073884]
# gradient using back prop is[-0.00073884]
# gradient using grad checker is[-0.00110752]
# gradient using back prop is[-0.00110752]
# gradient using grad checker is[-0.0016168]
# gradient using back prop is[-0.0016168]
# gradient using grad checker is[-0.00187163]
# gradient using back prop is[-0.00187163]
# gradient using grad checker is[-0.00216247]
# gradient using back prop is[-0.00216247]
# gradient using grad checker is[-0.00212303]
# gradient using back prop is[-0.00212303]
# gradient using grad checker is[-0.00152524]
# gradient using back prop is[-0.00152525]
# gradient using grad checker is[-0.00086291]
# gradient using back prop is[-0.00086291]
# gradient using grad checker is[-0.00043324]
# gradient using back prop is[-0.00043324]
# gradient using grad checker is[-0.00012285]
# gradient using back prop is[-0.00012285]
# gradient using grad checker is[-3.88888921e-05]
# gradient using back prop is[-3.88885395e-05]
# gradient using grad checker is[-1.00786046e-05]
# gradient using back prop is[-1.00760072e-05]
# gradient using grad checker is[-3.33066907e-07]
# gradient using back prop is[-3.33833505e-07]
# gradient using grad checker is[-9.65894031e-07]
# gradient using back prop is[-9.65162515e-07]
# gradient using grad checker is[-7.3052675e-07]
# gradient using back prop is[-7.30366074e-07]
# gradient using grad checker is[-3.10862447e-08]
# gradient using back prop is[-3.06342967e-08]
# gradient using grad checker is[3.64153152e-07]
# gradient using back prop is[3.64008865e-07]
# gradient using grad checker is[-3.63042929e-06]
# gradient using back prop is[-3.63256198e-06]
# gradient using grad checker is[-9.45687972e-06]
# gradient using back prop is[-9.45540965e-06]
# gradient using grad checker is[2.08655315e-05]
# gradient using back prop is[2.08676361e-05]
# gradient using grad checker is[8.65707506e-05]
# gradient using back prop is[8.65705876e-05]
# gradient using grad checker is[0.00030413]
# gradient using back prop is[0.00030413]
# gradient using grad checker is[0.00074832]
# gradient using back prop is[0.00074833]
# gradient using grad checker is[0.00135532]
# gradient using back prop is[0.00135532]
# gradient using grad checker is[0.0019649]
# gradient using back prop is[0.0019649]
# gradient using grad checker is[0.00264506]
# gradient using back prop is[0.00264506]
# gradient using grad checker is[0.00315598]
# gradient using back prop is[0.00315598]
# gradient using grad checker is[0.00333364]
# gradient using back prop is[0.00333364]
# gradient using grad checker is[0.00324889]
# gradient using back prop is[0.00324888]
# gradient using grad checker is[0.0029279]
# gradient using back prop is[0.00292791]
# gradient using grad checker is[0.00269629]
# gradient using back prop is[0.0026963]
# gradient using grad checker is[0.00242194]
# gradient using back prop is[0.00242194]
# gradient using grad checker is[0.00160431]
# gradient using back prop is[0.00160431]
# gradient using grad checker is[0.00066526]
# gradient using back prop is[0.00066526]
# gradient using grad checker is[-3.61932706e-06]
# gradient using back prop is[-3.61928759e-06]
# gradient using grad checker is[-0.00033185]
# gradient using back prop is[-0.00033185]
# gradient using grad checker is[-0.00033113]
# gradient using back prop is[-0.00033113]
# gradient using grad checker is[-0.00021076]
# gradient using back prop is[-0.00021076]
# gradient using grad checker is[-9.47308898e-05]
# gradient using back prop is[-9.47312284e-05]
# gradient using grad checker is[-1.61448632e-05]
# gradient using back prop is[-1.61474567e-05]
# gradient using grad checker is[-5.15143483e-07]
# gradient using back prop is[-5.15980159e-07]
# gradient using grad checker is[-4.08562073e-07]
# gradient using back prop is[-4.08442687e-07]
# gradient using grad checker is[1.02140518e-07]
# gradient using back prop is[1.01308288e-07]
# gradient using grad checker is[1.46549439e-07]
# gradient using back prop is[1.46476411e-07]
# gradient using grad checker is[1.94733119e-06]
# gradient using back prop is[1.94892333e-06]
# gradient using grad checker is[1.39022127e-05]
# gradient using back prop is[1.39004038e-05]
# gradient using grad checker is[7.00639546e-05]
# gradient using back prop is[7.00640489e-05]
# gradient using grad checker is[0.00023208]
# gradient using back prop is[0.00023207]
# gradient using grad checker is[0.0004759]
# gradient using back prop is[0.00047589]
# gradient using grad checker is[0.00112329]
# gradient using back prop is[0.00112329]
# gradient using grad checker is[0.00231575]
# gradient using back prop is[0.00231575]
# gradient using grad checker is[0.00355069]
# gradient using back prop is[0.00355069]
# gradient using grad checker is[0.0049613]
# gradient using back prop is[0.0049613]
# gradient using grad checker is[0.00741752]
# gradient using back prop is[0.00741752]
# gradient using grad checker is[0.00989968]
# gradient using back prop is[0.00989968]
# gradient using grad checker is[0.0123503]
# gradient using back prop is[0.0123503]
# gradient using grad checker is[0.01415787]
# gradient using back prop is[0.01415786]
# gradient using grad checker is[0.01577794]
# gradient using back prop is[0.01577794]
# gradient using grad checker is[0.01636755]
# gradient using back prop is[0.01636755]
# gradient using grad checker is[0.01437927]
# gradient using back prop is[0.01437927]
# gradient using grad checker is[0.01225061]
# gradient using back prop is[0.01225061]
# gradient using grad checker is[0.0103649]
# gradient using back prop is[0.0103649]
# gradient using grad checker is[0.00826191]
# gradient using back prop is[0.00826191]
# gradient using grad checker is[0.00591451]
# gradient using back prop is[0.00591451]
# gradient using grad checker is[0.00375665]
# gradient using back prop is[0.00375665]
# gradient using grad checker is[0.001767]
# gradient using back prop is[0.001767]
# gradient using grad checker is[0.0007195]
# gradient using back prop is[0.0007195]
# gradient using grad checker is[0.00013244]
# gradient using back prop is[0.00013244]
# gradient using grad checker is[9.69446745e-06]
# gradient using back prop is[9.69700713e-06]
# gradient using grad checker is[7.88258347e-07]
# gradient using back prop is[7.87604654e-07]
# gradient using grad checker is[2.26485497e-07]
# gradient using back prop is[2.2590374e-07]
# gradient using grad checker is[-6.41708908e-07]
# gradient using back prop is[-6.42544994e-07]
# gradient using grad checker is[2.45803378e-06]
# gradient using back prop is[2.45720397e-06]
# gradient using grad checker is[5.51869661e-05]
# gradient using back prop is[5.51848163e-05]
# gradient using grad checker is[8.19544432e-05]
# gradient using back prop is[8.19570463e-05]
# gradient using grad checker is[0.00039462]
# gradient using back prop is[0.00039462]
# gradient using grad checker is[0.0009724]
# gradient using back prop is[0.0009724]
# gradient using grad checker is[0.00211994]
# gradient using back prop is[0.00211994]
# gradient using grad checker is[0.00382748]
# gradient using back prop is[0.00382748]
# gradient using grad checker is[0.00618368]
# gradient using back prop is[0.00618368]
# gradient using grad checker is[0.00911573]
# gradient using back prop is[0.00911573]
# gradient using grad checker is[0.01246277]
# gradient using back prop is[0.01246277]
# gradient using grad checker is[0.01464317]
# gradient using back prop is[0.01464317]
# gradient using grad checker is[0.01610969]
# gradient using back prop is[0.01610968]
# gradient using grad checker is[0.01648729]
# gradient using back prop is[0.01648729]
# gradient using grad checker is[0.01677938]
# gradient using back prop is[0.01677938]
# gradient using grad checker is[0.01635734]
# gradient using back prop is[0.01635734]
# gradient using grad checker is[0.01493366]
# gradient using back prop is[0.01493367]
# gradient using grad checker is[0.01300586]
# gradient using back prop is[0.01300586]
# gradient using grad checker is[0.01294685]
# gradient using back prop is[0.01294685]
# gradient using grad checker is[0.013227]
# gradient using back prop is[0.013227]
# gradient using grad checker is[0.0119891]
# gradient using back prop is[0.0119891]
# gradient using grad checker is[0.00877893]
# gradient using back prop is[0.00877893]
# gradient using grad checker is[0.00492658]
# gradient using back prop is[0.00492658]
# gradient using grad checker is[0.00179456]
# gradient using back prop is[0.00179456]
# gradient using grad checker is[0.00029475]
# gradient using back prop is[0.00029475]
# gradient using grad checker is[4.37250236e-05]
# gradient using back prop is[4.37270918e-05]
# gradient using grad checker is[3.44391182e-06]
# gradient using back prop is[3.44359056e-06]
# gradient using grad checker is[-5.2846616e-07]
# gradient using back prop is[-5.28777804e-07]
# gradient using grad checker is[-1.39888101e-07]
# gradient using back prop is[-1.39661842e-07]
# gradient using grad checker is[5.68878278e-06]
# gradient using back prop is[5.68976132e-06]
# gradient using grad checker is[3.88866717e-05]
# gradient using back prop is[3.88855578e-05]
# gradient using grad checker is[0.00016084]
# gradient using back prop is[0.00016084]
# gradient using grad checker is[0.00054114]
# gradient using back prop is[0.00054114]
# gradient using grad checker is[0.00159197]
# gradient using back prop is[0.00159196]
# gradient using grad checker is[0.00312907]
# gradient using back prop is[0.00312907]
# gradient using grad checker is[0.00540339]
# gradient using back prop is[0.00540339]
# gradient using grad checker is[0.00841535]
# gradient using back prop is[0.00841535]
# gradient using grad checker is[0.01108387]
# gradient using back prop is[0.01108386]
# gradient using grad checker is[0.01270833]
# gradient using back prop is[0.01270833]
# gradient using grad checker is[0.0120307]
# gradient using back prop is[0.0120307]
# gradient using grad checker is[0.01081786]
# gradient using back prop is[0.01081786]
# gradient using grad checker is[0.00920918]
# gradient using back prop is[0.00920918]
# gradient using grad checker is[0.00795627]
# gradient using back prop is[0.00795627]
# gradient using grad checker is[0.00787292]
# gradient using back prop is[0.00787292]
# gradient using grad checker is[0.00865497]
# gradient using back prop is[0.00865497]
# gradient using grad checker is[0.01004919]
# gradient using back prop is[0.01004919]
# gradient using grad checker is[0.01261957]
# gradient using back prop is[0.01261958]
# gradient using grad checker is[0.01542302]
# gradient using back prop is[0.01542302]
# gradient using grad checker is[0.0153179]
# gradient using back prop is[0.0153179]
# gradient using grad checker is[0.01028848]
# gradient using back prop is[0.01028848]
# gradient using grad checker is[0.0050323]
# gradient using back prop is[0.0050323]
# gradient using grad checker is[0.00199458]
# gradient using back prop is[0.00199457]
# gradient using grad checker is[0.00033108]
# gradient using back prop is[0.00033108]
# gradient using grad checker is[5.99742478e-05]
# gradient using back prop is[5.99743806e-05]
# gradient using grad checker is[9.02389274e-06]
# gradient using back prop is[9.02285548e-06]
# gradient using grad checker is[-1.7985613e-07]
# gradient using back prop is[-1.80736074e-07]
# gradient using grad checker is[4.02788913e-06]
# gradient using back prop is[4.02575212e-06]
# gradient using grad checker is[2.56594745e-05]
# gradient using back prop is[2.56590446e-05]
# gradient using grad checker is[8.64153193e-05]
# gradient using back prop is[8.64172752e-05]
# gradient using grad checker is[0.0002869]
# gradient using back prop is[0.0002869]
# gradient using grad checker is[0.00073796]
# gradient using back prop is[0.00073796]
# gradient using grad checker is[0.0019141]
# gradient using back prop is[0.00191411]
# gradient using grad checker is[0.00321734]
# gradient using back prop is[0.00321734]
# gradient using grad checker is[0.00525263]
# gradient using back prop is[0.00525263]
# gradient using grad checker is[0.00800443]
# gradient using back prop is[0.00800443]
# gradient using grad checker is[0.01012329]
# gradient using back prop is[0.01012329]
# gradient using grad checker is[0.00921577]
# gradient using back prop is[0.00921577]
# gradient using grad checker is[0.0061862]
# gradient using back prop is[0.0061862]
# gradient using grad checker is[0.00345761]
# gradient using back prop is[0.00345761]
# gradient using grad checker is[0.00128438]
# gradient using back prop is[0.00128439]
# gradient using grad checker is[0.00044177]
# gradient using back prop is[0.00044177]
# gradient using grad checker is[0.00194342]
# gradient using back prop is[0.00194342]
# gradient using grad checker is[0.00498297]
# gradient using back prop is[0.00498297]
# gradient using grad checker is[0.00910946]
# gradient using back prop is[0.00910946]
# gradient using grad checker is[0.01493664]
# gradient using back prop is[0.01493664]
# gradient using grad checker is[0.02038762]
# gradient using back prop is[0.02038762]
# gradient using grad checker is[0.01871448]
# gradient using back prop is[0.01871448]
# gradient using grad checker is[0.01037997]
# gradient using back prop is[0.01037997]
# gradient using grad checker is[0.00341471]
# gradient using back prop is[0.00341471]
# gradient using grad checker is[0.00116329]
# gradient using back prop is[0.00116329]
# gradient using grad checker is[0.00039428]
# gradient using back prop is[0.00039429]
# gradient using grad checker is[2.04991579e-05]
# gradient using back prop is[2.05001863e-05]
# gradient using grad checker is[-1.49702473e-05]
# gradient using back prop is[-1.49672126e-05]
# gradient using grad checker is[-1.96065386e-06]
# gradient using back prop is[-1.95675745e-06]
# gradient using grad checker is[3.40172335e-05]
# gradient using back prop is[3.40198971e-05]
# gradient using grad checker is[9.05897579e-05]
# gradient using back prop is[9.05900601e-05]
# gradient using grad checker is[0.00032219]
# gradient using back prop is[0.00032219]
# gradient using grad checker is[0.00053441]
# gradient using back prop is[0.00053441]
# gradient using grad checker is[0.00094719]
# gradient using back prop is[0.00094719]
# gradient using grad checker is[0.00189474]
# gradient using back prop is[0.00189474]
# gradient using grad checker is[0.00287441]
# gradient using back prop is[0.0028744]
# gradient using grad checker is[0.004559]
# gradient using back prop is[0.004559]
# gradient using grad checker is[0.00656442]
# gradient using back prop is[0.00656442]
# gradient using grad checker is[0.00687533]
# gradient using back prop is[0.00687533]
# gradient using grad checker is[0.00476139]
# gradient using back prop is[0.00476138]
# gradient using grad checker is[0.00172926]
# gradient using back prop is[0.00172927]
# gradient using grad checker is[-0.00023578]
# gradient using back prop is[-0.00023578]
# gradient using grad checker is[-0.00101755]
# gradient using back prop is[-0.00101755]
# gradient using grad checker is[0.00051887]
# gradient using back prop is[0.00051887]
# gradient using grad checker is[0.0039713]
# gradient using back prop is[0.0039713]
# gradient using grad checker is[0.00832646]
# gradient using back prop is[0.00832647]
# gradient using grad checker is[0.01403204]
# gradient using back prop is[0.01403204]
# gradient using grad checker is[0.02133545]
# gradient using back prop is[0.02133545]
# gradient using grad checker is[0.02676681]
# gradient using back prop is[0.02676681]
# gradient using grad checker is[0.02125889]
# gradient using back prop is[0.02125889]
# gradient using grad checker is[0.00946125]
# gradient using back prop is[0.00946125]
# gradient using grad checker is[0.00116121]
# gradient using back prop is[0.00116121]
# gradient using grad checker is[0.00035812]
# gradient using back prop is[0.00035812]
# gradient using grad checker is[0.00023286]
# gradient using back prop is[0.00023285]
# gradient using grad checker is[-2.5990321e-05]
# gradient using back prop is[-2.59912467e-05]
# gradient using grad checker is[-1.95043981e-05]
# gradient using back prop is[-1.95043352e-05]
# gradient using grad checker is[3.8768988e-06]
# gradient using back prop is[3.8783113e-06]
# gradient using grad checker is[3.21276339e-05]
# gradient using back prop is[3.21289736e-05]
# gradient using grad checker is[0.00018256]
# gradient using back prop is[0.00018256]
# gradient using grad checker is[0.00062581]
# gradient using back prop is[0.00062581]
