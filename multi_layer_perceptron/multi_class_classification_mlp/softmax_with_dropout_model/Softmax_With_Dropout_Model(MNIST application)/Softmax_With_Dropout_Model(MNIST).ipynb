# %%
import numpy as np
import matplotlib.pyplot as plt
from Softmax_Necessary_Functions_With_Dropout import *
from Softmax_Gradient_Checker_With_Dropout import *
from Load_Dataset import read_input_file
import time
# Out:
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = read_input_file()
# Out:
# WARNING:tensorflow:From /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Softmax_With_Dropout_Model/Softmax_With_Dropout_Model(MNIST application)/Load_Dataset.py:15: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST/t10k-images-idx3-ubyte.gz
# Extracting MNIST/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X_train = X_train_orig.T
Y_train = Y_train_orig.T
X_test = X_test_orig.T
Y_test = Y_test_orig.T
print("X_train has shape: " +str(X_train.shape))
print("Y_train has shape: " +str(Y_train.shape))
print("X_test has shape: " + str(X_test.shape))
print("Y_test has shape: " +str(Y_test.shape))
# Out:
# X_train has shape: (784, 55000)
# Y_train has shape: (10, 55000)
# X_test has shape: (784, 10000)
# Y_test has shape: (10, 10000)

# %%
tic = time.time()
parameters = dropout_model_softmax(X_train, Y_train, 0.0075, 20, [784,6,3,10], keep_prob= 0.8)
tac = time.time()
print('Time taken in training is :' + str(tac-tic) +' seconds')
train_accuracy = predict_accuracy_with_dropout(X_train, Y_train, parameters, 0.8)
test_accuracy = pred_accuracy_softmax(X_test, Y_test, parameters)
print('Train accuracy is : '+str(train_accuracy))
print('Test accuracy is : '+str(test_accuracy))
# Out:
# cost after 0 iterations is 2.3159838016291183
# Time taken in training is :41.076700925827026 seconds
# Train accuracy is : 0.11449090909090909
# Test accuracy is : 0.1328

# %%
AL, cache = forward_prop_with_dropout(X_train, parameters, 0.8)
gradients = back_prop_with_dropout(X_train,Y_train, cache, 0.8)
difference = dropout_gradient_check(X_train,Y_train,parameters,gradients, keep_prob = 0.8)
# Out:
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[3.2018832e-06]
# gradient using back prop is[3.20203877e-06]
# gradient using grad checker is[9.23927601e-06]
# gradient using back prop is[9.2380662e-06]
# gradient using grad checker is[3.12860848e-06]
# gradient using back prop is[3.12842869e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[1.64313008e-07]
# gradient using back prop is[1.65537902e-07]
# gradient using grad checker is[1.07691633e-06]
# gradient using back prop is[1.07599639e-06]
# gradient using grad checker is[1.50013335e-05]
# gradient using back prop is[1.50022534e-05]
# gradient using grad checker is[3.34421379e-05]
# gradient using back prop is[3.34432194e-05]
# gradient using grad checker is[6.18549656e-05]
# gradient using back prop is[6.1856771e-05]
# gradient using grad checker is[4.25659508e-05]
# gradient using back prop is[4.25661863e-05]
# gradient using grad checker is[2.245093e-05]
# gradient using back prop is[2.24537796e-05]
# gradient using grad checker is[2.20290453e-05]
# gradient using back prop is[2.20278777e-05]
# gradient using grad checker is[3.29825056e-05]
# gradient using back prop is[3.29836479e-05]
# gradient using grad checker is[1.15130128e-05]
# gradient using back prop is[1.15119402e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-2.88657986e-08]
# gradient using back prop is[-2.81960876e-08]
# gradient using grad checker is[2.93765012e-06]
# gradient using back prop is[2.93601042e-06]
# gradient using grad checker is[3.42281758e-05]
# gradient using back prop is[3.42301664e-05]
# gradient using grad checker is[0.00010451]
# gradient using back prop is[0.00010451]
# gradient using grad checker is[0.00024032]
# gradient using back prop is[0.00024032]
# gradient using grad checker is[0.00037533]
# gradient using back prop is[0.00037533]
# gradient using grad checker is[0.00029673]
# gradient using back prop is[0.00029674]
# gradient using grad checker is[0.00012467]
# gradient using back prop is[0.00012467]
# gradient using grad checker is[3.88866717e-05]
# gradient using back prop is[3.88900548e-05]
# gradient using grad checker is[3.22519789e-05]
# gradient using back prop is[3.22522676e-05]
# gradient using grad checker is[9.83213511e-06]
# gradient using back prop is[9.83042096e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-5.32907052e-07]
# gradient using back prop is[-5.32288358e-07]
# gradient using grad checker is[-5.45785639e-06]
# gradient using back prop is[-5.45585439e-06]
# gradient using grad checker is[2.2863933e-05]
# gradient using back prop is[2.28628775e-05]
# gradient using grad checker is[4.05675493e-05]
# gradient using back prop is[4.05669076e-05]
# gradient using grad checker is[0.00015433]
# gradient using back prop is[0.00015433]
# gradient using grad checker is[0.00041219]
# gradient using back prop is[0.00041219]
# gradient using grad checker is[0.00062424]
# gradient using back prop is[0.00062424]
# gradient using grad checker is[0.00051568]
# gradient using back prop is[0.00051568]
# gradient using grad checker is[0.00017653]
# gradient using back prop is[0.00017653]
# gradient using grad checker is[3.40549811e-05]
# gradient using back prop is[3.40545449e-05]
# gradient using grad checker is[8.95061802e-06]
# gradient using back prop is[8.95126512e-06]
# gradient using grad checker is[-1.93955962e-05]
# gradient using back prop is[-1.93957102e-05]
# gradient using grad checker is[-2.17492691e-05]
# gradient using back prop is[-2.17487434e-05]
# gradient using grad checker is[-3.11106696e-05]
# gradient using back prop is[-3.11106228e-05]
# gradient using grad checker is[-4.24016378e-05]
# gradient using back prop is[-4.24027346e-05]
# gradient using grad checker is[-4.08095779e-05]
# gradient using back prop is[-4.08111128e-05]
# gradient using grad checker is[-1.94666505e-05]
# gradient using back prop is[-1.94689458e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-4.6629367e-08]
# gradient using back prop is[-4.81755195e-08]
# gradient using grad checker is[6.61692923e-07]
# gradient using back prop is[6.63134395e-07]
# gradient using grad checker is[-8.16013923e-06]
# gradient using back prop is[-8.1587923e-06]
# gradient using grad checker is[-3.55937502e-06]
# gradient using back prop is[-3.55757518e-06]
