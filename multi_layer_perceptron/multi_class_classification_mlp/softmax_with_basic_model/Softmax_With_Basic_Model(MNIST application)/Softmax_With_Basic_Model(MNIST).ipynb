# %%
import numpy as np
import matplotlib.pyplot as plt
from Softmax_Necessary_Functions_With_Basic import *
from Softmax_Gradient_Checker_With_Basic import *
from Load_Dataset import read_input_file
import time
# Out:
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = read_input_file()
# Out:
# WARNING:tensorflow:From /Users/Apple/Google Drive/My Deep Learning practice & innovation/My own model/Softmax_With_Basic_Model/Softmax_With_Basic_Model(MNIST application)/Load_Dataset.py:15: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST/t10k-images-idx3-ubyte.gz
# Extracting MNIST/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/Apple/anaconda3/envs/Arya/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X_train = X_train_orig.T
Y_train = Y_train_orig.T
X_test = X_test_orig.T
Y_test = Y_test_orig.T
print("X_train has shape: " +str(X_train.shape))
print("Y_train has shape: " +str(Y_train.shape))
print("X_test has shape: " + str(X_test.shape))
print("Y_test has shape: " +str(Y_test.shape))
# Out:
# X_train has shape: (784, 55000)
# Y_train has shape: (10, 55000)
# X_test has shape: (784, 10000)
# Y_test has shape: (10, 10000)

# %%
tic = time.time()
parameters = basic_model_softmax(X_train, Y_train, 0.0075, 20, [784,6,3,10])
tac = time.time()
print('Time taken in training is :' + str(tac-tic) +' seconds')
train_accuracy = pred_accuracy_softmax(X_train, Y_train, parameters)
test_accuracy = pred_accuracy_softmax(X_test, Y_test, parameters)
print('Train accuracy is : '+str(train_accuracy))
print('Test accuracy is : '+str(test_accuracy))
# Out:
# cost after 0 iterations is 2.317178403772234
# Time taken in training is :23.86139488220215 seconds
# Train accuracy is : 0.11409090909090909
# Test accuracy is : 0.1155

# %%
AL, cache = forward_prop(X_train, parameters)
gradients = back_prop_without_regularization(X_train,Y_train,cache)
difference = gradient_check(X_train,Y_train,parameters,gradients)
# Out:
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-2.66675571e-06]
# gradient using back prop is[-2.66484524e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[8.60388353e-10]
# gradient using grad checker is[-4.97379915e-07]
# gradient using back prop is[-4.97811484e-07]
# gradient using grad checker is[7.98472399e-06]
# gradient using back prop is[7.98524384e-06]
# gradient using grad checker is[9.34363698e-06]
# gradient using back prop is[9.34455127e-06]
# gradient using grad checker is[4.34763336e-06]
# gradient using back prop is[4.34719933e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[4.24105195e-07]
# gradient using back prop is[4.22853788e-07]
# gradient using grad checker is[2.79110068e-06]
# gradient using back prop is[2.79094902e-06]
# gradient using grad checker is[-2.46469511e-07]
# gradient using back prop is[-2.43926516e-07]
# gradient using grad checker is[-1.42774681e-06]
# gradient using back prop is[-1.42951272e-06]
# gradient using grad checker is[-3.10862447e-08]
# gradient using back prop is[-3.12461808e-08]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[3.01536573e-06]
# gradient using back prop is[3.01694836e-06]
# gradient using grad checker is[-1.9095836e-07]
# gradient using back prop is[-1.90183964e-07]
# gradient using grad checker is[-1.75415238e-07]
# gradient using back prop is[-1.74348646e-07]
# gradient using grad checker is[1.41309187e-05]
# gradient using back prop is[1.41306982e-05]
# gradient using grad checker is[2.89279711e-05]
# gradient using back prop is[2.89288182e-05]
# gradient using grad checker is[9.41668965e-05]
# gradient using back prop is[9.41661833e-05]
# gradient using grad checker is[0.00024193]
# gradient using back prop is[0.00024193]
# gradient using grad checker is[0.00027935]
# gradient using back prop is[0.00027935]
# gradient using grad checker is[0.00020046]
# gradient using back prop is[0.00020046]
# gradient using grad checker is[0.0001256]
# gradient using back prop is[0.00012561]
# gradient using grad checker is[5.774492e-05]
# gradient using back prop is[5.7746602e-05]
# gradient using grad checker is[7.23443527e-05]
# gradient using back prop is[7.2346083e-05]
# gradient using grad checker is[0.00016797]
# gradient using back prop is[0.00016797]
# gradient using grad checker is[0.0002159]
# gradient using back prop is[0.0002159]
# gradient using grad checker is[0.00012012]
# gradient using back prop is[0.00012012]
# gradient using grad checker is[4.77506923e-05]
# gradient using back prop is[4.77501697e-05]
# gradient using grad checker is[1.72706294e-05]
# gradient using back prop is[1.72707369e-05]
# gradient using grad checker is[7.01882996e-06]
# gradient using back prop is[7.01909533e-06]
# gradient using grad checker is[2.26485497e-07]
# gradient using back prop is[2.25107143e-07]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[1.72750703e-06]
# gradient using back prop is[1.72685103e-06]
# gradient using grad checker is[1.23412391e-05]
# gradient using back prop is[1.23409995e-05]
# gradient using grad checker is[2.150502e-05]
# gradient using back prop is[2.15062276e-05]
# gradient using grad checker is[5.24202903e-05]
# gradient using back prop is[5.24211001e-05]
# gradient using grad checker is[9.60165281e-05]
# gradient using back prop is[9.60139809e-05]
# gradient using grad checker is[0.0002116]
# gradient using back prop is[0.0002116]
# gradient using grad checker is[0.00035478]
# gradient using back prop is[0.00035478]
# gradient using grad checker is[0.0006005]
# gradient using back prop is[0.0006005]
# gradient using grad checker is[0.00088585]
# gradient using back prop is[0.00088585]
# gradient using grad checker is[0.00095575]
# gradient using back prop is[0.00095575]
# gradient using grad checker is[0.00075903]
# gradient using back prop is[0.00075903]
# gradient using grad checker is[0.00054724]
# gradient using back prop is[0.00054723]
# gradient using grad checker is[0.00047686]
# gradient using back prop is[0.00047686]
# gradient using grad checker is[0.00061694]
# gradient using back prop is[0.00061695]
# gradient using grad checker is[0.00061001]
# gradient using back prop is[0.00061001]
# gradient using grad checker is[0.000454]
# gradient using back prop is[0.000454]
# gradient using grad checker is[0.0002174]
# gradient using back prop is[0.0002174]
# gradient using grad checker is[6.52544685e-05]
# gradient using back prop is[6.52527284e-05]
# gradient using grad checker is[4.39870362e-06]
# gradient using back prop is[4.39822589e-06]
# gradient using grad checker is[-2.00728323e-05]
# gradient using back prop is[-2.00747203e-05]
# gradient using grad checker is[-1.1155521e-05]
# gradient using back prop is[-1.11531385e-05]
# gradient using grad checker is[-1.29896094e-06]
# gradient using back prop is[-1.29912245e-06]
# gradient using grad checker is[-1.67199588e-06]
# gradient using back prop is[-1.67166615e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[2.7533531e-07]
# gradient using back prop is[2.75845501e-07]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-6.31938946e-06]
# gradient using back prop is[-6.3186386e-06]
# gradient using grad checker is[9.16600129e-06]
# gradient using back prop is[9.16572338e-06]
# gradient using grad checker is[0.00011273]
# gradient using back prop is[0.00011273]
# gradient using grad checker is[0.0003059]
# gradient using back prop is[0.00030589]
# gradient using grad checker is[0.00066001]
# gradient using back prop is[0.00066001]
# gradient using grad checker is[0.00115453]
# gradient using back prop is[0.00115453]
# gradient using grad checker is[0.00183014]
# gradient using back prop is[0.00183014]
# gradient using grad checker is[0.00264397]
# gradient using back prop is[0.00264397]
# gradient using grad checker is[0.0034004]
# gradient using back prop is[0.00340041]
# gradient using grad checker is[0.00389186]
# gradient using back prop is[0.00389186]
# gradient using grad checker is[0.00364892]
# gradient using back prop is[0.00364892]
# gradient using grad checker is[0.00299441]
# gradient using back prop is[0.00299441]
# gradient using grad checker is[0.00259256]
# gradient using back prop is[0.00259256]
# gradient using grad checker is[0.00260269]
# gradient using back prop is[0.00260269]
# gradient using grad checker is[0.0021813]
# gradient using back prop is[0.00218129]
# gradient using grad checker is[0.00146296]
# gradient using back prop is[0.00146296]
# gradient using grad checker is[0.00073612]
# gradient using back prop is[0.00073612]
# gradient using grad checker is[0.00036606]
# gradient using back prop is[0.00036605]
# gradient using grad checker is[6.605827e-05]
# gradient using back prop is[6.60590657e-05]
# gradient using grad checker is[-0.00018598]
# gradient using back prop is[-0.00018598]
# gradient using grad checker is[-0.00034832]
# gradient using back prop is[-0.00034832]
# gradient using grad checker is[-0.00025733]
# gradient using back prop is[-0.00025733]
# gradient using grad checker is[-0.00010037]
# gradient using back prop is[-0.00010037]
# gradient using grad checker is[-1.37223566e-05]
# gradient using back prop is[-1.37233911e-05]
# gradient using grad checker is[3.10862447e-07]
# gradient using back prop is[3.10216287e-07]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[1.41864298e-05]
# gradient using back prop is[1.41839448e-05]
# gradient using grad checker is[0.00014888]
# gradient using back prop is[0.00014888]
# gradient using grad checker is[0.00047276]
# gradient using back prop is[0.00047276]
# gradient using grad checker is[0.00112246]
# gradient using back prop is[0.00112246]
# gradient using grad checker is[0.00205521]
# gradient using back prop is[0.00205521]
# gradient using grad checker is[0.00312589]
# gradient using back prop is[0.00312589]
# gradient using grad checker is[0.00450845]
# gradient using back prop is[0.00450845]
# gradient using grad checker is[0.00592572]
# gradient using back prop is[0.00592572]
# gradient using grad checker is[0.00712655]
# gradient using back prop is[0.00712655]
# gradient using grad checker is[0.00747032]
# gradient using back prop is[0.00747032]
# gradient using grad checker is[0.00730382]
# gradient using back prop is[0.00730382]
# gradient using grad checker is[0.00703882]
# gradient using back prop is[0.00703882]
# gradient using grad checker is[0.00706758]
# gradient using back prop is[0.00706758]
# gradient using grad checker is[0.00658086]
# gradient using back prop is[0.00658086]
# gradient using grad checker is[0.00509474]
# gradient using back prop is[0.00509475]
# gradient using grad checker is[0.00294359]
# gradient using back prop is[0.00294358]
# gradient using grad checker is[0.00138014]
# gradient using back prop is[0.00138014]
# gradient using grad checker is[0.00035793]
# gradient using back prop is[0.00035793]
# gradient using grad checker is[-0.00048405]
# gradient using back prop is[-0.00048405]
# gradient using grad checker is[-0.00101657]
# gradient using back prop is[-0.00101657]
# gradient using grad checker is[-0.00103781]
# gradient using back prop is[-0.00103781]
# gradient using grad checker is[-0.00073096]
# gradient using back prop is[-0.00073096]
# gradient using grad checker is[-0.00029496]
# gradient using back prop is[-0.00029496]
# gradient using grad checker is[-1.03983488e-05]
# gradient using back prop is[-1.03994032e-05]
# gradient using grad checker is[1.99840144e-07]
# gradient using back prop is[1.98785817e-07]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[2.88657986e-08]
# gradient using back prop is[2.78638502e-08]
# gradient using grad checker is[-6.50368648e-06]
# gradient using back prop is[-6.50415549e-06]
# gradient using grad checker is[7.96607225e-05]
# gradient using back prop is[7.96591496e-05]
# gradient using grad checker is[0.00041565]
# gradient using back prop is[0.00041565]
# gradient using grad checker is[0.00093428]
# gradient using back prop is[0.00093428]
# gradient using grad checker is[0.00187899]
# gradient using back prop is[0.00187899]
# gradient using grad checker is[0.00301868]
# gradient using back prop is[0.00301868]
# gradient using grad checker is[0.00427697]
# gradient using back prop is[0.00427696]
# gradient using grad checker is[0.00532543]
# gradient using back prop is[0.00532543]
# gradient using grad checker is[0.0060644]
# gradient using back prop is[0.0060644]
# gradient using grad checker is[0.00677693]
# gradient using back prop is[0.00677693]
# gradient using grad checker is[0.00720042]
# gradient using back prop is[0.00720042]
# gradient using grad checker is[0.00749711]
# gradient using back prop is[0.00749711]
# gradient using grad checker is[0.00794172]
# gradient using back prop is[0.00794172]
# gradient using grad checker is[0.00802592]
# gradient using back prop is[0.00802592]
# gradient using grad checker is[0.00709957]
# gradient using back prop is[0.00709957]
# gradient using grad checker is[0.00499024]
# gradient using back prop is[0.00499024]
# gradient using grad checker is[0.00266815]
# gradient using back prop is[0.00266815]
# gradient using grad checker is[0.00085852]
# gradient using back prop is[0.00085851]
# gradient using grad checker is[-0.00014164]
# gradient using back prop is[-0.00014164]
# gradient using grad checker is[-0.00130085]
# gradient using back prop is[-0.00130085]
# gradient using grad checker is[-0.00182]
# gradient using back prop is[-0.00182]
# gradient using grad checker is[-0.00169542]
# gradient using back prop is[-0.00169542]
# gradient using grad checker is[-0.00114719]
# gradient using back prop is[-0.00114719]
# gradient using grad checker is[-0.00049746]
# gradient using back prop is[-0.00049746]
# gradient using grad checker is[-7.04658554e-05]
# gradient using back prop is[-7.04659236e-05]
# gradient using grad checker is[-1.52189372e-05]
# gradient using back prop is[-1.52190255e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[2.22044605e-07]
# gradient using back prop is[2.22910802e-07]
# gradient using grad checker is[-1.81743509e-05]
# gradient using back prop is[-1.81722893e-05]
# gradient using grad checker is[3.40660833e-05]
# gradient using back prop is[3.40641412e-05]
# gradient using grad checker is[0.00037474]
# gradient using back prop is[0.00037474]
# gradient using grad checker is[0.0009127]
# gradient using back prop is[0.0009127]
# gradient using grad checker is[0.00185728]
# gradient using back prop is[0.00185728]
# gradient using grad checker is[0.00299034]
# gradient using back prop is[0.00299034]
# gradient using grad checker is[0.00357128]
# gradient using back prop is[0.00357128]
# gradient using grad checker is[0.00367028]
# gradient using back prop is[0.00367028]
# gradient using grad checker is[0.00330705]
# gradient using back prop is[0.00330705]
# gradient using grad checker is[0.00266842]
# gradient using back prop is[0.00266842]
# gradient using grad checker is[0.00244382]
# gradient using back prop is[0.00244382]
# gradient using grad checker is[0.002783]
# gradient using back prop is[0.002783]
# gradient using grad checker is[0.00327931]
# gradient using back prop is[0.00327931]
# gradient using grad checker is[0.00312923]
# gradient using back prop is[0.00312923]
# gradient using grad checker is[0.00207109]
# gradient using back prop is[0.00207109]
# gradient using grad checker is[0.00033082]
# gradient using back prop is[0.00033082]
# gradient using grad checker is[-0.00086618]
# gradient using back prop is[-0.00086618]
# gradient using grad checker is[-0.00112551]
# gradient using back prop is[-0.00112551]
# gradient using grad checker is[-0.00108036]
# gradient using back prop is[-0.00108036]
# gradient using grad checker is[-0.00167013]
# gradient using back prop is[-0.00167012]
# gradient using grad checker is[-0.00202104]
# gradient using back prop is[-0.00202104]
# gradient using grad checker is[-0.00172519]
# gradient using back prop is[-0.00172519]
# gradient using grad checker is[-0.00124143]
# gradient using back prop is[-0.00124143]
# gradient using grad checker is[-0.00055309]
# gradient using back prop is[-0.00055309]
# gradient using grad checker is[-8.78341844e-05]
# gradient using back prop is[-8.78356116e-05]
# gradient using grad checker is[-5.77315973e-06]
# gradient using back prop is[-5.77480833e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-5.81446002e-05]
# gradient using back prop is[-5.81453121e-05]
# gradient using grad checker is[-8.11861689e-05]
# gradient using back prop is[-8.11909012e-05]
# gradient using grad checker is[9.76152492e-05]
# gradient using back prop is[9.76152968e-05]
# gradient using grad checker is[0.00035709]
# gradient using back prop is[0.00035709]
# gradient using grad checker is[0.00096406]
# gradient using back prop is[0.00096406]
# gradient using grad checker is[0.00154622]
# gradient using back prop is[0.00154622]
# gradient using grad checker is[0.0016801]
# gradient using back prop is[0.0016801]
# gradient using grad checker is[0.00087898]
# gradient using back prop is[0.00087898]
# gradient using grad checker is[-0.00073507]
# gradient using back prop is[-0.00073507]
# gradient using grad checker is[-0.00245878]
# gradient using back prop is[-0.00245879]
# gradient using grad checker is[-0.00341927]
# gradient using back prop is[-0.00341927]
# gradient using grad checker is[-0.00267509]
# gradient using back prop is[-0.00267509]
# gradient using grad checker is[-0.00218916]
# gradient using back prop is[-0.00218916]
# gradient using grad checker is[-0.00236521]
# gradient using back prop is[-0.0023652]
# gradient using grad checker is[-0.00289705]
# gradient using back prop is[-0.00289705]
# gradient using grad checker is[-0.00324882]
# gradient using back prop is[-0.00324882]
# gradient using grad checker is[-0.00304635]
# gradient using back prop is[-0.00304635]
# gradient using grad checker is[-0.0017921]
# gradient using back prop is[-0.0017921]
# gradient using grad checker is[-0.00109351]
# gradient using back prop is[-0.00109351]
# gradient using grad checker is[-0.00123252]
# gradient using back prop is[-0.00123253]
# gradient using grad checker is[-0.00134353]
# gradient using back prop is[-0.00134353]
# gradient using grad checker is[-0.00107616]
# gradient using back prop is[-0.00107616]
# gradient using grad checker is[-0.00064174]
# gradient using back prop is[-0.00064174]
# gradient using grad checker is[-0.00018466]
# gradient using back prop is[-0.00018466]
# gradient using grad checker is[1.83586479e-05]
# gradient using back prop is[1.83617668e-05]
# gradient using grad checker is[4.8072657e-06]
# gradient using back prop is[4.80747337e-06]
# gradient using grad checker is[-1.26654243e-05]
# gradient using back prop is[-1.26655922e-05]
# gradient using grad checker is[-1.56030744e-05]
# gradient using back prop is[-1.56046408e-05]
# gradient using grad checker is[-4.99755792e-05]
# gradient using back prop is[-4.99741689e-05]
# gradient using grad checker is[-0.00021182]
# gradient using back prop is[-0.00021182]
# gradient using grad checker is[-0.00023507]
# gradient using back prop is[-0.00023507]
# gradient using grad checker is[-0.00018281]
# gradient using back prop is[-0.00018281]
# gradient using grad checker is[-1.35513822e-05]
# gradient using back prop is[-1.35530816e-05]
# gradient using grad checker is[6.85940194e-05]
# gradient using back prop is[6.85932967e-05]
# gradient using grad checker is[-0.00035271]
# gradient using back prop is[-0.00035271]
# gradient using grad checker is[-0.00168796]
# gradient using back prop is[-0.00168796]
# gradient using grad checker is[-0.00402163]
# gradient using back prop is[-0.00402163]
# gradient using grad checker is[-0.00580349]
# gradient using back prop is[-0.00580349]
# gradient using grad checker is[-0.00571285]
# gradient using back prop is[-0.00571285]
# gradient using grad checker is[-0.00456635]
# gradient using back prop is[-0.00456635]
# gradient using grad checker is[-0.00391243]
# gradient using back prop is[-0.00391243]
# gradient using grad checker is[-0.00394576]
# gradient using back prop is[-0.00394576]
# gradient using grad checker is[-0.00421006]
# gradient using back prop is[-0.00421006]
# gradient using grad checker is[-0.00403822]
# gradient using back prop is[-0.00403822]
# gradient using grad checker is[-0.00326527]
# gradient using back prop is[-0.00326527]
# gradient using grad checker is[-0.00171965]
# gradient using back prop is[-0.00171965]
# gradient using grad checker is[-0.00056248]
# gradient using back prop is[-0.00056248]
# gradient using grad checker is[-0.00041372]
# gradient using back prop is[-0.00041372]
# gradient using grad checker is[-0.00040001]
# gradient using back prop is[-0.00040001]
# gradient using grad checker is[-1.30939704e-05]
# gradient using back prop is[-1.30959338e-05]
# gradient using grad checker is[0.00020754]
# gradient using back prop is[0.00020754]
# gradient using grad checker is[0.00021106]
# gradient using back prop is[0.00021106]
# gradient using grad checker is[9.87743221e-05]
# gradient using back prop is[9.87758726e-05]
# gradient using grad checker is[-3.87023746e-06]
# gradient using back prop is[-3.87023804e-06]
# gradient using grad checker is[-1.47326595e-05]
# gradient using back prop is[-1.47306353e-05]
# gradient using grad checker is[-7.26085858e-06]
# gradient using back prop is[-7.26068614e-06]
# gradient using grad checker is[-4.93294294e-05]
# gradient using back prop is[-4.93314604e-05]
# gradient using grad checker is[-0.00019525]
# gradient using back prop is[-0.00019525]
# gradient using grad checker is[-0.00038735]
# gradient using back prop is[-0.00038735]
# gradient using grad checker is[-0.00047212]
# gradient using back prop is[-0.00047212]
# gradient using grad checker is[-0.00045476]
# gradient using back prop is[-0.00045477]
# gradient using grad checker is[-0.00053146]
# gradient using back prop is[-0.00053146]
# gradient using grad checker is[-0.00130122]
# gradient using back prop is[-0.00130122]
# gradient using grad checker is[-0.00342272]
# gradient using back prop is[-0.00342272]
# gradient using grad checker is[-0.0060642]
# gradient using back prop is[-0.0060642]
# gradient using grad checker is[-0.00628587]
# gradient using back prop is[-0.00628587]
# gradient using grad checker is[-0.00446859]
# gradient using back prop is[-0.0044686]
# gradient using grad checker is[-0.00256275]
# gradient using back prop is[-0.00256275]
# gradient using grad checker is[-0.00159193]
# gradient using back prop is[-0.00159193]
# gradient using grad checker is[-0.00146631]
# gradient using back prop is[-0.00146631]
# gradient using grad checker is[-0.001831]
# gradient using back prop is[-0.001831]
# gradient using grad checker is[-0.00280213]
# gradient using back prop is[-0.00280213]
# gradient using grad checker is[-0.00290396]
# gradient using back prop is[-0.00290396]
# gradient using grad checker is[-0.00158095]
# gradient using back prop is[-0.00158095]
# gradient using grad checker is[-0.00053591]
# gradient using back prop is[-0.00053591]
# gradient using grad checker is[-0.0002904]
# gradient using back prop is[-0.0002904]
# gradient using grad checker is[-4.61608529e-05]
# gradient using back prop is[-4.61605577e-05]
# gradient using grad checker is[0.00016374]
# gradient using back prop is[0.00016375]
# gradient using grad checker is[0.00017888]
# gradient using back prop is[0.00017888]
# gradient using grad checker is[0.00013483]
# gradient using back prop is[0.00013483]
# gradient using grad checker is[9.24282872e-05]
# gradient using back prop is[9.24295205e-05]
# gradient using grad checker is[1.07913678e-06]
# gradient using back prop is[1.0793585e-06]
# gradient using grad checker is[-1.58317803e-06]
# gradient using back prop is[-1.58319903e-06]
# gradient using grad checker is[-3.21276339e-05]
# gradient using back prop is[-3.21291033e-05]
# gradient using grad checker is[-8.21698265e-05]
# gradient using back prop is[-8.21701293e-05]
# gradient using grad checker is[-0.0001729]
# gradient using back prop is[-0.0001729]
# gradient using grad checker is[-0.00038519]
# gradient using back prop is[-0.00038518]
# gradient using grad checker is[-0.00044466]
# gradient using back prop is[-0.00044466]
# gradient using grad checker is[-0.00055572]
# gradient using back prop is[-0.00055572]
# gradient using grad checker is[-0.00085782]
# gradient using back prop is[-0.00085782]
# gradient using grad checker is[-0.00234211]
# gradient using back prop is[-0.00234211]
# gradient using grad checker is[-0.0052686]
# gradient using back prop is[-0.0052686]
# gradient using grad checker is[-0.00668256]
# gradient using back prop is[-0.00668256]
# gradient using grad checker is[-0.0045161]
# gradient using back prop is[-0.0045161]
# gradient using grad checker is[-0.00095578]
# gradient using back prop is[-0.00095577]
# gradient using grad checker is[0.00145974]
# gradient using back prop is[0.00145974]
# gradient using grad checker is[0.0025497]
# gradient using back prop is[0.0025497]
# gradient using grad checker is[0.00294758]
# gradient using back prop is[0.00294758]
# gradient using grad checker is[0.00139629]
# gradient using back prop is[0.00139629]
# gradient using grad checker is[-0.00182687]
# gradient using back prop is[-0.00182687]
# gradient using grad checker is[-0.00295617]
# gradient using back prop is[-0.00295617]
# gradient using grad checker is[-0.00210857]
# gradient using back prop is[-0.00210857]
# gradient using grad checker is[-0.00101035]
# gradient using back prop is[-0.00101035]
# gradient using grad checker is[-0.00046106]
# gradient using back prop is[-0.00046106]
# gradient using grad checker is[-0.00024837]
# gradient using back prop is[-0.00024837]
# gradient using grad checker is[-0.00011852]
# gradient using back prop is[-0.00011852]
# gradient using grad checker is[-6.87339075e-05]
# gradient using back prop is[-6.87327957e-05]
# gradient using grad checker is[-1.319167e-05]
# gradient using back prop is[-1.31935949e-05]
# gradient using grad checker is[2.20978791e-05]
# gradient using back prop is[2.20986924e-05]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-2.54085641e-05]
# gradient using back prop is[-2.5407501e-05]
# gradient using grad checker is[-7.24842408e-05]
# gradient using back prop is[-7.24841867e-05]
# gradient using grad checker is[-0.00012818]
# gradient using back prop is[-0.00012818]
# gradient using grad checker is[-0.00025023]
# gradient using back prop is[-0.00025023]
# gradient using grad checker is[-0.00033663]
# gradient using back prop is[-0.00033663]
# gradient using grad checker is[-0.0005421]
# gradient using back prop is[-0.0005421]
# gradient using grad checker is[-0.00151394]
# gradient using back prop is[-0.00151394]
# gradient using grad checker is[-0.00427501]
# gradient using back prop is[-0.00427501]
# gradient using grad checker is[-0.00638408]
# gradient using back prop is[-0.00638408]
# gradient using grad checker is[-0.00501457]
# gradient using back prop is[-0.00501457]
# gradient using grad checker is[-0.00103039]
# gradient using back prop is[-0.00103039]
# gradient using grad checker is[0.00319448]
# gradient using back prop is[0.00319447]
# gradient using grad checker is[0.0050848]
# gradient using back prop is[0.0050848]
# gradient using grad checker is[0.00641639]
# gradient using back prop is[0.00641639]
# gradient using grad checker is[0.00609287]
# gradient using back prop is[0.00609287]
# gradient using grad checker is[0.00226041]
# gradient using back prop is[0.00226041]
# gradient using grad checker is[-0.0023508]
# gradient using back prop is[-0.0023508]
# gradient using grad checker is[-0.00388268]
# gradient using back prop is[-0.00388268]
# gradient using grad checker is[-0.00258172]
# gradient using back prop is[-0.00258172]
# gradient using grad checker is[-0.00072619]
# gradient using back prop is[-0.00072619]
# gradient using grad checker is[-0.00013659]
# gradient using back prop is[-0.00013659]
# gradient using grad checker is[-0.00010909]
# gradient using back prop is[-0.00010909]
# gradient using grad checker is[-0.00010244]
# gradient using back prop is[-0.00010244]
# gradient using grad checker is[-1.00963682e-05]
# gradient using back prop is[-1.00966935e-05]
# gradient using grad checker is[-1.09290355e-05]
# gradient using back prop is[-1.09268113e-05]
# gradient using grad checker is[3.63264974e-06]
# gradient using back prop is[3.6326397e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-1.96065386e-06]
# gradient using back prop is[-1.95956811e-06]
# gradient using grad checker is[-2.97806224e-05]
# gradient using back prop is[-2.97815706e-05]
# gradient using grad checker is[-8.8036245e-05]
# gradient using back prop is[-8.80377928e-05]
# gradient using grad checker is[-0.00014233]
# gradient using back prop is[-0.00014233]
# gradient using grad checker is[-0.00028459]
# gradient using back prop is[-0.00028459]
# gradient using grad checker is[-0.00084355]
# gradient using back prop is[-0.00084355]
# gradient using grad checker is[-0.00291728]
# gradient using back prop is[-0.00291728]
# gradient using grad checker is[-0.00566948]
# gradient using back prop is[-0.00566948]
# gradient using grad checker is[-0.00587354]
# gradient using back prop is[-0.00587354]
# gradient using grad checker is[-0.00267116]
# gradient using back prop is[-0.00267116]
# gradient using grad checker is[0.00162882]
# gradient using back prop is[0.00162882]
# gradient using grad checker is[0.00459928]
# gradient using back prop is[0.00459928]
# gradient using grad checker is[0.00611508]
# gradient using back prop is[0.00611508]
# gradient using grad checker is[0.00690008]
# gradient using back prop is[0.00690009]
# gradient using grad checker is[0.00522814]
# gradient using back prop is[0.00522814]
# gradient using grad checker is[0.0009359]
# gradient using back prop is[0.0009359]
# gradient using grad checker is[-0.00325688]
# gradient using back prop is[-0.00325688]
# gradient using grad checker is[-0.00433849]
# gradient using back prop is[-0.00433849]
# gradient using grad checker is[-0.0025192]
# gradient using back prop is[-0.00251919]
# gradient using grad checker is[-0.00041571]
# gradient using back prop is[-0.00041571]
# gradient using grad checker is[0.00025968]
# gradient using back prop is[0.00025968]
# gradient using grad checker is[7.7726714e-05]
# gradient using back prop is[7.77270764e-05]
# gradient using grad checker is[-4.14801526e-05]
# gradient using back prop is[-4.14789205e-05]
# gradient using grad checker is[-9.28146449e-06]
# gradient using back prop is[-9.28278204e-06]
# gradient using grad checker is[3.42392781e-06]
# gradient using back prop is[3.42275607e-06]
# gradient using grad checker is[4.04787315e-06]
# gradient using back prop is[4.04746713e-06]
# gradient using grad checker is[1.7408297e-06]
# gradient using back prop is[1.74046501e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-6.30606678e-06]
# gradient using back prop is[-6.30610766e-06]
# gradient using grad checker is[-4.18287627e-05]
# gradient using back prop is[-4.18310417e-05]
# gradient using grad checker is[-8.6533003e-05]
# gradient using back prop is[-8.65311081e-05]
# gradient using grad checker is[-0.00035025]
# gradient using back prop is[-0.00035025]
# gradient using grad checker is[-0.00176666]
# gradient using back prop is[-0.00176665]
# gradient using grad checker is[-0.00432282]
# gradient using back prop is[-0.00432283]
# gradient using grad checker is[-0.00581685]
# gradient using back prop is[-0.00581685]
# gradient using grad checker is[-0.00475841]
# gradient using back prop is[-0.00475841]
# gradient using grad checker is[-0.00180206]
# gradient using back prop is[-0.00180206]
# gradient using grad checker is[0.00101221]
# gradient using back prop is[0.00101221]
# gradient using grad checker is[0.00315031]
# gradient using back prop is[0.00315031]
# gradient using grad checker is[0.0041058]
# gradient using back prop is[0.0041058]
# gradient using grad checker is[0.00371633]
# gradient using back prop is[0.00371633]
# gradient using grad checker is[0.0013079]
# gradient using back prop is[0.0013079]
# gradient using grad checker is[-0.0024789]
# gradient using back prop is[-0.0024789]
# gradient using grad checker is[-0.00462399]
# gradient using back prop is[-0.00462399]
# gradient using grad checker is[-0.00391495]
# gradient using back prop is[-0.00391495]
# gradient using grad checker is[-0.0020636]
# gradient using back prop is[-0.0020636]
# gradient using grad checker is[-0.00036206]
# gradient using back prop is[-0.00036206]
# gradient using grad checker is[0.00029745]
# gradient using back prop is[0.00029745]
# gradient using grad checker is[0.00011067]
# gradient using back prop is[0.00011067]
# gradient using grad checker is[-0.00013682]
# gradient using back prop is[-0.00013681]
# gradient using grad checker is[-6.16973139e-05]
# gradient using back prop is[-6.16943424e-05]
# gradient using grad checker is[-1.49902313e-05]
# gradient using back prop is[-1.49889942e-05]
# gradient using grad checker is[1.59716684e-05]
# gradient using back prop is[1.59725451e-05]
# gradient using grad checker is[1.2922996e-06]
# gradient using back prop is[1.29291692e-06]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[0.]
# gradient using back prop is[0.]
# gradient using grad checker is[-9.59232693e-06]
# gradient using back prop is[-9.59353886e-06]
# gradient using grad checker is[-4.14446255e-05]
# gradient using back prop is[-4.1445759e-05]
# gradient using grad checker is[-9.79416548e-05]
# gradient using back prop is[-9.79407361e-05]
# gradient using grad checker is[-0.00057157]
# gradient using back prop is[-0.00057157]
# gradient using grad checker is[-0.00250026]
# gradient using back prop is[-0.00250026]
# gradient using grad checker is[-0.00480307]
# gradient using back prop is[-0.00480307]
# gradient using grad checker is[-0.0053149]
# gradient using back prop is[-0.00531491]
# gradient using grad checker is[-0.00396668]
# gradient using back prop is[-0.00396668]
# gradient using grad checker is[-0.00199754]
# gradient using back prop is[-0.00199754]
# gradient using grad checker is[-0.00014301]
# gradient using back prop is[-0.00014301]
# gradient using grad checker is[0.00100776]
# gradient using back prop is[0.00100777]
# gradient using grad checker is[0.000698]
# gradient using back prop is[0.000698]
# gradient using grad checker is[-0.00052539]
# gradient using back prop is[-0.00052539]
# gradient using grad checker is[-0.00375806]
# gradient using back prop is[-0.00375806]
# gradient using grad checker is[-0.00701476]
# gradient using back prop is[-0.00701476]
# gradient using grad checker is[-0.00678142]
# gradient using back prop is[-0.00678142]
